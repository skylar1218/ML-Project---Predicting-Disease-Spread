# %% [markdown]
# <a href="https://colab.research.google.com/github/skylar1218/ML-Project---Predicting-Disease-Spread/blob/master/Final_Submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Contributor: Carly, Skylar, Thomas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive
# Out:
# /content/drive

# %% [markdown]
# # Import Data

# %%
# import package
import numpy as np
import pandas as pd

# %%
# import csv files
url = "https://raw.githubusercontent.com/skylar1218/ML-Project---Predicting-Disease-Spread/master/data/dengue_features_train.csv"
dengue_features_train = pd.read_csv(url)

# %%
url = "https://raw.githubusercontent.com/skylar1218/ML-Project---Predicting-Disease-Spread/master/data/dengue_labels_train.csv"
dengue_labels_train = pd.read_csv(url)

# %%
url = 'https://raw.githubusercontent.com/skylar1218/ML-Project---Predicting-Disease-Spread/master/data/dengue_features_test.csv'
dengue_features_test = pd.read_csv(url)

# %% [markdown]
# # Data Description

# %%
dengue_features_train.head()
# Out:
#   city  year  ...  station_min_temp_c station_precip_mm
# 0   sj  1990  ...                20.0              16.0
# 1   sj  1990  ...                22.2               8.6
# 2   sj  1990  ...                22.8              41.4
# 3   sj  1990  ...                23.3               4.0
# 4   sj  1990  ...                23.9               5.8
#
# [5 rows x 24 columns]

# %%
dengue_features_train.shape
# Out:
# (1456, 24)

# %%
dengue_labels_train.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
dengue_labels_train.shape
# Out:
# (1456, 4)

# %%
dengue_features_test.head()
# Out:
#   city  year  ...  station_min_temp_c station_precip_mm
# 0   sj  2008  ...                21.7              75.2
# 1   sj  2008  ...                22.2              34.3
# 2   sj  2008  ...                22.8               3.0
# 3   sj  2008  ...                24.4               0.3
# 4   sj  2008  ...                23.3              84.1
#
# [5 rows x 24 columns]

# %%
dengue_features_test.shape
# Out:
# (416, 24)

# %%
dengue_features_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
#  10  reanalysis_avg_temp_k                  1446 non-null   float64
#  11  reanalysis_dew_point_temp_k            1446 non-null   float64
#  12  reanalysis_max_air_temp_k              1446 non-null   float64
#  13  reanalysis_min_air_temp_k              1446 non-null   float64
#  14  reanalysis_precip_amt_kg_per_m2        1446 non-null   float64
#  15  reanalysis_relative_humidity_percent   1446 non-null   float64
#  16  reanalysis_sat_precip_amt_mm           1443 non-null   float64
#  17  reanalysis_specific_humidity_g_per_kg  1446 non-null   float64
#  18  reanalysis_tdtr_k                      1446 non-null   float64
#  19  station_avg_temp_c                     1413 non-null   float64
#  20  station_diur_temp_rng_c                1413 non-null   float64
#  21  station_max_temp_c                     1436 non-null   float64
#  22  station_min_temp_c                     1442 non-null   float64
#  23  station_precip_mm                      1434 non-null   float64
# dtypes: float64(20), int64(2), object(2)
# memory usage: 273.1+ KB

# %%
dengue_features_train.describe()
# Out:
#               year   weekofyear  ...  station_min_temp_c  station_precip_mm
# count  1456.000000  1456.000000  ...         1442.000000        1434.000000
# mean   2001.031593    26.503434  ...           22.102150          39.326360
# std       5.408314    15.019437  ...            1.574066          47.455314
# min    1990.000000     1.000000  ...           14.700000           0.000000
# 25%    1997.000000    13.750000  ...           21.100000           8.700000
# 50%    2002.000000    26.500000  ...           22.200000          23.850000
# 75%    2005.000000    39.250000  ...           23.300000          53.900000
# max    2010.000000    53.000000  ...           25.600000         543.300000
#
# [8 rows x 22 columns]

# %%
# plot histogram for all features
# %matplotlib inline
import matplotlib.pyplot as plt
dengue_features_train.hist(bins=50, figsize=(20,15))

plt.show()

# %%
# check missing for each column
# training data
dengue_features_train.isnull().sum(axis=0)
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# station_min_temp_c                        14
# station_precip_mm                         22
# dtype: int64

# %%
# test data
dengue_features_test.isnull().sum(axis=0)
# Out:
# city                                      0
# year                                      0
# weekofyear                                0
# week_start_date                           0
# ndvi_ne                                  43
# ndvi_nw                                  11
# ndvi_se                                   1
# ndvi_sw                                   1
# precipitation_amt_mm                      2
# reanalysis_air_temp_k                     2
# reanalysis_avg_temp_k                     2
# reanalysis_dew_point_temp_k               2
# reanalysis_max_air_temp_k                 2
# reanalysis_min_air_temp_k                 2
# reanalysis_precip_amt_kg_per_m2           2
# reanalysis_relative_humidity_percent      2
# reanalysis_sat_precip_amt_mm              2
# reanalysis_specific_humidity_g_per_kg     2
# reanalysis_tdtr_k                         2
# station_avg_temp_c                       12
# station_diur_temp_rng_c                  12
# station_max_temp_c                        3
# station_min_temp_c                        9
# station_precip_mm                         5
# dtype: int64

# %%
pd.set_option('display.max_rows', None)
dengue_features_train[(dengue_features_train['city'] == 'sj') & (dengue_features_train['weekofyear'] == 23)]
# Out:
#     city  year  ...  station_min_temp_c station_precip_mm
# 5     sj  1990  ...                23.9              39.1
# 57    sj  1991  ...                23.3              20.6
# 109   sj  1992  ...                22.8             103.9
# 162   sj  1993  ...                25.0               1.3
# 214   sj  1994  ...                23.3              67.3
# 266   sj  1995  ...                22.8              35.5
# 317   sj  1996  ...                23.9               2.3
# 369   sj  1997  ...                22.2              31.3
# 421   sj  1998  ...                23.9              10.5
# 474   sj  1999  ...                22.8              56.8
# 526   sj  2000  ...                23.3               4.8
# 577   sj  2001  ...                23.9               6.7
# 629   sj  2002  ...                23.3              12.9
# 681   sj  2003  ...                22.8               3.3
# 733   sj  2004  ...                22.8               4.6
# 786   sj  2005  ...                24.4               4.4
# 838   sj  2006  ...                24.4               1.3
# 889   sj  2007  ...                23.3              33.3
#
# [18 rows x 24 columns]

# %% [markdown]
# # Delete Training Data Observations with Majority Features Missing
#
# https://thispointer.com/python-pandas-how-to-drop-rows-in-dataframe-by-conditions-on-column-values/

# %%
# option 1 - keep only the rows with at least 5 non-na values
# X_train1 = dengue_features_train.dropna(thresh=5)

# %%
# option 2 - get names of indexes for which observations with more than 15 variables' values missing
indexNames = dengue_features_train[dengue_features_train.isnull().sum(axis=1)>15].index

# %%
indexNames
# Out:
# Int64Index([87, 139, 399, 451, 711, 763, 1118, 1170, 1378, 1430], dtype='int64')

# %%
dengue_features_train[dengue_features_train.isnull().sum(axis=1)>15]
# Out:
#      city  year  ...  station_min_temp_c station_precip_mm
# 87     sj  1992  ...                 NaN               NaN
# 139    sj  1993  ...                 NaN               NaN
# 399    sj  1998  ...                 NaN               NaN
# 451    sj  1999  ...                 NaN               NaN
# 711    sj  2004  ...                 NaN               NaN
# 763    sj  2005  ...                 NaN               NaN
# 1118   iq  2004  ...                 NaN               NaN
# 1170   iq  2005  ...                 NaN               NaN
# 1378   iq  2009  ...                 NaN               NaN
# 1430   iq  2010  ...                 NaN               NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# *   Half of the missing observations are from week 53 of the year; those observations have all features' values missing.

# %%
# check how many observations are from week 53 in training data
dengue_features_train[dengue_features_train.weekofyear > 52]
# Out:
#      city  year  ...  station_min_temp_c station_precip_mm
# 139    sj  1993  ...                 NaN               NaN
# 451    sj  1999  ...                 NaN               NaN
# 763    sj  2005  ...                 NaN               NaN
# 1170   iq  2005  ...                 NaN               NaN
# 1430   iq  2010  ...                 NaN               NaN
#
# [5 rows x 24 columns]

# %%
# check how many observations are from week 53 in testing data
dengue_features_test[dengue_features_test.weekofyear > 52]
# Out:
#    city  year  ...  station_min_temp_c station_precip_mm
# 87   sj  2010  ...                 NaN               NaN
#
# [1 rows x 24 columns]

# %% [markdown]
# *   There is only 1 test data with week of the year = 53
# *   We can drop the week 53 observations in the training data and then predict the week 53 observations either using the model or set it equal to the average of the week 52 prediction

# %%
# delete these row indexes from dengue_features_train
X_train1 = dengue_features_train.drop(indexNames)
y_train1 = dengue_labels_train.drop(indexNames)

# %%
print(X_train1.shape)
print(y_train1.shape)
# Out:
# (1446, 24)
# (1446, 4)

# %%
# check missing for each column
X_train1.isnull().sum(axis=0)
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  189
# ndvi_nw                                   47
# ndvi_se                                   17
# ndvi_sw                                   17
# precipitation_amt_mm                       3
# reanalysis_air_temp_k                      0
# reanalysis_avg_temp_k                      0
# reanalysis_dew_point_temp_k                0
# reanalysis_max_air_temp_k                  0
# reanalysis_min_air_temp_k                  0
# reanalysis_precip_amt_kg_per_m2            0
# reanalysis_relative_humidity_percent       0
# reanalysis_sat_precip_amt_mm               3
# reanalysis_specific_humidity_g_per_kg      0
# reanalysis_tdtr_k                          0
# station_avg_temp_c                        33
# station_diur_temp_rng_c                   33
# station_max_temp_c                        10
# station_min_temp_c                         4
# station_precip_mm                         12
# dtype: int64

# %% [markdown]
# # Create a Dummy Variable for City

# %%
X_train1['city_sj'] = [1 if x == 'sj' else 0 for x in X_train1['city']]

# %%
X_train1.head()
# Out:
#   city  year  weekofyear  ... station_min_temp_c  station_precip_mm  city_sj
# 0   sj  1990          18  ...               20.0               16.0        1
# 1   sj  1990          19  ...               22.2                8.6        1
# 2   sj  1990          20  ...               22.8               41.4        1
# 3   sj  1990          21  ...               23.3                4.0        1
# 4   sj  1990          22  ...               23.9                5.8        1
#
# [5 rows x 25 columns]

# %%
X_test1 = dengue_features_test.copy()
X_test1['city_sj'] = [1 if x == 'sj' else 0 for x in X_test1['city']]

# %%
X_test1.head()
# Out:
#   city  year  weekofyear  ... station_min_temp_c  station_precip_mm  city_sj
# 0   sj  2008          18  ...               21.7               75.2        1
# 1   sj  2008          19  ...               22.2               34.3        1
# 2   sj  2008          20  ...               22.8                3.0        1
# 3   sj  2008          21  ...               24.4                0.3        1
# 4   sj  2008          22  ...               23.3               84.1        1
#
# [5 rows x 25 columns]

# %% [markdown]
# # Replace Feature Missing Value
#
# https://medium.com/@george.drakos62/handling-missing-values-in-machine-learning-part-1-dda69d4f88ca
#
# https://towardsdatascience.com/6-different-ways-to-compensate-for-missing-values-data-imputation-with-examples-6022d9ca0779
#
# *   Replace with overall Median
# ```
# dataframe.Column_Name.fillna(dataframe.Column_Name.median(),inplace=True)
# ```
# *   Replace with values close to the mean value but within one standard deviation
# ```
# Column_Name_avg = dataframe['Column_Name'].mean()
# Column_Name_std = dataframe['Column_Name'].std()
# Column_Name_null_count = dataframe['Column_Name'].isnull().sum()
# Column_Name_null_random_list = np.random.randint(Column_Name_avg - Column_Name_std, Column_Name_avg + Column_Name_std, size=Column_Name_null_count)
# dataframe['Column_Name'][np.isnan(dataframe['Column_Name'])] = Column_Name_null_random_list
# dataframe['Column_Name'] = dataframe['Column_Name'].astype(int)
# ```
# *   Back-fill or forward-fill to propagate next or previous values respectively
# ```
# # for back fill
# dataframe.fillna(method='bfill',inplace=True)
# # for forward-fill
# dataframe.fillna(method='ffill',inplace=True)
# ```
# *   Replace with some constant value outside fixed value range: -999,-1 etc
# ```
# dataframe.Column_Name.fillna(-99,inplace=True)
# ```
# *   Replace with median by cluster (imputation using k-NN)
#  * Computationally expensive. KNN works by storing the whole training dataset in memory.
#  * K-NN is quite sensitive to outliers in the data (unlike SVM).
# ```
# import sys
# from impyute.imputation.cs import fast_knn
# # Increase the recursion limit of the OS
# sys.setrecursionlimit(100000)
# # start the KNN training
# imputed_training=fast_knn(train.values, k=30)
# ```
# * Imputation Using Multivariate Imputation by Chained Equation (MICE)
#  * filling the missing data multiple times
#  * Multiple Imputations (MIs) are much better than a single imputation as it measures the uncertainty of the missing values in a better way
#   * can handle different variables of different data types (ie., continuous or binary) as well as complexities such as bounds or survey skip patterns
# ```
# from impyute.imputation.cs import mice
# # start the MICE training
# imputed_training=mice(train.values)
# ```
# * Stochastic regression imputation
#  * predict the missing values by regressing it from other related variables in the same dataset plus some random residual value
#
# * Multivariate feature imputation
#  * https://scikit-learn.org/stable/modules/generated/sklearn.impute.IterativeImputer.html#sklearn.impute.IterativeImputer
# * Nearest neighbors imputation
#  * https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html#sklearn.impute.KNNImputer

# %%
# from sklearn.impute import KNNImputer

# imputer = KNNImputer(n_neighbors=5)

# label = X_train1.iloc[:, 0:4]
# data = X_train1.iloc[:, 4:]

# data_missing_filled = imputer.fit_transform(data)
# data_missing_filled

# %% [markdown]
# ## Find the optimal n_cluster for EM-type Algorithm (k-POD)

# %%
# find the optimal n_cluster for training data
X_tr = X_train1.copy()

# %%
# features that have no missing values
X_tr = X_tr[['city_sj', 'weekofyear', 'reanalysis_air_temp_k', 'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k', 
             'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k', 'reanalysis_precip_amt_kg_per_m2', 
             'reanalysis_relative_humidity_percent', 'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k']]

# %%
# find the optimal n_cluster using k-Means on features with no missing values
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

def getInertia(X,kmeans):
    ''' This function returns the exact same value as the attribute inertia_ of kmeans'''
    inertia = 0
    for J in range(len(X)):
        inertia = inertia + np.linalg.norm(X[J] - kmeans.cluster_centers_[kmeans.labels_[J]])**2
    return inertia

# %%
inertias_1 = []
silhouette_avgs = []
max_K = 15
for k in np.arange(1,max_K+1):
    kmeans = KMeans(n_clusters=k, random_state=0).fit(X_tr)    
    inertias_1 = inertias_1 + [kmeans.inertia_]
    if k>1:
        silhouette_avgs = silhouette_avgs + [silhouette_score(X_tr, kmeans.labels_)]

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
plt.title("Inertia_1: sum square distances to closest cluster")
plt.plot(np.arange(1,max_K+1),inertias_1)
plt.xticks(np.arange(1,max_K+1))
plt.xlabel('number of clusters')
plt.grid()

plt.subplot(1,2,2)  
plt.title("Average Silhouette")
plt.plot(np.arange(2,max_K+1), silhouette_avgs)
plt.xticks(np.arange(2,max_K+1))
plt.xlabel('number of clusters')
plt.grid()

plt.show()

# %% [markdown]
# There is to evident elbow for k=2. This value also maximize the silhouette plot. So k=2 is acceptable number of clusters.

# %%
# find the optimal n_cluster for test data
df = X_test1.copy()

# %%
indexNames = X_test1[X_test1.isnull().sum(axis=1)>15].index

# %%
df = df.drop(indexNames)

# %%
print(df.shape)
# Out:
# (414, 25)

# %%
df.isnull().sum(axis=0)
# Out:
# city                                      0
# year                                      0
# weekofyear                                0
# week_start_date                           0
# ndvi_ne                                  42
# ndvi_nw                                  10
# ndvi_se                                   0
# ndvi_sw                                   0
# precipitation_amt_mm                      0
# reanalysis_air_temp_k                     0
# reanalysis_avg_temp_k                     0
# reanalysis_dew_point_temp_k               0
# reanalysis_max_air_temp_k                 0
# reanalysis_min_air_temp_k                 0
# reanalysis_precip_amt_kg_per_m2           0
# reanalysis_relative_humidity_percent      0
# reanalysis_sat_precip_amt_mm              0
# reanalysis_specific_humidity_g_per_kg     0
# reanalysis_tdtr_k                         0
# station_avg_temp_c                       10
# station_diur_temp_rng_c                  10
# station_max_temp_c                        1
# station_min_temp_c                        7
# station_precip_mm                         3
# city_sj                                   0
# dtype: int64

# %%
df = df[['city_sj', 'weekofyear', 'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
         'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k', 'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
         'reanalysis_precip_amt_kg_per_m2', 'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
         'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k']]

# %%
# find the optimal n_cluster using k-Means on features with no missing values
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

def getInertia(X,kmeans):
    ''' This function returns the exact same value as the attribute inertia_ of kmeans'''
    inertia = 0
    for J in range(len(X)):
        inertia = inertia + np.linalg.norm(X[J] - kmeans.cluster_centers_[kmeans.labels_[J]])**2
    return inertia

# %%
inertias_1 = []
silhouette_avgs = []
max_K = 15
for k in np.arange(1,max_K+1):
    kmeans = KMeans(n_clusters=k, random_state=0).fit(df)    
    inertias_1 = inertias_1 + [kmeans.inertia_]
    if k>1:
        silhouette_avgs = silhouette_avgs + [silhouette_score(df, kmeans.labels_)]

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
plt.title("Inertia_1: sum square distances to closest cluster")
plt.plot(np.arange(1,max_K+1),inertias_1)
plt.xticks(np.arange(1,max_K+1))
plt.xlabel('number of clusters')
plt.grid()

plt.subplot(1,2,2)  
plt.title("Average Silhouette")
plt.plot(np.arange(2,max_K+1), silhouette_avgs)
plt.xticks(np.arange(2,max_K+1))
plt.xlabel('number of clusters')
plt.grid()

plt.show()

# %% [markdown]
# There is to evident elbow for k=2. This value also maximize the silhouette plot. So k=2 is acceptable number of clusters.

# %% [markdown]
# ## Iterative EM-type algorithm:
#
# *   Initialize missing values to their column means
# *   Repeat until convergence
# *   Perform K-means clustering on the filled-in data
# *   Set the missing values to the centroid coordinates of the clusters to which they were assigned
#
# https://stackoverflow.com/questions/35611465/python-scikit-learn-clustering-with-missing-data
#
# https://arxiv.org/pdf/1411.7013.pdf

# %%
X_tr = X_train1.copy()
X_te = X_test1.copy()

# %%
X_tr.drop(columns=['city', 'year', 'week_start_date'], inplace=True)
X_te.drop(columns=['city', 'year', 'week_start_date'], inplace=True)

# %%
from sklearn.cluster import KMeans

def kmeans_missing(X, n_clusters, max_iter=10):
    """Perform K-Means clustering on data with missing values.

    Args:
      X: An [n_samples, n_features] array of data to cluster.
      n_clusters: Number of clusters to form.
      max_iter: Maximum number of EM iterations to perform.

    Returns:
      labels: An [n_samples] vector of integer labels.
      centroids: An [n_clusters, n_features] array of cluster centroids.
      X_hat: Copy of X with the missing values filled in.
    """

    # Initialize missing values to their column means
    missing = ~np.isfinite(X)
    mu = np.nanmean(X, 0, keepdims=1)
    X_hat = np.where(missing, mu, X)

    for i in range(max_iter):
        if i > 0:
            # initialize KMeans with the previous set of centroids. this is much
            # faster and makes it easier to check convergence (since labels
            # won't be permuted on every iteration), but might be more prone to
            # getting stuck in local minima.
            cls = KMeans(n_clusters, init=prev_centroids)
        else:
            # do multiple random initializations in parallel
            cls = KMeans(n_clusters, n_jobs=-1)

        # perform clustering on the filled-in data
        labels = cls.fit_predict(X_hat)
        centroids = cls.cluster_centers_

        # fill in the missing values based on their cluster centroids
        X_hat[missing] = centroids[labels][missing]

        # when the labels have stopped changing then we have converged
        if i > 0 and np.all(labels == prev_labels):
            break

        prev_labels = labels
        prev_centroids = cls.cluster_centers_

    return labels, centroids, X_hat

# %%
# filling the missing
# X_tr_hat is the output data
labels_tr, centroids_tr, X_tr_hat = kmeans_missing(X_tr, n_clusters=2) # n_cluster is defined in the previous step
labels_te, centroids_te, X_te_hat = kmeans_missing(X_te, n_clusters=2)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_kmeans.py:1008: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return self.fit(X, sample_weight=sample_weight).labels_
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_kmeans.py:1008: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return self.fit(X, sample_weight=sample_weight).labels_

# %%
X_train2 = pd.DataFrame(X_tr_hat, index=X_tr.index, columns=X_tr.columns)
y_train2 = y_train1.copy()

# %%
X_test2 = pd.DataFrame(X_te_hat, index=X_te.index, columns=X_te.columns)

# %% [markdown]
# # Split Data into Train and Validation

# %%
df = X_train2.copy()

# %%
# merge the label with features before splitting the data
df['total_cases'] = y_train2.total_cases

# %%
from sklearn.model_selection import train_test_split

train_set, val_set = train_test_split(df, test_size = 0.3, random_state = 42)

# %%
train_set_feature = train_set.drop(['total_cases'], axis=1)
train_set_label = train_set.total_cases

# %%
val_set_feature = val_set.drop(['total_cases'], axis=1)
val_set_label = val_set.total_cases

# %%
print(train_set_feature.shape)
print(val_set_feature.shape)
# Out:
# (1012, 22)
# (434, 22)

# %%
# looking for correlations
from pandas.plotting import scatter_matrix
attributes = ["city_sj","weekofyear","ndvi_ne", "ndvi_nw", "ndvi_se","ndvi_sw","total_cases"]
scatter_matrix(train_set[attributes], figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49e58f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49f01d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49c8b7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b499df198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b3537c668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49bbc908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49b2f748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48e8f6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48e8f4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49bc92e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b4991da20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b497da5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48ea9eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b497c0d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48f9a278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49740cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48f5f748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b496b04a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b496897f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48e12fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b495ef470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48e2c208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49d54cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49de2f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48e9c208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49004be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48f249b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b494d5128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49e4aa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48d87320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48fae7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49f73f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b4a4a8b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b4a457e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b499ac5c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b4a3aa2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b4a36e9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b4a3254a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48f5b048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48dec128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49b6d240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48de3198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48da80f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48ed0208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b4a12b4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b4a0d1cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49e192e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b49afa048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b48e4f6a0>]],
#       dtype=object)

# %% [markdown]
# # Feature Scaling

# %%
df_tr = train_set_feature.copy()
df_val = val_set_feature.copy()
df_te = X_test2.copy()

# %%
col_names = ['weekofyear', 'ndvi_ne', 'ndvi_nw', 'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k', 
             'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k', 'reanalysis_max_air_temp_k', 
             'reanalysis_min_air_temp_k', 'reanalysis_precip_amt_kg_per_m2', 'reanalysis_relative_humidity_percent', 
             'reanalysis_sat_precip_amt_mm', 'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k', 
             'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c', 'station_min_temp_c', 'station_precip_mm']

# %%
# select the continuous numeric features in training data
features_tr = df_tr[col_names]

# select the continuous numeric features in val data
features_val = df_val[col_names]

# select the continuous numeric features in test data
features_te = df_te[col_names]

# %%
# sclae on only continuous numeric features
from sklearn.preprocessing import StandardScaler

# fit the standard scaler on training data features value
scaler = StandardScaler().fit(features_tr.values)

# scale training, val, test features value based on training features value
features_tr = scaler.transform(features_tr.values)
features_val = scaler.transform(features_val.values)
features_te = scaler.transform(features_te.values)

# %%
# transform it back to dataframe with proper index and column names
tr_feature_scaled = pd.DataFrame(features_tr, columns=col_names, index=train_set_feature.index)
val_feature_scaled = pd.DataFrame(features_val, columns=col_names, index=val_set_feature.index)
te_feature_scaled = pd.DataFrame(features_te, columns=col_names, index=X_test2.index)

# %%
tr_dummy = train_set_feature[['city_sj']]

val_dummy = val_set_feature[['city_sj']]

te_dummy = X_test2[['city_sj']]

# %%
# merge back the dummry features
tr_feature_scaled = pd.concat([tr_feature_scaled, tr_dummy], axis=1)
val_feature_scaled = pd.concat([val_feature_scaled, val_dummy], axis=1)
te_feature_scaled = pd.concat([te_feature_scaled, te_dummy], axis=1)

# %%
tr_feature_scaled.head()
# Out:
#       weekofyear   ndvi_ne  ...  station_precip_mm  city_sj
# 996     0.576417  0.655168  ...          -0.183824      0.0
# 1204    0.510122  1.411393  ...           1.789088      0.0
# 1064    1.637146  0.851545  ...          -0.327683      0.0
# 1207    0.709008  0.740433  ...          -0.794194      0.0
# 97     -1.014675 -0.405059  ...          -0.699659      1.0
#
# [5 rows x 22 columns]

# %%
print(tr_feature_scaled.shape)
print(val_feature_scaled.shape)
print(te_feature_scaled.shape)
# Out:
# (1012, 22)
# (434, 22)
# (416, 22)

# %%
tr_label = train_set_label.copy()
val_label = val_set_label.copy()

# %% [markdown]
# Final datasets are:
# *   tr_feature_scaled
# *   tr_label
# *   val_feature_scaled
# *   val_label
# *   te_feature

# %% [markdown]
# # Base Line models

# %% [markdown]
# We are going to take two models as baselines models. Es decir, que estos dos modelos van a ser nuestro punto de partida, y la idea es mejorar los resultados de estos modelos que son mas simples con modelos mas complejos y optimizaciones

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score

#poly = PolynomialFeatures(1) 
#X_poly = poly.fit_transform(tr_feature_scaled)
#val_poly = poly.fit_transform(val_feature_scaled)

lin_reg = LinearRegression()
lin_reg.fit(tr_feature_scaled, tr_label)

cv = cross_val_score(lin_reg, tr_feature_scaled, tr_label, cv = 4, scoring='neg_mean_absolute_error')
print("CV AVG MAE: ",-cv.mean())

predictions = lin_reg.predict(val_feature_scaled)
mae = mean_absolute_error(val_label, predictions)


print("MAE in val : ", mae)
# Out:
# CV AVG MAE:  21.14023174974135
# MAE in val :  21.4010899621619

# %%
# predict on test data
te_pred = lin_reg.predict(te_feature_scaled)
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)
upload = './My Drive/ML Term Project/Submission CSV/submission_linregressor.csv'
submission.to_csv(upload, index = False)

# %% [markdown]
# ## K-Neighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

kn = KNeighborsRegressor(n_neighbors=6)
kn.fit(tr_feature_scaled, tr_label)

cv = cross_val_score(kn, tr_feature_scaled, tr_label, cv = 4, scoring='neg_mean_absolute_error')
print("CV AVG MAE: ",-cv.mean())

predictions = kn.predict(val_feature_scaled)
mae = mean_absolute_error(val_label, predictions)
print("MAE: ", mae)
# Out:
# CV AVG MAE:  19.411561264822133
# MAE:  19.589861751152075

# %%
# predict on test data
te_pred = kn.predict(te_feature_scaled)
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)
upload = './My Drive/ML Term Project/Submission CSV/submission_knregressor.csv'
submission.to_csv(upload, index = False)

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Fit a Decision Tree with Default Parameters

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())

# %%
dt_reg = DecisionTreeRegressor(random_state=42)

# fit the decision tree regressor onto training data
dt_reg.fit(tr_feature_scaled, tr_label)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=42, splitter='best')

# %%
# plot feature importance
import matplotlib
import matplotlib.pyplot as plt

features = tr_feature_scaled.columns
importances = dt_reg.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(10,15))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# predict on val data
val_pred = dt_reg.predict(val_feature_scaled)

# %%
# mean absolue error of the val data
mean_absolute_error(val_label, val_pred)
# Out:
# 24.944700460829495

# %%
# cross-validation
dt_cv_score = cross_val_score(dt_reg, tr_feature_scaled, tr_label, cv=20, scoring='neg_mean_absolute_error')

# %%
dt_mae_scores = -dt_cv_score
display_scores(dt_mae_scores)
# Out:
# Scores: [20.52941176 18.11764706 34.         23.70588235 22.15686275 40.49019608
#  29.78431373 26.76470588 27.78431373 28.17647059 19.62745098 29.1372549
#  26.44       13.58       20.04       15.58       16.68       18.66
#  20.42       13.06      ]
# Mean: 23.23672549019608

# %% [markdown]
# ## Hyperparameters Tuning

# %%
# random search to fine tune hyperparameters
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from scipy.stats import uniform
from time import time

# set parameter range 
param_distribs = {
    
    'max_depth': randint(low=1, high=20),
    'min_samples_split': uniform(loc=0, scale=1),
    'min_samples_leaf': uniform(loc=0, scale=1),
    'max_features': randint(low=1, high=22),
    'max_leaf_nodes': randint(low=2, high=20),
}

# %%
dt_reg = DecisionTreeRegressor(random_state=42)
rnd_search_dt = RandomizedSearchCV(dt_reg, param_distributions=param_distribs, n_jobs=-1,
                                   n_iter=1000, cv=20, scoring='neg_mean_absolute_error', random_state=42)

start = time()
rnd_search_dt.fit(tr_feature_scaled, tr_label)
print("RandomizedSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(rnd_search_dt.cv_results_['params'])))
# Out:
# RandomizedSearchCV took 53.60 seconds for 1000 candidate parameter settings.

# %%
# display the score of each hyperparameter combination tested during the random search
cvres = rnd_search_dt.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print("{:.4f}".format(mean_score), params)
# Out:
# nan {'max_depth': 7, 'max_features': 20, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.7319939418114051, 'min_samples_split': 0.5986584841970366}
# -20.6352 {'max_depth': 7, 'max_features': 19, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.45924889196586716, 'min_samples_split': 0.33370861113902184}
# nan {'max_depth': 8, 'max_features': 3, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.7219987722668247, 'min_samples_split': 0.9385527090157502}
# -20.8568 {'max_depth': 2, 'max_features': 21, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.3042422429595377, 'min_samples_split': 0.5247564316322378}
# -20.8568 {'max_depth': 12, 'max_features': 17, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.04666566321361543, 'min_samples_split': 0.9737555188414592}
# nan {'max_depth': 15, 'max_features': 15, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.5142344384136116, 'min_samples_split': 0.5924145688620425}
# -19.7593 {'max_depth': 3, 'max_features': 5, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.17052412368729153, 'min_samples_split': 0.06505159298527952}
# -20.6272 {'max_depth': 4, 'max_features': 14, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.3854165025399161, 'min_samples_split': 0.015966252220214194}
# nan {'max_depth': 2, 'max_features': 20, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.6832635188254582, 'min_samples_split': 0.6099966577826209}
# nan {'max_depth': 8, 'max_features': 15, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.9093204020787821, 'min_samples_split': 0.2587799816000169}
# -21.0935 {'max_depth': 8, 'max_features': 4, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.4251558744912447, 'min_samples_split': 0.20794166286818883}
# nan {'max_depth': 4, 'max_features': 18, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.9394989415641891, 'min_samples_split': 0.8948273504276488}
# -18.7260 {'max_depth': 14, 'max_features': 16, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.0884925020519195, 'min_samples_split': 0.1959828624191452}
# nan {'max_depth': 8, 'max_features': 21, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.7473201101373809, 'min_samples_split': 0.5396921323890798}
# -18.1595 {'max_depth': 13, 'max_features': 9, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.1652669390630025, 'min_samples_split': 0.01563640674119393}
# -22.1881 {'max_depth': 9, 'max_features': 1, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.2934881747180381, 'min_samples_split': 0.014079822715084456}
# nan {'max_depth': 19, 'max_features': 17, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.7290071680409873, 'min_samples_split': 0.7712703466859457}
# nan {'max_depth': 5, 'max_features': 10, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.6510770255019445, 'min_samples_split': 0.9149596755437808}
# -20.1230 {'max_depth': 9, 'max_features': 8, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.3308980248526492, 'min_samples_split': 0.06355835028602363}
# nan {'max_depth': 5, 'max_features': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.6375574713552131, 'min_samples_split': 0.8872127425763265}
# nan {'max_depth': 1, 'max_features': 3, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.9717120953891037, 'min_samples_split': 0.8489138242660839}
# -20.8568 {'max_depth': 5, 'max_features': 14, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.04043358953843135, 'min_samples_split': 0.7106628896857874}
# -21.4369 {'max_depth': 10, 'max_features': 13, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.47537022318211175, 'min_samples_split': 0.5632755719763837}
# -21.0569 {'max_depth': 4, 'max_features': 5, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.41038292303562973, 'min_samples_split': 0.7555511385430487}
# -18.6469 {'max_depth': 4, 'max_features': 13, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.289751452913768, 'min_samples_split': 0.16122128725400442}
# -18.7330 {'max_depth': 2, 'max_features': 10, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.295633685837714, 'min_samples_split': 0.10549425983027061}
# -20.1230 {'max_depth': 12, 'max_features': 12, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.32434502100527396, 'min_samples_split': 0.12208795470067335}
# -22.3166 {'max_depth': 7, 'max_features': 1, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.22793516254194168, 'min_samples_split': 0.4271077886262563}
# -18.3209 {'max_depth': 13, 'max_features': 9, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.006952130531190703, 'min_samples_split': 0.5107473025775657}
# -20.9959 {'max_depth': 9, 'max_features': 5, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.1198653673336828, 'min_samples_split': 0.33761517140362796}
# -18.1450 {'max_depth': 15, 'max_features': 9, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.06489224710898156, 'min_samples_split': 0.2539154139343447}
# nan {'max_depth': 12, 'max_features': 7, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.712270589924442, 'min_samples_split': 0.1480869299533999}
# nan {'max_depth': 17, 'max_features': 17, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.5026790232288615, 'min_samples_split': 0.05147875124998935}
# -22.3177 {'max_depth': 5, 'max_features': 1, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.23956189066697242, 'min_samples_split': 0.1448948720912231}
# -18.7981 {'max_depth': 12, 'max_features': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.08085332633271525, 'min_samples_split': 0.36965445606140446}
# nan {'max_depth': 17, 'max_features': 6, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.6323058305935795, 'min_samples_split': 0.6335297107608947}
# nan {'max_depth': 11, 'max_features': 16, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.835302495589238, 'min_samples_split': 0.32078006497173583}
# nan {'max_depth': 6, 'max_features': 16, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.5908929431882418, 'min_samples_split': 0.6775643618422824}
# -22.3849 {'max_depth': 19, 'max_features': 3, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.17436642900499144, 'min_samples_split': 0.690937738102466}
# -18.4748 {'max_depth': 7, 'max_features': 18, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.13752094414599325, 'min_samples_split': 0.3410663510502585}
# -18.3209 {'max_depth': 18, 'max_features': 10, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.22855002179729966, 'min_samples_split': 0.17495492709593619}
# -19.9274 {'max_depth': 16, 'max_features': 20, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.24185229090045168, 'min_samples_split': 0.09310276780589921}
# nan {'max_depth': 12, 'max_features': 5, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.8826363431893397, 'min_samples_split': 0.18870710834137938}
# nan {'max_depth': 9, 'max_features': 3, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.8466611422383059, 'min_samples_split': 0.8563242918780924}
# nan {'max_depth': 1, 'max_features': 20, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.9356349942209475, 'min_samples_split': 0.7853406511139436}
# -20.7604 {'max_depth': 8, 'max_features': 20, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.3722827665617431, 'min_samples_split': 0.9401334424577784}
# -20.6518 {'max_depth': 18, 'max_features': 14, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.4856137535862266, 'min_samples_split': 0.44842414298624733}
# -20.9959 {'max_depth': 9, 'max_features': 4, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.018075363615520867, 'min_samples_split': 0.4938937151834346}
# nan {'max_depth': 16, 'max_features': 20, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.8492234104941779, 'min_samples_split': 0.6576128923003434}
# nan {'max_depth': 1, 'max_features': 16, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.50881407683876, 'min_samples_split': 0.6363326181858954}
# -21.1198 {'max_depth': 14, 'max_features': 6, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.3930977246667604, 'min_samples_split': 0.8920465551771133}
# nan {'max_depth': 2, 'max_features': 21, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.5769038846263591, 'min_samples_split': 0.4925176938188639}
# -20.8230 {'max_depth': 5, 'max_features': 16, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.02431596643145384, 'min_samples_split': 0.6454722959071678}
# nan {'max_depth': 17, 'max_features': 12, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.9148643902204485, 'min_samples_split': 0.3701587002554444}
# nan {'max_depth': 9, 'max_features': 5, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.5527649668354899, 'min_samples_split': 0.5722924691708383}
# -20.8568 {'max_depth': 1, 'max_features': 20, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.31692200515627766, 'min_samples_split': 0.1694927466860925}
# -21.0864 {'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.0704161308495439, 'min_samples_split': 0.20891871761536018}
# nan {'max_depth': 15, 'max_features': 2, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.8773730719279554, 'min_samples_split': 0.7407686177542044}
# nan {'max_depth': 1, 'max_features': 9, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.7089109969101186, 'min_samples_split': 0.5528199769079077}
# nan {'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.8670723185801037, 'min_samples_split': 0.9132405525564713}
# -20.4157 {'max_depth': 7, 'max_features': 4, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.19427395351204224, 'min_samples_split': 0.07094091699992766}
# nan {'max_depth': 14, 'max_features': 16, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.8900053418175663, 'min_samples_split': 0.3379951568515358}
# -21.9154 {'max_depth': 2, 'max_features': 2, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.03734818874921442, 'min_samples_split': 0.8226005606596583}
# nan {'max_depth': 11, 'max_features': 5, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.8278690037875887, 'min_samples_split': 0.2715429158197419}
# -19.2656 {'max_depth': 12, 'max_features': 5, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.085347464993768, 'min_samples_split': 0.0516817211686077}
# nan {'max_depth': 15, 'max_features': 3, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.7260913337226615, 'min_samples_split': 0.9758520794625346}
# -20.6272 {'max_depth': 10, 'max_features': 19, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.39882090144479454, 'min_samples_split': 0.43352073758074205}
# nan {'max_depth': 5, 'max_features': 21, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.6884999007653664, 'min_samples_split': 0.05819359550844361}
# -20.8568 {'max_depth': 1, 'max_features': 15, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.23978735915740323, 'min_samples_split': 0.09387329008129175}
# nan {'max_depth': 8, 'max_features': 13, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.9548652806631941, 'min_samples_split': 0.7378969166957685}
# nan {'max_depth': 5, 'max_features': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.5660372104940763, 'min_samples_split': 0.15864644764249103}
# -20.9959 {'max_depth': 14, 'max_features': 5, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.040728802318970136, 'min_samples_split': 0.8554605840110072}
# -19.6809 {'max_depth': 5, 'max_features': 12, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.09783416065100148, 'min_samples_split': 0.49161587511683236}
# -21.3324 {'max_depth': 7, 'max_features': 4, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.4646738129396114, 'min_samples_split': 0.6497736826427634}
# -19.7354 {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.04530400977204452, 'min_samples_split': 0.3746126146264712}
# nan {'max_depth': 19, 'max_features': 1, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.6839637693981411, 'min_samples_split': 0.6158511643899138}
# nan {'max_depth': 16, 'max_features': 2, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.8671989335550038, 'min_samples_split': 0.6364035974460113}
# nan {'max_depth': 12, 'max_features': 18, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.6432882184423532, 'min_samples_split': 0.45825289049151663}
# nan {'max_depth': 19, 'max_features': 11, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.6259396701015728, 'min_samples_split': 0.8204268437712681}
# -18.2752 {'max_depth': 8, 'max_features': 10, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.19579113478929644, 'min_samples_split': 0.06936130087516545}
# nan {'max_depth': 14, 'max_features': 2, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.6830067734163568, 'min_samples_split': 0.07118864846022899}
# -18.4099 {'max_depth': 8, 'max_features': 10, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.2606945282359031, 'min_samples_split': 0.4960374542934062}
# nan {'max_depth': 18, 'max_features': 13, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.877472013527053, 'min_samples_split': 0.7350710438038858}
# nan {'max_depth': 4, 'max_features': 10, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.7506147516408583, 'min_samples_split': 0.806834739267264}
# -21.6377 {'max_depth': 17, 'max_features': 3, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.1276897294224656, 'min_samples_split': 0.25001644921610466}
# nan {'max_depth': 5, 'max_features': 12, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.6798447799002458, 'min_samples_split': 0.7399087604473745}
# nan {'max_depth': 3, 'max_features': 9, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.5343274735305634, 'min_samples_split': 0.4965611906830777}
# -20.8568 {'max_depth': 13, 'max_features': 19, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.053485296747368904, 'min_samples_split': 0.9585414968831983}
# -20.1230 {'max_depth': 19, 'max_features': 12, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.31931363759041487, 'min_samples_split': 0.9500619670508049}
# -20.6419 {'max_depth': 19, 'max_features': 15, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.44844552197831977, 'min_samples_split': 0.29321077169806453}
# nan {'max_depth': 4, 'max_features': 21, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.7896181427945539, 'min_samples_split': 0.09120610304869037}
# nan {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.5495288823237355, 'min_samples_split': 0.441530501373377}
# nan {'max_depth': 11, 'max_features': 11, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.9686519439741349, 'min_samples_split': 0.6880300101750391}
# -20.8568 {'max_depth': 12, 'max_features': 17, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.08410680611499743, 'min_samples_split': 0.70096913145912}
# nan {'max_depth': 10, 'max_features': 9, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.8918969087767766, 'min_samples_split': 0.1466048216920255}
# -20.9182 {'max_depth': 5, 'max_features': 6, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.3742707957561203, 'min_samples_split': 0.3706421470668909}
# nan {'max_depth': 17, 'max_features': 7, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.7533781852589416, 'min_samples_split': 0.37625958553091576}
# -21.4388 {'max_depth': 19, 'max_features': 12, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.4242220092469763, 'min_samples_split': 0.906354385094736}
# -22.6166 {'max_depth': 7, 'max_features': 3, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.011353644767419069, 'min_samples_split': 0.46866064199412627}
# nan {'max_depth': 8, 'max_features': 9, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.7460448792654233, 'min_samples_split': 0.5833687650971596}
# -22.4804 {'max_depth': 17, 'max_features': 1, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.436335831606556, 'min_samples_split': 0.8021092490267341}
# nan {'max_depth': 13, 'max_features': 13, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.8911431136980711, 'min_samples_split': 0.5277011090862999}
# nan {'max_depth': 11, 'max_features': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.5538542844013208, 'min_samples_split': 0.969302535619099}
# -19.7911 {'max_depth': 18, 'max_features': 15, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.21680910658649122, 'min_samples_split': 0.29449394683942987}
# nan {'max_depth': 1, 'max_features': 21, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.901158010490989, 'min_samples_split': 0.04544638034145787}
# nan {'max_depth': 12, 'max_features': 10, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.8902637838909163, 'min_samples_split': 0.45565675278571294}
# -20.9415 {'max_depth': 8, 'max_features': 4, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.3533522280260528, 'min_samples_split': 0.5836561118508721}
# nan {'max_depth': 5, 'max_features': 9, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.9862107444796029, 'min_samples_split': 0.6981617140197451}
# -21.3551 {'max_depth': 17, 'max_features': 9, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.41120672087218624, 'min_samples_split': 0.6027818820232985}
# -20.1230 {'max_depth': 16, 'max_features': 13, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.07620037959916315, 'min_samples_split': 0.9405318271353834}
# nan {'max_depth': 19, 'max_features': 5, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.9191765518355596, 'min_samples_split': 0.08274842003530614}
# -18.3086 {'max_depth': 18, 'max_features': 13, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.026366974497252005, 'min_samples_split': 0.3764633668780496}
# -20.8568 {'max_depth': 1, 'max_features': 18, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.15041689110352818, 'min_samples_split': 0.5941307153521351}
# -21.4400 {'max_depth': 17, 'max_features': 13, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.4686931597949703, 'min_samples_split': 0.4148195023376652}
# -20.8568 {'max_depth': 1, 'max_features': 21, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.07535906035246231, 'min_samples_split': 0.691714397168912}
# nan {'max_depth': 5, 'max_features': 5, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.9131657522576428, 'min_samples_split': 0.585149532325472}
# -20.9710 {'max_depth': 5, 'max_features': 10, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.37785054927578643, 'min_samples_split': 0.24108483232963185}
# nan {'max_depth': 9, 'max_features': 14, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.9540510272587224, 'min_samples_split': 0.60617463445088}
# nan {'max_depth': 1, 'max_features': 17, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.6181282404578958, 'min_samples_split': 0.3581627180328405}
# -21.3764 {'max_depth': 8, 'max_features': 7, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.4762106967890142, 'min_samples_split': 0.8313714900625012}
# nan {'max_depth': 18, 'max_features': 12, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.5519068387744855, 'min_samples_split': 0.5609379715353863}
# -20.6272 {'max_depth': 17, 'max_features': 16, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.4205357786650751, 'min_samples_split': 0.7846682639443096}
# -20.5037 {'max_depth': 14, 'max_features': 2, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.21296416150891073, 'min_samples_split': 0.13637147558676976}
# nan {'max_depth': 2, 'max_features': 6, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.5899176868546331, 'min_samples_split': 0.3922440450997323}
# -22.4144 {'max_depth': 19, 'max_features': 2, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.4509104474161044, 'min_samples_split': 0.910471278403273}
# nan {'max_depth': 10, 'max_features': 19, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.9495206236576421, 'min_samples_split': 0.14707348092903794}
# -18.4087 {'max_depth': 17, 'max_features': 10, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.25824438829895835, 'min_samples_split': 0.4591357562382613}
# -20.9959 {'max_depth': 2, 'max_features': 6, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.3287516102875082, 'min_samples_split': 0.6334008543167258}
# -19.1769 {'max_depth': 16, 'max_features': 11, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.12887972191064923, 'min_samples_split': 0.12804583895777244}
# -20.8568 {'max_depth': 11, 'max_features': 16, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.18006727234929853, 'min_samples_split': 0.696501466227079}
# nan {'max_depth': 3, 'max_features': 3, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.6019353955409602, 'min_samples_split': 0.2238490659063206}
# -18.6482 {'max_depth': 5, 'max_features': 18, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.17701048427674682, 'min_samples_split': 0.08870253375705561}
# -20.9415 {'max_depth': 1, 'max_features': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.3559914842719861, 'min_samples_split': 0.8942172628959257}
# -20.8067 {'max_depth': 17, 'max_features': 14, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.321582764680029, 'min_samples_split': 0.09229058622874609}
# nan {'max_depth': 15, 'max_features': 15, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.9208724005318132, 'min_samples_split': 0.06107795985486375}
# nan {'max_depth': 4, 'max_features': 1, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.7482596903836584, 'min_samples_split': 0.18452101935637732}
# nan {'max_depth': 15, 'max_features': 15, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.618254771530296, 'min_samples_split': 0.3689136395697724}
# -18.1912 {'max_depth': 2, 'max_features': 13, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.1477390919062267, 'min_samples_split': 0.13311692858747826}
# nan {'max_depth': 3, 'max_features': 15, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.7496162320085874, 'min_samples_split': 0.03047215273359416}
# -21.1064 {'max_depth': 18, 'max_features': 6, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.3971638325040825, 'min_samples_split': 0.1048691665324809}
# -20.1230 {'max_depth': 5, 'max_features': 10, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.3220791655831783, 'min_samples_split': 0.21144800699654465}
# nan {'max_depth': 12, 'max_features': 17, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.5935924535540487, 'min_samples_split': 0.6791023191444896}
# -21.4662 {'max_depth': 3, 'max_features': 9, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.4795821017542502, 'min_samples_split': 0.5841994847141693}
# nan {'max_depth': 2, 'max_features': 15, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.5865354346607591, 'min_samples_split': 0.5644585425226413}
# -20.1249 {'max_depth': 10, 'max_features': 9, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.3630822963986351, 'min_samples_split': 0.6459172413316012}
# nan {'max_depth': 2, 'max_features': 13, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.6057748193568872, 'min_samples_split': 0.23722679173599448}
# -18.7446 {'max_depth': 6, 'max_features': 6, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.16068137325955567, 'min_samples_split': 0.18656702405130576}
# nan {'max_depth': 9, 'max_features': 3, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.6969614623664215, 'min_samples_split': 0.9972555347683943}
# nan {'max_depth': 6, 'max_features': 2, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.8655071258939803, 'min_samples_split': 0.8170720709492799}
# nan {'max_depth': 17, 'max_features': 6, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.5567628930139298, 'min_samples_split': 0.5716126894698998}
# -20.1230 {'max_depth': 19, 'max_features': 13, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.2050775601494591, 'min_samples_split': 0.9679940665042343}
# nan {'max_depth': 4, 'max_features': 19, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.7362471836984882, 'min_samples_split': 0.5298400231811167}
# nan {'max_depth': 1, 'max_features': 14, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.5812382214226123, 'min_samples_split': 0.1543627152742023}
# nan {'max_depth': 4, 'max_features': 13, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.5938830975578988, 'min_samples_split': 0.3692304815098961}
# nan {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.9899602323899452, 'min_samples_split': 0.32235384497472297}
# -20.8568 {'max_depth': 2, 'max_features': 20, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.13882477344202038, 'min_samples_split': 0.0027108994143296705}
# -21.5062 {'max_depth': 9, 'max_features': 11, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.47157618855015837, 'min_samples_split': 0.41184091414726853}
# -21.0569 {'max_depth': 17, 'max_features': 5, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.4085182929359169, 'min_samples_split': 0.9329380670999546}
# -18.3209 {'max_depth': 11, 'max_features': 9, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.18123306616566015, 'min_samples_split': 0.0664962673667775}
# nan {'max_depth': 8, 'max_features': 8, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.7952673118598902, 'min_samples_split': 0.20162732004774453}
# nan {'max_depth': 3, 'max_features': 21, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.8145747202313821, 'min_samples_split': 0.6651972206962001}
# -21.4935 {'max_depth': 4, 'max_features': 13, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.3924451074226354, 'min_samples_split': 0.8165994394715771}
# nan {'max_depth': 7, 'max_features': 8, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.8996674452921731, 'min_samples_split': 0.6241015441818376}
# -20.8568 {'max_depth': 1, 'max_features': 15, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.2322126951468173, 'min_samples_split': 0.8995745732745685}
# -19.8874 {'max_depth': 2, 'max_features': 14, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.22902539092479635, 'min_samples_split': 0.5428493106134089}
# nan {'max_depth': 6, 'max_features': 6, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.6277080530714179, 'min_samples_split': 0.3349056146570861}
# nan {'max_depth': 15, 'max_features': 15, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.5334610919763215, 'min_samples_split': 0.8938925830509576}
# nan {'max_depth': 4, 'max_features': 6, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.706980461243459, 'min_samples_split': 0.7785719390507511}
# nan {'max_depth': 1, 'max_features': 4, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.7624586857406905, 'min_samples_split': 0.8767656367617495}
# -20.9959 {'max_depth': 1, 'max_features': 6, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.11063173695520723, 'min_samples_split': 0.8464522917345182}
# -21.3698 {'max_depth': 15, 'max_features': 8, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.4863574819956078, 'min_samples_split': 0.4089551770854932}
# nan {'max_depth': 13, 'max_features': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.5427244433475962, 'min_samples_split': 0.25179905890695276}
# nan {'max_depth': 5, 'max_features': 20, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.9590747945640278, 'min_samples_split': 0.3425242571785434}
# -19.7376 {'max_depth': 6, 'max_features': 8, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.2879296164757261, 'min_samples_split': 0.6149502631526544}
# nan {'max_depth': 13, 'max_features': 8, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.6114542354346478, 'min_samples_split': 0.01811018382084051}
# nan {'max_depth': 11, 'max_features': 12, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.5651331835892089, 'min_samples_split': 0.6966508238768923}
# nan {'max_depth': 5, 'max_features': 8, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.771246668519738, 'min_samples_split': 0.374435369720422}
# nan {'max_depth': 9, 'max_features': 19, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.9343670147690148, 'min_samples_split': 0.9255685129067763}
# nan {'max_depth': 1, 'max_features': 14, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.9848411989623346, 'min_samples_split': 0.8388980864459341}
# nan {'max_depth': 1, 'max_features': 19, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.6078943937942587, 'min_samples_split': 0.37930569838554884}
# -18.3209 {'max_depth': 9, 'max_features': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.11426730005568775, 'min_samples_split': 0.4145045842036277}
# -21.3324 {'max_depth': 11, 'max_features': 6, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.4657001223188132, 'min_samples_split': 0.48083697808907355}
# nan {'max_depth': 17, 'max_features': 11, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.9127494628791288, 'min_samples_split': 0.2482264427571519}
# -18.4632 {'max_depth': 7, 'max_features': 20, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.033879160246594986, 'min_samples_split': 0.3114731711327574}
# -20.8568 {'max_depth': 11, 'max_features': 18, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.17803596686975143, 'min_samples_split': 0.9610703174694551}
# nan {'max_depth': 17, 'max_features': 20, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.5021950103312426, 'min_samples_split': 0.5953850173200438}
# -19.8681 {'max_depth': 13, 'max_features': 19, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.03654966784809488, 'min_samples_split': 0.47206694510999925}
# -20.8568 {'max_depth': 8, 'max_features': 19, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.29404467922097155, 'min_samples_split': 0.7140591997898282}
# -22.4312 {'max_depth': 18, 'max_features': 2, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.400763060875326, 'min_samples_split': 0.5596403313082179}
# nan {'max_depth': 4, 'max_features': 1, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.8617856210135173, 'min_samples_split': 0.9461154621336327}
# nan {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.5265784666592938, 'min_samples_split': 0.800749771486121}
# -18.6737 {'max_depth': 18, 'max_features': 7, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.02709599250348349, 'min_samples_split': 0.22197216193294944}
# -20.8211 {'max_depth': 8, 'max_features': 15, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.1785446620543336, 'min_samples_split': 0.6527461078518747}
# nan {'max_depth': 15, 'max_features': 8, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.8053149673579051, 'min_samples_split': 0.9887287819554428}
# -21.7065 {'max_depth': 14, 'max_features': 11, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.3971835296184548, 'min_samples_split': 0.6680851365706462}
# -18.9494 {'max_depth': 14, 'max_features': 16, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.013001923510736035, 'min_samples_split': 0.08550853085446808}
# nan {'max_depth': 19, 'max_features': 16, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.6429255636142532, 'min_samples_split': 0.7039461351385095}
# -20.8568 {'max_depth': 1, 'max_features': 15, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.34181735169787597, 'min_samples_split': 0.2594234334312925}
# nan {'max_depth': 2, 'max_features': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.8306545065652498, 'min_samples_split': 0.3451921448812756}
# -22.3006 {'max_depth': 9, 'max_features': 2, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.2195105250809587, 'min_samples_split': 0.9745472651988699}
# nan {'max_depth': 12, 'max_features': 17, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.5657766199665605, 'min_samples_split': 0.9853673122417347}
# -19.9187 {'max_depth': 17, 'max_features': 18, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.2686773593849461, 'min_samples_split': 0.5416342146608669}
# -20.9959 {'max_depth': 13, 'max_features': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.13935607407282413, 'min_samples_split': 0.8349302367992991}
# -18.5647 {'max_depth': 4, 'max_features': 13, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.27230732651936895, 'min_samples_split': 0.018390676547466733}
# nan {'max_depth': 18, 'max_features': 21, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.5765164755142536, 'min_samples_split': 0.274055220687206}
# nan {'max_depth': 17, 'max_features': 5, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.8297418037072016, 'min_samples_split': 0.2064212717606032}
# nan {'max_depth': 10, 'max_features': 21, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.7321845784590624, 'min_samples_split': 0.25073066056159776}
# nan {'max_depth': 13, 'max_features': 21, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.5732943781794007, 'min_samples_split': 0.8381069631782958}
# -20.2413 {'max_depth': 14, 'max_features': 2, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.1843709206789632, 'min_samples_split': 0.09033696057760787}
# -19.9635 {'max_depth': 19, 'max_features': 21, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.28869373677069987, 'min_samples_split': 0.35567271646494913}
# nan {'max_depth': 17, 'max_features': 7, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.5664046402968972, 'min_samples_split': 0.47605040219909966}
# -20.9959 {'max_depth': 15, 'max_features': 5, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.2699112223921949, 'min_samples_split': 0.5398427789081934}
# nan {'max_depth': 19, 'max_features': 3, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.8464078493145573, 'min_samples_split': 0.955236312723479}
# nan {'max_depth': 11, 'max_features': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.7709122037458219, 'min_samples_split': 0.1065982531337718}
# -21.3663 {'max_depth': 9, 'max_features': 8, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.41279355060675227, 'min_samples_split': 0.704925549688953}
# -18.4576 {'max_depth': 8, 'max_features': 10, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.07593341036962209, 'min_samples_split': 0.07776534407895708}
# nan {'max_depth': 12, 'max_features': 12, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.5902306668690871, 'min_samples_split': 0.3609738969400268}
# nan {'max_depth': 12, 'max_features': 17, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.9502373538208024, 'min_samples_split': 0.44600577295795574}
# nan {'max_depth': 15, 'max_features': 12, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.8729458358764083, 'min_samples_split': 0.7322248864095612}
# nan {'max_depth': 17, 'max_features': 5, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.8491956515653193, 'min_samples_split': 0.24966800885918594}
# nan {'max_depth': 12, 'max_features': 15, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.9440593396866133, 'min_samples_split': 0.0394268113685059}
# nan {'max_depth': 10, 'max_features': 16, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.9993534995658349, 'min_samples_split': 0.5558065814371796}
# nan {'max_depth': 7, 'max_features': 14, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.6974202672468399, 'min_samples_split': 0.29734900737255077}
# -21.3910 {'max_depth': 16, 'max_features': 8, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.4217626597305125, 'min_samples_split': 0.7953418379590974}
# nan {'max_depth': 7, 'max_features': 3, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.5224345760711689, 'min_samples_split': 0.6445466506258222}
# -21.6378 {'max_depth': 14, 'max_features': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.12056688577727881, 'min_samples_split': 0.07695320162920916}
# -21.6735 {'max_depth': 5, 'max_features': 11, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.4410321617481616, 'min_samples_split': 0.40448544968185074}
# nan {'max_depth': 7, 'max_features': 15, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.5384014903807876, 'min_samples_split': 0.6616551750805415}
# nan {'max_depth': 13, 'max_features': 18, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.8859777482361871, 'min_samples_split': 0.6158631881823046}
# nan {'max_depth': 2, 'max_features': 3, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.9903413133417771, 'min_samples_split': 0.0002375235758845795}
# nan {'max_depth': 13, 'max_features': 13, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.9390676985128962, 'min_samples_split': 0.7987832357736654}
# -20.6272 {'max_depth': 7, 'max_features': 14, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.40193091360924216, 'min_samples_split': 0.47987562030390885}
# -21.6853 {'max_depth': 16, 'max_features': 12, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.39828738397563557, 'min_samples_split': 0.09169933511143014}
# nan {'max_depth': 7, 'max_features': 20, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.7322718071846451, 'min_samples_split': 0.003346362042979223}
# -20.0391 {'max_depth': 13, 'max_features': 14, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.2963081204559901, 'min_samples_split': 0.23360775104990994}
# -19.9519 {'max_depth': 16, 'max_features': 1, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.04510067722032318, 'min_samples_split': 0.10946759867911515}
# nan {'max_depth': 4, 'max_features': 12, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.786345014415552, 'min_samples_split': 0.08941100231225951}
# nan {'max_depth': 6, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.600798446442198, 'min_samples_split': 0.9037239671752705}
# -20.9959 {'max_depth': 2, 'max_features': 7, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.2316717013834434, 'min_samples_split': 0.9427317741351257}
# -18.3209 {'max_depth': 19, 'max_features': 13, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.2306698117177587, 'min_samples_split': 0.17652803200550826}
# nan {'max_depth': 9, 'max_features': 17, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.8262056957939659, 'min_samples_split': 0.8007696871298751}
# nan {'max_depth': 15, 'max_features': 17, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.927752283195213, 'min_samples_split': 0.9949078226464353}
# -22.2305 {'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.49118634086862656, 'min_samples_split': 0.9963357758067243}
# nan {'max_depth': 3, 'max_features': 3, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.6229373829351187, 'min_samples_split': 0.7478716040922285}
# nan {'max_depth': 9, 'max_features': 4, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.8601268164179238, 'min_samples_split': 0.4574320977737073}
# nan {'max_depth': 3, 'max_features': 9, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.9556514982297534, 'min_samples_split': 0.8621276172654506}
# nan {'max_depth': 9, 'max_features': 15, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.9315894883189899, 'min_samples_split': 0.7352126545234527}
# -20.8568 {'max_depth': 2, 'max_features': 15, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.2597537837603262, 'min_samples_split': 0.7234201136885849}
# -20.9959 {'max_depth': 18, 'max_features': 6, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.22018320194981134, 'min_samples_split': 0.6832587636595959}
# -20.1230 {'max_depth': 5, 'max_features': 13, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.06151702623923505, 'min_samples_split': 0.8829062691374613}
# nan {'max_depth': 19, 'max_features': 3, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.6780161525590636, 'min_samples_split': 0.5657319639957911}
# nan {'max_depth': 13, 'max_features': 1, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.5212603121804149, 'min_samples_split': 0.8681608040515469}
# -20.8568 {'max_depth': 1, 'max_features': 16, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.3340088787452379, 'min_samples_split': 0.2386900313010175}
# -20.9959 {'max_depth': 10, 'max_features': 4, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.1892215397850059, 'min_samples_split': 0.8816371327703502}
# -18.4632 {'max_depth': 13, 'max_features': 19, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.1288698674734452, 'min_samples_split': 0.3351188542591419}
# nan {'max_depth': 7, 'max_features': 18, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.556181735039757, 'min_samples_split': 0.7566358037849347}
# -20.8186 {'max_depth': 12, 'max_features': 7, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.2870381331749128, 'min_samples_split': 0.6169269183757422}
# -18.1400 {'max_depth': 17, 'max_features': 9, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.11584385678025766, 'min_samples_split': 0.37669536198679876}
# -22.3849 {'max_depth': 13, 'max_features': 3, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.10698063882695841, 'min_samples_split': 0.761027902502028}
# -20.1230 {'max_depth': 10, 'max_features': 9, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.3418721660386861, 'min_samples_split': 0.6326218931339481}
# -19.1841 {'max_depth': 5, 'max_features': 4, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.0678370591051719, 'min_samples_split': 0.30096356694681625}
# nan {'max_depth': 17, 'max_features': 12, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.5821704601762733, 'min_samples_split': 0.34588305695295674}
# nan {'max_depth': 18, 'max_features': 18, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.9734889691773969, 'min_samples_split': 0.9688778552856915}
# -20.4107 {'max_depth': 4, 'max_features': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.02458691645880151, 'min_samples_split': 0.022123551528997254}
# nan {'max_depth': 6, 'max_features': 15, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.8187856433570937, 'min_samples_split': 0.2525087496883822}
# nan {'max_depth': 2, 'max_features': 14, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.9971245001577111, 'min_samples_split': 0.42618130223597295}
# nan {'max_depth': 13, 'max_features': 9, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.5270240962118621, 'min_samples_split': 0.8259207657998966}
# nan {'max_depth': 11, 'max_features': 20, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.7728227800168045, 'min_samples_split': 0.23005368303143392}
# nan {'max_depth': 11, 'max_features': 3, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.9632366534401319, 'min_samples_split': 0.03130231374751624}
# nan {'max_depth': 15, 'max_features': 16, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.6385259476640855, 'min_samples_split': 0.3975943979627943}
# -22.3849 {'max_depth': 5, 'max_features': 3, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.32074274043812745, 'min_samples_split': 0.724422672614117}
# nan {'max_depth': 2, 'max_features': 3, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.651666825375885, 'min_samples_split': 0.36852634372376114}
# nan {'max_depth': 15, 'max_features': 12, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.5432328057899581, 'min_samples_split': 0.15924573827926447}
# nan {'max_depth': 17, 'max_features': 21, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.770921844644052, 'min_samples_split': 0.8447832281168877}
# -22.3849 {'max_depth': 7, 'max_features': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.032526179491251916, 'min_samples_split': 0.9208478478156868}
# -20.5693 {'max_depth': 3, 'max_features': 20, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.46209729076566064, 'min_samples_split': 0.0012318351664258875}
# -19.8417 {'max_depth': 7, 'max_features': 17, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.24753995560337516, 'min_samples_split': 0.5584126725831979}
# nan {'max_depth': 16, 'max_features': 21, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.7975591006371882, 'min_samples_split': 0.31036195892357377}
# -20.6135 {'max_depth': 13, 'max_features': 17, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.46459859663581016, 'min_samples_split': 0.6804566263593252}
# nan {'max_depth': 18, 'max_features': 14, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.6000205481193037, 'min_samples_split': 0.29166257870930323}
# nan {'max_depth': 13, 'max_features': 1, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.9078186529846402, 'min_samples_split': 0.7242853081264119}
# -18.3209 {'max_depth': 19, 'max_features': 9, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.10279240449266569, 'min_samples_split': 0.5709045018441643}
# nan {'max_depth': 15, 'max_features': 16, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.5596486834869141, 'min_samples_split': 0.00977084741918366}
# -22.3035 {'max_depth': 1, 'max_features': 2, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.08786649914483335, 'min_samples_split': 0.35062693120918076}
# -20.1230 {'max_depth': 1, 'max_features': 13, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.13271575404306035, 'min_samples_split': 0.5675408482615582}
# -19.4978 {'max_depth': 14, 'max_features': 18, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.2001502442448101, 'min_samples_split': 0.16748258225906976}
# -20.1230 {'max_depth': 17, 'max_features': 8, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.12421996672805935, 'min_samples_split': 0.8962213026850383}
# -20.3337 {'max_depth': 9, 'max_features': 6, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.05197128365147241, 'min_samples_split': 0.5412963353010705}
# nan {'max_depth': 18, 'max_features': 12, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.9473504626310387, 'min_samples_split': 0.6253046602139478}
# nan {'max_depth': 15, 'max_features': 7, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.8948166560605276, 'min_samples_split': 0.5475923761537362}
# -21.4995 {'max_depth': 3, 'max_features': 9, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.4386072164895384, 'min_samples_split': 0.7248265598740583}
# -21.4662 {'max_depth': 12, 'max_features': 12, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.4792789285762873, 'min_samples_split': 0.6157420219422428}
# nan {'max_depth': 19, 'max_features': 14, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.7442790655949556, 'min_samples_split': 0.8718327789731212}
# -20.1230 {'max_depth': 19, 'max_features': 12, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.0208611392915381, 'min_samples_split': 0.6532630192373301}
# -18.3209 {'max_depth': 5, 'max_features': 9, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.0815264895524267, 'min_samples_split': 0.4032613611238318}
# -22.4459 {'max_depth': 15, 'max_features': 1, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.4626229567393163, 'min_samples_split': 0.8682725054083805}
# nan {'max_depth': 5, 'max_features': 4, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.7677238880667803, 'min_samples_split': 0.5048448818930178}
# -20.5878 {'max_depth': 18, 'max_features': 17, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.43861541918959046, 'min_samples_split': 0.7252576604151365}
# nan {'max_depth': 4, 'max_features': 2, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.9007018640112585, 'min_samples_split': 0.4217209268734554}
# -20.6272 {'max_depth': 10, 'max_features': 19, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.3838471518677963, 'min_samples_split': 0.4658128070202485}
# nan {'max_depth': 15, 'max_features': 1, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.7760002070354295, 'min_samples_split': 0.4053101830857434}
# nan {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.9713950940416396, 'min_samples_split': 0.18097695270948977}
# -21.1563 {'max_depth': 5, 'max_features': 6, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.43716538881682654, 'min_samples_split': 0.09739339255355217}
# -20.7654 {'max_depth': 15, 'max_features': 14, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.3592333693997657, 'min_samples_split': 0.5929508514349274}
# nan {'max_depth': 6, 'max_features': 17, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.8579862539227058, 'min_samples_split': 0.009030404129550251}
# -20.1230 {'max_depth': 1, 'max_features': 8, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.13087366071834983, 'min_samples_split': 0.9698210450785447}
# -18.8449 {'max_depth': 15, 'max_features': 11, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.07349674733001266, 'min_samples_split': 0.16975790508754074}
# nan {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.8288833658826095, 'min_samples_split': 0.43088752366180594}
# nan {'max_depth': 8, 'max_features': 11, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.7067772168854458, 'min_samples_split': 0.16704190790094986}
# nan {'max_depth': 11, 'max_features': 5, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.6638045276218051, 'min_samples_split': 0.4746308757498139}
# nan {'max_depth': 17, 'max_features': 12, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.8682712805132586, 'min_samples_split': 0.20584121003676825}
# -19.5990 {'max_depth': 18, 'max_features': 14, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.12297080852962672, 'min_samples_split': 0.2311309124276466}
# -22.3849 {'max_depth': 1, 'max_features': 3, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.1800104374727235, 'min_samples_split': 0.08855558422324139}
# nan {'max_depth': 1, 'max_features': 17, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.6882078658665954, 'min_samples_split': 0.397378988464401}
# -20.1230 {'max_depth': 18, 'max_features': 11, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.32313065707027855, 'min_samples_split': 0.9730977480703464}
# -20.5846 {'max_depth': 7, 'max_features': 15, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.4888465802569202, 'min_samples_split': 0.6668642575461043}
# nan {'max_depth': 13, 'max_features': 20, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.9398197919268417, 'min_samples_split': 0.7328989183413418}
# nan {'max_depth': 8, 'max_features': 18, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.7308294748708763, 'min_samples_split': 0.15616384479217393}
# -20.9959 {'max_depth': 6, 'max_features': 5, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.1771497894473859, 'min_samples_split': 0.6926259522261645}
# -20.1230 {'max_depth': 11, 'max_features': 10, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.24414729042237426, 'min_samples_split': 0.8308771913417055}
# -20.1230 {'max_depth': 15, 'max_features': 8, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.03038705969683686, 'min_samples_split': 0.9309486955069778}
# nan {'max_depth': 14, 'max_features': 4, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.6006095425462361, 'min_samples_split': 0.9408753563380648}
# nan {'max_depth': 14, 'max_features': 21, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.6512329770414921, 'min_samples_split': 0.10659303030799072}
# -20.8568 {'max_depth': 2, 'max_features': 18, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.3181115536181195, 'min_samples_split': 0.8664386675276454}
# -18.3642 {'max_depth': 16, 'max_features': 13, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.09048169528705075, 'min_samples_split': 0.2886855955306381}
# -21.0569 {'max_depth': 11, 'max_features': 4, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.404140321651033, 'min_samples_split': 0.3270331615632387}
# nan {'max_depth': 6, 'max_features': 19, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.9013756495884443, 'min_samples_split': 0.8778911590413275}
# ...
# nan {'max_depth': 2, 'max_features': 17, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.6448612228149799, 'min_samples_split': 0.02353249441409877}
# nan {'max_depth': 11, 'max_features': 1, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.5561906926300116, 'min_samples_split': 0.7795167014240635}
# -20.8568 {'max_depth': 15, 'max_features': 18, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.04013885908536652, 'min_samples_split': 0.8899133763628625}
# nan {'max_depth': 1, 'max_features': 15, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.791463540889519, 'min_samples_split': 0.6024698307034551}
# nan {'max_depth': 4, 'max_features': 12, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.9791515551006156, 'min_samples_split': 0.6738388982700046}
# -22.3849 {'max_depth': 13, 'max_features': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.15177540985110205, 'min_samples_split': 0.8895766183304922}
# -18.6228 {'max_depth': 2, 'max_features': 17, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.00540492367266987, 'min_samples_split': 0.0013462709565636999}
# -18.7202 {'max_depth': 6, 'max_features': 10, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.23333282264932664, 'min_samples_split': 0.6253301699544539}
# -18.4587 {'max_depth': 9, 'max_features': 10, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.05994330086130828, 'min_samples_split': 0.13097374299417408}
# nan {'max_depth': 18, 'max_features': 11, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.9969092185893553, 'min_samples_split': 0.18345240115022932}
# -19.5298 {'max_depth': 2, 'max_features': 12, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.1263864224056671, 'min_samples_split': 0.027843907577413396}
# -21.0237 {'max_depth': 10, 'max_features': 2, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.027852240821074403, 'min_samples_split': 0.631375326048251}
# -20.8568 {'max_depth': 1, 'max_features': 19, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.17464718589632955, 'min_samples_split': 0.2959320294366161}
# nan {'max_depth': 14, 'max_features': 2, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.8903843208552661, 'min_samples_split': 0.5768812013112085}
# nan {'max_depth': 7, 'max_features': 21, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.5466963282963399, 'min_samples_split': 0.8398203522034884}
# -22.3035 {'max_depth': 14, 'max_features': 2, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.1506874870008338, 'min_samples_split': 0.851594319304219}
# nan {'max_depth': 13, 'max_features': 4, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.784769681824988, 'min_samples_split': 0.9944152675588734}
# nan {'max_depth': 1, 'max_features': 13, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.6144857775116312, 'min_samples_split': 0.5811954237209566}
# nan {'max_depth': 13, 'max_features': 16, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.6618345851139982, 'min_samples_split': 0.633711599765529}
# nan {'max_depth': 14, 'max_features': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.7287780544506475, 'min_samples_split': 0.3235304124854915}
# -20.8568 {'max_depth': 13, 'max_features': 14, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.12627113710773186, 'min_samples_split': 0.8134344823242641}
# -21.3979 {'max_depth': 17, 'max_features': 9, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.49897111691376594, 'min_samples_split': 0.3182620413857259}
# nan {'max_depth': 8, 'max_features': 14, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.8912000730636024, 'min_samples_split': 0.013634023905821469}
# -19.8806 {'max_depth': 3, 'max_features': 17, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.01289746978952544, 'min_samples_split': 0.5402994067614997}
# nan {'max_depth': 8, 'max_features': 13, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.8987878897373477, 'min_samples_split': 0.5531119710583715}
# -21.3101 {'max_depth': 2, 'max_features': 13, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.3887263478765467, 'min_samples_split': 0.24029912345036675}
# -20.8568 {'max_depth': 1, 'max_features': 20, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.09664483428775228, 'min_samples_split': 0.17689695082398393}
# nan {'max_depth': 15, 'max_features': 11, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.9955689004906878, 'min_samples_split': 0.5827144493446815}
# -20.8568 {'max_depth': 1, 'max_features': 21, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.31830409469234733, 'min_samples_split': 0.48903577530762}
# -19.9245 {'max_depth': 6, 'max_features': 8, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.1332099241366287, 'min_samples_split': 0.6323962564655086}
# nan {'max_depth': 3, 'max_features': 5, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.693422128056309, 'min_samples_split': 0.7006114963944516}
# -21.5482 {'max_depth': 9, 'max_features': 7, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.42593770846693946, 'min_samples_split': 0.9946841651964872}
# nan {'max_depth': 13, 'max_features': 11, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.6737017335421565, 'min_samples_split': 0.7674988305907054}
# nan {'max_depth': 15, 'max_features': 21, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.8499593305032054, 'min_samples_split': 0.19624571670616564}
# -18.6125 {'max_depth': 8, 'max_features': 10, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.28226247041293284, 'min_samples_split': 0.29807565052482277}
# -18.3209 {'max_depth': 13, 'max_features': 9, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.10548342746103567, 'min_samples_split': 0.5855876838726125}
# nan {'max_depth': 14, 'max_features': 11, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.8200675020556494, 'min_samples_split': 0.041578959846593766}
# -19.9168 {'max_depth': 11, 'max_features': 19, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.2523119270696871, 'min_samples_split': 0.3077709052931491}
# nan {'max_depth': 10, 'max_features': 1, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.8099244203028994, 'min_samples_split': 0.5831302190995835}
# nan {'max_depth': 15, 'max_features': 7, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.9077354331775127, 'min_samples_split': 0.9965656562889824}
# -20.9959 {'max_depth': 12, 'max_features': 6, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.3373028364674864, 'min_samples_split': 0.9415768527339338}
# -20.8568 {'max_depth': 5, 'max_features': 14, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.05688139777764656, 'min_samples_split': 0.7665273162216272}
# nan {'max_depth': 4, 'max_features': 11, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.6761050258143518, 'min_samples_split': 0.3072389618477205}
# nan {'max_depth': 9, 'max_features': 13, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.5845431132594582, 'min_samples_split': 0.9693218122841789}
# -21.7169 {'max_depth': 19, 'max_features': 1, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.16605252148153637, 'min_samples_split': 0.06110466761963229}
# -22.3849 {'max_depth': 17, 'max_features': 3, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.1141399693096321, 'min_samples_split': 0.941048260038377}
# nan {'max_depth': 13, 'max_features': 15, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.8832736014262238, 'min_samples_split': 0.414825655521352}
# -20.6307 {'max_depth': 10, 'max_features': 15, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.4553831354806076, 'min_samples_split': 0.4149604360796805}
# -19.4983 {'max_depth': 7, 'max_features': 17, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.19763922059113015, 'min_samples_split': 0.1805182283924236}
# -20.6272 {'max_depth': 7, 'max_features': 16, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.40146177908904324, 'min_samples_split': 0.3380844093662614}
# -20.1230 {'max_depth': 1, 'max_features': 12, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.03808630059931928, 'min_samples_split': 0.6199685648741642}
# nan {'max_depth': 4, 'max_features': 1, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.5952297327194016, 'min_samples_split': 0.8719130612805055}
# nan {'max_depth': 3, 'max_features': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.5402788931874211, 'min_samples_split': 0.07928028463119174}
# nan {'max_depth': 14, 'max_features': 18, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.5583523150641136, 'min_samples_split': 0.869937832897689}
# nan {'max_depth': 4, 'max_features': 5, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.5236634160546108, 'min_samples_split': 0.31912348982046257}
# nan {'max_depth': 16, 'max_features': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.8284386709389908, 'min_samples_split': 0.08018675681211329}
# nan {'max_depth': 11, 'max_features': 2, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.9157882394541271, 'min_samples_split': 0.35979409354529945}
# -22.4810 {'max_depth': 7, 'max_features': 1, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.39413604678262815, 'min_samples_split': 0.6033341962120348}
# nan {'max_depth': 19, 'max_features': 5, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.5806452259096341, 'min_samples_split': 0.9359372482485595}
# nan {'max_depth': 10, 'max_features': 1, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.8096750362658893, 'min_samples_split': 0.9505328209544089}
# nan {'max_depth': 7, 'max_features': 9, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.8143867792687614, 'min_samples_split': 0.2803347525514125}
# -22.4210 {'max_depth': 15, 'max_features': 2, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.380951845023475, 'min_samples_split': 0.05456540828269896}
# -21.3764 {'max_depth': 3, 'max_features': 7, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.4593314408005428, 'min_samples_split': 0.7521286995435712}
# nan {'max_depth': 1, 'max_features': 12, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.8263408109501867, 'min_samples_split': 0.5880004634296284}
# nan {'max_depth': 17, 'max_features': 2, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.8259323085500162, 'min_samples_split': 0.6314587925830206}
# nan {'max_depth': 16, 'max_features': 14, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.6050895185405384, 'min_samples_split': 0.22048763941474925}
# nan {'max_depth': 17, 'max_features': 9, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.8196095530657999, 'min_samples_split': 0.8248537674871036}
# nan {'max_depth': 5, 'max_features': 10, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.5429981326052693, 'min_samples_split': 0.37380810886700244}
# -19.3747 {'max_depth': 7, 'max_features': 15, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.18445905105988336, 'min_samples_split': 0.20229394915820365}
# -22.3849 {'max_depth': 15, 'max_features': 3, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.38510260282302966, 'min_samples_split': 0.8548057787992615}
# -22.3144 {'max_depth': 19, 'max_features': 3, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.27061999469359665, 'min_samples_split': 0.19416286904608226}
# -20.4191 {'max_depth': 15, 'max_features': 4, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.07115567887790974, 'min_samples_split': 0.5738658496770963}
# -21.3532 {'max_depth': 13, 'max_features': 3, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.2018418353637581, 'min_samples_split': 0.2581039291604684}
# -18.3211 {'max_depth': 7, 'max_features': 15, 'max_leaf_nodes': 8, 'min_samples_leaf': 0.04406586157038139, 'min_samples_split': 0.18527685033354002}
# -20.9959 {'max_depth': 17, 'max_features': 5, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.0455851579486688, 'min_samples_split': 0.9459708898455993}
# -18.6912 {'max_depth': 14, 'max_features': 8, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.07718753022646796, 'min_samples_split': 0.16988707321905727}
# nan {'max_depth': 17, 'max_features': 14, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.6805581617791014, 'min_samples_split': 0.1660748523335137}
# nan {'max_depth': 11, 'max_features': 6, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.728786222256576, 'min_samples_split': 0.046972991098139794}
# -20.1230 {'max_depth': 13, 'max_features': 11, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.2859005337712024, 'min_samples_split': 0.6723898127987045}
# -20.6272 {'max_depth': 19, 'max_features': 15, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.4154430005920896, 'min_samples_split': 0.024005044844888856}
# nan {'max_depth': 1, 'max_features': 4, 'max_leaf_nodes': 15, 'min_samples_leaf': 0.9885399870457067, 'min_samples_split': 0.041428088819387754}
# nan {'max_depth': 8, 'max_features': 6, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.9631590270650665, 'min_samples_split': 0.11475359941383545}
# -18.3420 {'max_depth': 13, 'max_features': 13, 'max_leaf_nodes': 6, 'min_samples_leaf': 0.09696567096542474, 'min_samples_split': 0.1790316374415838}
# nan {'max_depth': 15, 'max_features': 18, 'max_leaf_nodes': 3, 'min_samples_leaf': 0.587697018287546, 'min_samples_split': 0.11236448194898563}
# -21.4100 {'max_depth': 15, 'max_features': 12, 'max_leaf_nodes': 16, 'min_samples_leaf': 0.43705152184218765, 'min_samples_split': 0.6277454148973364}
# -20.8568 {'max_depth': 11, 'max_features': 19, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.3249227944066413, 'min_samples_split': 0.6872955625825176}
# -21.4068 {'max_depth': 14, 'max_features': 13, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.48987047671774453, 'min_samples_split': 0.6307174444919292}
# nan {'max_depth': 11, 'max_features': 19, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.810468217215466, 'min_samples_split': 0.2726506473124847}
# nan {'max_depth': 1, 'max_features': 19, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.9571969635192346, 'min_samples_split': 0.890138053446914}
# nan {'max_depth': 3, 'max_features': 8, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.6757612928952238, 'min_samples_split': 0.618610289093939}
# -20.6272 {'max_depth': 16, 'max_features': 16, 'max_leaf_nodes': 4, 'min_samples_leaf': 0.3960009663856152, 'min_samples_split': 0.13300979890732878}
# -19.5331 {'max_depth': 12, 'max_features': 21, 'max_leaf_nodes': 9, 'min_samples_leaf': 0.12757017457137088, 'min_samples_split': 0.4090851486348762}
# nan {'max_depth': 6, 'max_features': 19, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.7007255212842638, 'min_samples_split': 0.5890200909809116}
# nan {'max_depth': 13, 'max_features': 11, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.575593428640082, 'min_samples_split': 0.16145783406424008}
# -20.1230 {'max_depth': 7, 'max_features': 13, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.2101071929123518, 'min_samples_split': 0.7422713922522868}
# -20.5088 {'max_depth': 8, 'max_features': 19, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.4730275033430207, 'min_samples_split': 0.04331527325431195}
# -21.3663 {'max_depth': 6, 'max_features': 9, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.4124030604678661, 'min_samples_split': 0.19575560640562462}
# -20.5909 {'max_depth': 8, 'max_features': 16, 'max_leaf_nodes': 14, 'min_samples_leaf': 0.488177675310814, 'min_samples_split': 0.1331821256675234}
# nan {'max_depth': 5, 'max_features': 21, 'max_leaf_nodes': 18, 'min_samples_leaf': 0.694017414105742, 'min_samples_split': 0.1827511659874359}
# nan {'max_depth': 18, 'max_features': 9, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.9080150893749742, 'min_samples_split': 0.24257826607382516}
# nan {'max_depth': 6, 'max_features': 13, 'max_leaf_nodes': 12, 'min_samples_leaf': 0.5848278113057909, 'min_samples_split': 0.9414742375060654}
# nan {'max_depth': 3, 'max_features': 1, 'max_leaf_nodes': 19, 'min_samples_leaf': 0.7144141014704978, 'min_samples_split': 0.3616470948410445}
# -22.3849 {'max_depth': 13, 'max_features': 3, 'max_leaf_nodes': 2, 'min_samples_leaf': 0.19629430231106704, 'min_samples_split': 0.022564511705347234}
# nan {'max_depth': 11, 'max_features': 2, 'max_leaf_nodes': 17, 'min_samples_leaf': 0.5969452234131726, 'min_samples_split': 0.8101610899597025}
# nan {'max_depth': 19, 'max_features': 16, 'max_leaf_nodes': 10, 'min_samples_leaf': 0.5721229637222063, 'min_samples_split': 0.18078515056237954}
# nan {'max_depth': 2, 'max_features': 16, 'max_leaf_nodes': 13, 'min_samples_leaf': 0.7906911019001679, 'min_samples_split': 0.38473257650744497}
# nan {'max_depth': 13, 'max_features': 6, 'max_leaf_nodes': 7, 'min_samples_leaf': 0.6154207798208354, 'min_samples_split': 0.08157492561136592}
# nan {'max_depth': 7, 'max_features': 10, 'max_leaf_nodes': 11, 'min_samples_leaf': 0.5180774980403448, 'min_samples_split': 0.21399467869831357}
# nan {'max_depth': 9, 'max_features': 15, 'max_leaf_nodes': 5, 'min_samples_leaf': 0.6493788202366224, 'min_samples_split': 0.6688765310406853}

# %%
"{:.4f}".format(-rnd_search_dt.best_score_)
# Out:
# '18.0402'

# %%
# best tuned hyperparameter values
rnd_search_dt.best_params_
# Out:
# {'max_depth': 7,
#  'max_features': 9,
#  'max_leaf_nodes': 18,
#  'min_samples_leaf': 0.01582109176558244,
#  'min_samples_split': 0.34109002447422054}

# %%
best_dt = rnd_search_dt.best_estimator_

# %%
# evaluate random search
val_pred = best_dt.predict(val_feature_scaled)

print("Mean Absolute Error for Decision Tree: ", "{:.4f}".format(mean_absolute_error(val_label, val_pred)))
# Out:
# Mean Absolute Error for Decision Tree:  18.9735

# %%
# plot feature importance
import matplotlib
import matplotlib.pyplot as plt

features = tr_feature_scaled.columns
importances = best_dt.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(10,15))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()
export_graphviz(best_dt, out_file=dot_data,  
                feature_names=tr_feature_scaled.columns,
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %% [markdown]
# ## Predit Test Data Using Best Hyperparameter Model

# %%
# predict on test data
te_pred = best_dt.predict(te_feature_scaled)

# %%
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)

# %%
submission
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18           14
# 1     sj  2008          19           14
# 2     sj  2008          20            9
# 3     sj  2008          21            9
# 4     sj  2008          22           14
# 5     sj  2008          23           14
# 6     sj  2008          24           14
# 7     sj  2008          25            9
# 8     sj  2008          26           14
# 9     sj  2008          27           14
# 10    sj  2008          28           14
# 11    sj  2008          29           14
# 12    sj  2008          30           14
# 13    sj  2008          31           14
# 14    sj  2008          32           52
# 15    sj  2008          33           57
# 16    sj  2008          34           57
# 17    sj  2008          35           57
# 18    sj  2008          36           57
# 19    sj  2008          37           57
# 20    sj  2008          38           57
# 21    sj  2008          39           57
# 22    sj  2008          40           57
# 23    sj  2008          41           57
# 24    sj  2008          42           57
# 25    sj  2008          43           57
# 26    sj  2008          44           57
# 27    sj  2008          45           57
# 28    sj  2008          46           57
# 29    sj  2008          47           57
# 30    sj  2008          48           57
# 31    sj  2008          49           57
# 32    sj  2008          50           57
# 33    sj  2008          51           57
# 34    sj  2008          52           57
# 35    sj  2009           1            9
# 36    sj  2009           2           27
# 37    sj  2009           3           27
# 38    sj  2009           4           27
# 39    sj  2009           5           27
# 40    sj  2009           6           27
# 41    sj  2009           7           27
# 42    sj  2009           8           14
# 43    sj  2009           9           14
# 44    sj  2009          10           14
# 45    sj  2009          11           14
# 46    sj  2009          12           14
# 47    sj  2009          13            9
# 48    sj  2009          14           14
# 49    sj  2009          15           14
# 50    sj  2009          16           14
# 51    sj  2009          17           14
# 52    sj  2009          18           14
# 53    sj  2009          19           14
# 54    sj  2009          20           14
# 55    sj  2009          21           14
# 56    sj  2009          22           14
# 57    sj  2009          23           14
# 58    sj  2009          24           14
# 59    sj  2009          25           14
# 60    sj  2009          26           14
# 61    sj  2009          27            9
# 62    sj  2009          28           14
# 63    sj  2009          29           14
# 64    sj  2009          30           14
# 65    sj  2009          31           14
# 66    sj  2009          32           14
# 67    sj  2009          33           57
# 68    sj  2009          34           57
# 69    sj  2009          35           57
# 70    sj  2009          36           57
# 71    sj  2009          37           57
# 72    sj  2009          38           57
# 73    sj  2009          39           57
# 74    sj  2009          40           57
# 75    sj  2009          41           57
# 76    sj  2009          42           57
# 77    sj  2009          43           57
# 78    sj  2009          44           57
# 79    sj  2009          45           57
# 80    sj  2009          46           57
# 81    sj  2009          47           57
# 82    sj  2009          48           57
# 83    sj  2009          49           57
# 84    sj  2009          50           57
# 85    sj  2009          51           57
# 86    sj  2009          52           57
# 87    sj  2010          53            9
# 88    sj  2010           1           27
# 89    sj  2010           2           27
# 90    sj  2010           3           27
# 91    sj  2010           4           27
# 92    sj  2010           5           27
# 93    sj  2010           6            9
# 94    sj  2010           7            9
# 95    sj  2010           8           14
# 96    sj  2010           9            9
# 97    sj  2010          10           14
# 98    sj  2010          11           14
# 99    sj  2010          12           14
# 100   sj  2010          13           14
# 101   sj  2010          14           14
# 102   sj  2010          15           14
# 103   sj  2010          16           14
# 104   sj  2010          17           14
# 105   sj  2010          18           14
# 106   sj  2010          19           14
# 107   sj  2010          20           14
# 108   sj  2010          21           14
# 109   sj  2010          22           52
# 110   sj  2010          23           52
# 111   sj  2010          24           52
# 112   sj  2010          25           52
# 113   sj  2010          26           52
# 114   sj  2010          27           52
# 115   sj  2010          28           52
# 116   sj  2010          29           52
# 117   sj  2010          30           52
# 118   sj  2010          31           52
# 119   sj  2010          32           52
# 120   sj  2010          33           57
# 121   sj  2010          34           57
# 122   sj  2010          35           57
# 123   sj  2010          36           57
# 124   sj  2010          37           57
# 125   sj  2010          38           57
# 126   sj  2010          39           57
# 127   sj  2010          40           57
# 128   sj  2010          41           57
# 129   sj  2010          42           57
# 130   sj  2010          43           57
# 131   sj  2010          44           57
# 132   sj  2010          45           57
# 133   sj  2010          46           57
# 134   sj  2010          47           57
# 135   sj  2010          48           57
# 136   sj  2010          49           57
# 137   sj  2010          50           57
# 138   sj  2010          51           57
# 139   sj  2011          52           57
# 140   sj  2011           1           27
# 141   sj  2011           2           27
# 142   sj  2011           3           27
# 143   sj  2011           4           27
# 144   sj  2011           5           27
# 145   sj  2011           6           27
# 146   sj  2011           7           27
# 147   sj  2011           8           14
# 148   sj  2011           9           14
# 149   sj  2011          10           14
# 150   sj  2011          11           14
# 151   sj  2011          12           14
# 152   sj  2011          13           14
# 153   sj  2011          14           14
# 154   sj  2011          15           14
# 155   sj  2011          16           14
# 156   sj  2011          17           14
# 157   sj  2011          18           14
# 158   sj  2011          19           14
# 159   sj  2011          20           14
# 160   sj  2011          21           14
# 161   sj  2011          22           14
# 162   sj  2011          23           14
# 163   sj  2011          24           52
# 164   sj  2011          25           52
# 165   sj  2011          26           52
# 166   sj  2011          27           52
# 167   sj  2011          28           52
# 168   sj  2011          29           14
# 169   sj  2011          30           52
# 170   sj  2011          31           52
# 171   sj  2011          32           52
# 172   sj  2011          33           57
# 173   sj  2011          34           57
# 174   sj  2011          35           57
# 175   sj  2011          36           57
# 176   sj  2011          37           57
# 177   sj  2011          38           57
# 178   sj  2011          39           57
# 179   sj  2011          40           57
# 180   sj  2011          41           57
# 181   sj  2011          42           57
# 182   sj  2011          43           57
# 183   sj  2011          44           57
# 184   sj  2011          45           57
# 185   sj  2011          46           57
# 186   sj  2011          47           57
# 187   sj  2011          48           57
# 188   sj  2011          49           57
# 189   sj  2011          50           57
# 190   sj  2011          51           57
# 191   sj  2012          52           57
# 192   sj  2012           1           27
# 193   sj  2012           2           27
# 194   sj  2012           3           27
# 195   sj  2012           4           27
# 196   sj  2012           5           27
# 197   sj  2012           6           27
# 198   sj  2012           7           27
# 199   sj  2012           8           14
# 200   sj  2012           9           14
# 201   sj  2012          10           14
# 202   sj  2012          11           14
# 203   sj  2012          12           14
# 204   sj  2012          13           14
# 205   sj  2012          14           14
# 206   sj  2012          15           14
# 207   sj  2012          16           14
# 208   sj  2012          17           14
# 209   sj  2012          18           14
# 210   sj  2012          19           14
# 211   sj  2012          20           14
# 212   sj  2012          21           14
# 213   sj  2012          22           14
# 214   sj  2012          23           14
# 215   sj  2012          24           14
# 216   sj  2012          25           14
# 217   sj  2012          26           14
# 218   sj  2012          27           14
# 219   sj  2012          28           14
# 220   sj  2012          29           14
# 221   sj  2012          30           52
# 222   sj  2012          31           14
# 223   sj  2012          32           52
# 224   sj  2012          33           57
# 225   sj  2012          34           57
# 226   sj  2012          35           57
# 227   sj  2012          36           57
# 228   sj  2012          37           57
# 229   sj  2012          38           57
# 230   sj  2012          39           57
# 231   sj  2012          40           57
# 232   sj  2012          41           57
# 233   sj  2012          42           57
# 234   sj  2012          43           57
# 235   sj  2012          44           57
# 236   sj  2012          45           57
# 237   sj  2012          46           57
# 238   sj  2012          47           57
# 239   sj  2012          48           57
# 240   sj  2012          49           57
# 241   sj  2012          50           57
# 242   sj  2012          51           57
# 243   sj  2013           1           27
# 244   sj  2013           2           27
# 245   sj  2013           3           27
# 246   sj  2013           4           27
# 247   sj  2013           5           27
# 248   sj  2013           6           27
# 249   sj  2013           7           27
# 250   sj  2013           8           14
# 251   sj  2013           9           14
# 252   sj  2013          10           14
# 253   sj  2013          11           14
# 254   sj  2013          12           14
# 255   sj  2013          13           14
# 256   sj  2013          14           14
# 257   sj  2013          15           14
# 258   sj  2013          16           14
# 259   sj  2013          17           14
# 260   iq  2010          26            9
# 261   iq  2010          27            4
# 262   iq  2010          28            4
# 263   iq  2010          29            4
# 264   iq  2010          30            4
# 265   iq  2010          31            9
# 266   iq  2010          32            4
# 267   iq  2010          33            9
# 268   iq  2010          34            4
# 269   iq  2010          35            9
# 270   iq  2010          36            9
# 271   iq  2010          37            9
# 272   iq  2010          38            9
# 273   iq  2010          39            9
# 274   iq  2010          40            9
# 275   iq  2010          41            9
# 276   iq  2010          42            9
# 277   iq  2010          43            9
# 278   iq  2010          44            9
# 279   iq  2010          45            4
# 280   iq  2010          46            9
# 281   iq  2010          47            9
# 282   iq  2010          48            9
# 283   iq  2010          49            9
# 284   iq  2010          50            9
# 285   iq  2010          51            9
# 286   iq  2011          52            9
# 287   iq  2011           1            9
# 288   iq  2011           2            9
# 289   iq  2011           3            4
# 290   iq  2011           4            9
# 291   iq  2011           5            4
# 292   iq  2011           6            4
# 293   iq  2011           7            9
# 294   iq  2011           8            4
# 295   iq  2011           9            9
# 296   iq  2011          10            9
# 297   iq  2011          11            9
# 298   iq  2011          12            9
# 299   iq  2011          13            9
# 300   iq  2011          14            9
# 301   iq  2011          15            9
# 302   iq  2011          16            9
# 303   iq  2011          17            9
# 304   iq  2011          18            9
# 305   iq  2011          19            4
# 306   iq  2011          20            4
# 307   iq  2011          21            4
# 308   iq  2011          22            9
# 309   iq  2011          23            4
# 310   iq  2011          24            4
# 311   iq  2011          25            4
# 312   iq  2011          26            4
# 313   iq  2011          27            4
# 314   iq  2011          28            4
# 315   iq  2011          29            4
# 316   iq  2011          30            4
# 317   iq  2011          31            4
# 318   iq  2011          32            4
# 319   iq  2011          33            4
# 320   iq  2011          34            4
# 321   iq  2011          35            4
# 322   iq  2011          36            4
# 323   iq  2011          37            4
# 324   iq  2011          38            4
# 325   iq  2011          39            4
# 326   iq  2011          40            4
# 327   iq  2011          41            9
# 328   iq  2011          42            9
# 329   iq  2011          43            4
# 330   iq  2011          44            4
# 331   iq  2011          45            9
# 332   iq  2011          46            9
# 333   iq  2011          47            9
# 334   iq  2011          48            9
# 335   iq  2011          49            9
# 336   iq  2011          50            9
# 337   iq  2011          51            9
# 338   iq  2012          52            9
# 339   iq  2012           1            9
# 340   iq  2012           2            9
# 341   iq  2012           3            9
# 342   iq  2012           4            4
# 343   iq  2012           5            4
# 344   iq  2012           6            9
# 345   iq  2012           7            9
# 346   iq  2012           8            9
# 347   iq  2012           9            4
# 348   iq  2012          10            9
# 349   iq  2012          11            4
# 350   iq  2012          12            4
# 351   iq  2012          13            9
# 352   iq  2012          14            4
# 353   iq  2012          15            9
# 354   iq  2012          16            9
# 355   iq  2012          17            4
# 356   iq  2012          18            9
# 357   iq  2012          19            4
# 358   iq  2012          20            4
# 359   iq  2012          21            4
# 360   iq  2012          22            4
# 361   iq  2012          23            4
# 362   iq  2012          24            4
# 363   iq  2012          25            4
# 364   iq  2012          26            4
# 365   iq  2012          27            4
# 366   iq  2012          28            4
# 367   iq  2012          29            4
# 368   iq  2012          30            4
# 369   iq  2012          31            4
# 370   iq  2012          32            4
# 371   iq  2012          33            4
# 372   iq  2012          34            4
# 373   iq  2012          35            4
# 374   iq  2012          36            4
# 375   iq  2012          37            4
# 376   iq  2012          38            9
# 377   iq  2012          39            9
# 378   iq  2012          40            4
# 379   iq  2012          41            9
# 380   iq  2012          42            9
# 381   iq  2012          43            9
# 382   iq  2012          44            9
# 383   iq  2012          45            9
# 384   iq  2012          46            9
# 385   iq  2012          47            9
# 386   iq  2012          48            9
# 387   iq  2012          49            9
# 388   iq  2012          50            9
# 389   iq  2012          51            9
# 390   iq  2013           1            9
# 391   iq  2013           2            9
# 392   iq  2013           3            9
# 393   iq  2013           4            9
# 394   iq  2013           5            9
# 395   iq  2013           6            9
# 396   iq  2013           7            9
# 397   iq  2013           8            9
# 398   iq  2013           9            9
# 399   iq  2013          10            9
# 400   iq  2013          11            9
# 401   iq  2013          12            9
# 402   iq  2013          13            9
# 403   iq  2013          14            9
# 404   iq  2013          15            9
# 405   iq  2013          16            9
# 406   iq  2013          17            9
# 407   iq  2013          18            4
# 408   iq  2013          19            9
# 409   iq  2013          20            9
# 410   iq  2013          21            4
# 411   iq  2013          22            9
# 412   iq  2013          23            4
# 413   iq  2013          24            4
# 414   iq  2013          25            4
# 415   iq  2013          26            4

# %%
upload = './My Drive/ML Term Project/Submission CSV/submission_decisiontree.csv'
submission.to_csv(upload, index = False)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Fit a Random Forest with Default Parameters

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())

# %%
rf_reg = RandomForestRegressor(random_state=42)

# fit the decision tree regressor onto training data
rf_reg.fit(tr_feature_scaled, tr_label)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
# plot feature importance
import matplotlib
import matplotlib.pyplot as plt

features = tr_feature_scaled.columns
importances = rf_reg.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(10,15))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# predict on val data
val_pred = rf_reg.predict(val_feature_scaled)

# %%
# mean absolue error of the val data
mean_absolute_error(val_label, val_pred)
# Out:
# 18.652350230414743

# %%
# cross-validation
rf_cv_score = cross_val_score(rf_reg, tr_feature_scaled, tr_label, cv=20, scoring='neg_mean_absolute_error')

# %%
rf_mae_scores = -rf_cv_score
display_scores(rf_mae_scores)
# Out:
# Scores: [15.38176471 11.8554902  28.36137255 15.28058824 16.18117647 21.87823529
#  21.73333333 20.87431373 17.30803922 24.69372549 16.79333333 19.8372549
#  15.1748     13.6376     21.8172     12.696      16.1882     18.0878
#  16.0742     13.265     ]
# Mean: 17.855971372549018

# %% [markdown]
# ## Hyperparameters Tuning

# %%
# random search to fine tune hyperparameters
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from scipy.stats import uniform
from time import time

# set parameter range 
param_distribs = {
    'n_estimators': randint(low=2, high=1000),
    'criterion': ['mae'],
    'max_depth': randint(low=2, high=100),
    'min_samples_split': randint(low=2, high=500),
    'min_samples_leaf': randint(low=2, high=300),
    'max_features': ['auto', 'sqrt', 'log2', None],
    'bootstrap': [True, False],
}

# %%
rf_reg = RandomForestRegressor(random_state=42)
rnd_search_rf = RandomizedSearchCV(rf_reg, param_distributions=param_distribs, n_jobs=-1,
                                   n_iter=100, cv=5, scoring='neg_mean_absolute_error', random_state=42)

start = time()
rnd_search_rf.fit(tr_feature_scaled, tr_label)
print("RandomizedSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(rnd_search_rf.cv_results_['params'])))
# Out:
# RandomizedSearchCV took 2832.00 seconds for 100 candidate parameter settings.

# %%
# display the score of each hyperparameter combination tested during the random search
cvres = rnd_search_rf.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print("{:.4f}".format(mean_score), params)
# Out:
# -19.4771 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 53, 'max_features': 'auto', 'min_samples_leaf': 272, 'min_samples_split': 108, 'n_estimators': 73}
# -17.7699 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 22, 'max_features': 'log2', 'min_samples_leaf': 123, 'min_samples_split': 468, 'n_estimators': 216}
# -17.6164 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 76, 'max_features': None, 'min_samples_leaf': 101, 'min_samples_split': 361, 'n_estimators': 665}
# -18.8514 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 23, 'max_features': 'auto', 'min_samples_leaf': 259, 'min_samples_split': 345, 'n_estimators': 493}
# -17.2480 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 39, 'max_features': 'sqrt', 'min_samples_leaf': 193, 'min_samples_split': 445, 'n_estimators': 278}
# -17.0632 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 77, 'max_features': 'sqrt', 'min_samples_leaf': 23, 'min_samples_split': 254, 'n_estimators': 749}
# -16.8622 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 50, 'max_features': 'log2', 'min_samples_leaf': 60, 'min_samples_split': 171, 'n_estimators': 477}
# -17.2734 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 81, 'max_features': 'log2', 'min_samples_leaf': 191, 'min_samples_split': 447, 'n_estimators': 688}
# -16.1547 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 52, 'max_features': None, 'min_samples_leaf': 56, 'min_samples_split': 245, 'n_estimators': 833}
# -16.3685 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 136, 'min_samples_split': 22, 'n_estimators': 842}
# -16.3428 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 19, 'max_features': None, 'min_samples_leaf': 90, 'min_samples_split': 317, 'n_estimators': 15}
# -17.1785 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 54, 'min_samples_split': 387, 'n_estimators': 341}
# -17.8565 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 61, 'max_features': 'log2', 'min_samples_leaf': 265, 'min_samples_split': 432, 'n_estimators': 36}
# -16.3534 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 82, 'max_features': None, 'min_samples_leaf': 51, 'min_samples_split': 361, 'n_estimators': 389}
# -16.8906 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 107, 'min_samples_split': 261, 'n_estimators': 823}
# -17.9516 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 64, 'max_features': 'sqrt', 'min_samples_leaf': 219, 'min_samples_split': 45, 'n_estimators': 163}
# -17.6691 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 63, 'max_features': None, 'min_samples_leaf': 271, 'min_samples_split': 352, 'n_estimators': 817}
# -17.9407 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 73, 'max_features': 'sqrt', 'min_samples_leaf': 216, 'min_samples_split': 253, 'n_estimators': 703}
# -16.5751 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 86, 'max_features': None, 'min_samples_leaf': 238, 'min_samples_split': 339, 'n_estimators': 880}
# -17.9511 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 25, 'max_features': 'sqrt', 'min_samples_leaf': 218, 'min_samples_split': 253, 'n_estimators': 189}
# -16.3274 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 42, 'max_features': 'auto', 'min_samples_leaf': 16, 'min_samples_split': 302, 'n_estimators': 66}
# -17.6225 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 72, 'max_features': 'auto', 'min_samples_leaf': 130, 'min_samples_split': 493, 'n_estimators': 649}
# -17.1891 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 64, 'max_features': 'log2', 'min_samples_leaf': 82, 'min_samples_split': 393, 'n_estimators': 676}
# -19.3809 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 34, 'max_features': 'log2', 'min_samples_leaf': 262, 'min_samples_split': 491, 'n_estimators': 232}
# -16.0806 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 42, 'max_features': None, 'min_samples_leaf': 136, 'min_samples_split': 202, 'n_estimators': 841}
# -16.3534 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 35, 'max_features': 'auto', 'min_samples_leaf': 49, 'min_samples_split': 408, 'n_estimators': 575}
# -17.2326 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 38, 'max_features': 'log2', 'min_samples_leaf': 173, 'min_samples_split': 361, 'n_estimators': 727}
# -17.7765 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 36, 'max_features': 'auto', 'min_samples_leaf': 228, 'min_samples_split': 102, 'n_estimators': 944}
# -16.1861 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 219, 'n_estimators': 504}
# -19.4751 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 284, 'min_samples_split': 394, 'n_estimators': 208}
# -17.8126 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 91, 'max_features': 'sqrt', 'min_samples_leaf': 180, 'min_samples_split': 64, 'n_estimators': 865}
# -17.6200 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 53, 'max_features': 'auto', 'min_samples_leaf': 97, 'min_samples_split': 389, 'n_estimators': 735}
# -18.0042 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 24, 'max_features': 'log2', 'min_samples_leaf': 238, 'min_samples_split': 144, 'n_estimators': 172}
# -17.1000 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 37, 'max_features': 'auto', 'min_samples_leaf': 161, 'min_samples_split': 328, 'n_estimators': 700}
# -15.9989 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 87, 'max_features': None, 'min_samples_leaf': 67, 'min_samples_split': 171, 'n_estimators': 558}
# -16.0846 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 58, 'max_features': 'auto', 'min_samples_leaf': 135, 'min_samples_split': 285, 'n_estimators': 29}
# -17.6691 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 45, 'max_features': None, 'min_samples_leaf': 287, 'min_samples_split': 447, 'n_estimators': 332}
# -16.5573 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 93, 'max_features': 'auto', 'min_samples_leaf': 232, 'min_samples_split': 191, 'n_estimators': 226}
# -17.2286 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 28, 'max_features': 'sqrt', 'min_samples_leaf': 122, 'min_samples_split': 117, 'n_estimators': 974}
# -17.8876 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 199, 'min_samples_split': 457, 'n_estimators': 412}
# -17.7729 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 63, 'max_features': 'auto', 'min_samples_leaf': 226, 'min_samples_split': 308, 'n_estimators': 235}
# -17.1703 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 25, 'max_features': 'log2', 'min_samples_leaf': 161, 'min_samples_split': 97, 'n_estimators': 473}
# -16.2499 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 53, 'max_features': 'auto', 'min_samples_leaf': 53, 'min_samples_split': 269, 'n_estimators': 511}
# -17.1847 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 114, 'min_samples_split': 102, 'n_estimators': 626}
# -16.8302 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 82, 'max_features': 'log2', 'min_samples_leaf': 114, 'min_samples_split': 3, 'n_estimators': 643}
# -17.3149 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 55, 'max_features': 'log2', 'min_samples_leaf': 225, 'min_samples_split': 226, 'n_estimators': 386}
# -17.6068 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 173, 'min_samples_split': 219, 'n_estimators': 673}
# -17.2397 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 33, 'max_features': 'log2', 'min_samples_leaf': 204, 'min_samples_split': 185, 'n_estimators': 124}
# -16.1943 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 39, 'max_features': None, 'min_samples_leaf': 99, 'min_samples_split': 199, 'n_estimators': 983}
# -17.6803 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 17, 'max_features': 'auto', 'min_samples_leaf': 202, 'min_samples_split': 125, 'n_estimators': 188}
# -17.4285 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 81, 'max_features': 'auto', 'min_samples_leaf': 260, 'min_samples_split': 149, 'n_estimators': 765}
# -17.3594 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 37, 'max_features': 'log2', 'min_samples_leaf': 148, 'min_samples_split': 149, 'n_estimators': 865}
# -16.3062 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 53, 'max_features': 'auto', 'min_samples_leaf': 129, 'min_samples_split': 40, 'n_estimators': 339}
# -17.2608 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 152, 'min_samples_split': 416, 'n_estimators': 991}
# -16.3534 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 145, 'min_samples_split': 347, 'n_estimators': 625}
# -17.6188 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 61, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 386, 'n_estimators': 305}
# -16.1880 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 13, 'max_features': 'auto', 'min_samples_leaf': 38, 'min_samples_split': 161, 'n_estimators': 10}
# -17.7113 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 209, 'min_samples_split': 132, 'n_estimators': 405}
# -16.3534 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 55, 'max_features': None, 'min_samples_leaf': 162, 'min_samples_split': 409, 'n_estimators': 629}
# -17.4751 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 73, 'max_features': None, 'min_samples_leaf': 105, 'min_samples_split': 341, 'n_estimators': 255}
# -17.7308 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 90, 'max_features': 'log2', 'min_samples_leaf': 154, 'min_samples_split': 350, 'n_estimators': 915}
# -17.1657 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 83, 'max_features': 'sqrt', 'min_samples_leaf': 164, 'min_samples_split': 209, 'n_estimators': 958}
# -19.4740 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 34, 'max_features': None, 'min_samples_leaf': 290, 'min_samples_split': 399, 'n_estimators': 278}
# -16.0806 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 21, 'max_features': None, 'min_samples_leaf': 136, 'min_samples_split': 196, 'n_estimators': 402}
# -16.1764 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 34, 'max_features': None, 'min_samples_leaf': 23, 'min_samples_split': 239, 'n_estimators': 671}
# -17.8749 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 52, 'max_features': 'sqrt', 'min_samples_leaf': 265, 'min_samples_split': 284, 'n_estimators': 28}
# -16.9272 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 22, 'max_features': 'sqrt', 'min_samples_leaf': 98, 'min_samples_split': 285, 'n_estimators': 880}
# -16.3312 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 98, 'max_features': 'auto', 'min_samples_leaf': 148, 'min_samples_split': 5, 'n_estimators': 548}
# -16.6958 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 50, 'max_features': None, 'min_samples_leaf': 18, 'min_samples_split': 173, 'n_estimators': 221}
# -16.2765 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 94, 'max_features': 'sqrt', 'min_samples_leaf': 7, 'min_samples_split': 100, 'n_estimators': 893}
# -17.6166 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 38, 'max_features': None, 'min_samples_leaf': 182, 'min_samples_split': 96, 'n_estimators': 100}
# -16.2962 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 98, 'max_features': None, 'min_samples_leaf': 192, 'min_samples_split': 254, 'n_estimators': 982}
# -17.0218 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 88, 'max_features': 'auto', 'min_samples_leaf': 257, 'min_samples_split': 324, 'n_estimators': 129}
# -17.3187 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 26, 'max_features': 'sqrt', 'min_samples_leaf': 224, 'min_samples_split': 55, 'n_estimators': 571}
# -16.2641 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 47, 'max_features': None, 'min_samples_leaf': 115, 'min_samples_split': 289, 'n_estimators': 944}
# -16.9437 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 24, 'max_features': 'sqrt', 'min_samples_leaf': 128, 'min_samples_split': 156, 'n_estimators': 491}
# -16.3534 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 91, 'max_features': 'auto', 'min_samples_leaf': 105, 'min_samples_split': 418, 'n_estimators': 394}
# -17.7508 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 49, 'max_features': 'log2', 'min_samples_leaf': 171, 'min_samples_split': 248, 'n_estimators': 539}
# -16.4065 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 51, 'max_features': 'auto', 'min_samples_leaf': 14, 'min_samples_split': 317, 'n_estimators': 507}
# -17.6123 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 58, 'max_features': None, 'min_samples_leaf': 174, 'min_samples_split': 21, 'n_estimators': 322}
# -17.0294 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 144, 'min_samples_split': 93, 'n_estimators': 355}
# -16.4415 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 33, 'max_features': 'log2', 'min_samples_leaf': 52, 'min_samples_split': 154, 'n_estimators': 699}
# -16.6309 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 63, 'max_features': 'auto', 'min_samples_leaf': 151, 'min_samples_split': 315, 'n_estimators': 571}
# -16.3534 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 50, 'max_features': None, 'min_samples_leaf': 171, 'min_samples_split': 327, 'n_estimators': 784}
# -17.6691 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 61, 'max_features': 'auto', 'min_samples_leaf': 265, 'min_samples_split': 54, 'n_estimators': 573}
# -17.2708 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 6, 'max_features': 'log2', 'min_samples_leaf': 197, 'min_samples_split': 263, 'n_estimators': 878}
# -17.0501 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 95, 'max_features': 'log2', 'min_samples_leaf': 145, 'min_samples_split': 270, 'n_estimators': 371}
# -17.0376 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 31, 'max_features': 'log2', 'min_samples_leaf': 146, 'min_samples_split': 121, 'n_estimators': 832}
# -17.9872 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 93, 'max_features': 'sqrt', 'min_samples_leaf': 230, 'min_samples_split': 475, 'n_estimators': 118}
# -16.9253 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 24, 'max_features': 'log2', 'min_samples_leaf': 130, 'min_samples_split': 59, 'n_estimators': 635}
# -16.2964 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 35, 'max_features': None, 'min_samples_leaf': 127, 'min_samples_split': 119, 'n_estimators': 561}
# -17.6489 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 190, 'min_samples_split': 488, 'n_estimators': 705}
# -18.1961 {'bootstrap': True, 'criterion': 'mae', 'max_depth': 70, 'max_features': 'sqrt', 'min_samples_leaf': 248, 'min_samples_split': 452, 'n_estimators': 77}
# -16.6863 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 17, 'max_features': 'log2', 'min_samples_leaf': 87, 'min_samples_split': 186, 'n_estimators': 286}
# -16.3534 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 93, 'max_features': 'auto', 'min_samples_leaf': 48, 'min_samples_split': 498, 'n_estimators': 95}
# -16.3303 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 63, 'max_features': None, 'min_samples_leaf': 205, 'min_samples_split': 401, 'n_estimators': 219}
# -16.4986 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 49, 'max_features': 'auto', 'min_samples_leaf': 40, 'min_samples_split': 101, 'n_estimators': 290}
# -16.1479 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 95, 'max_features': 'auto', 'min_samples_leaf': 24, 'min_samples_split': 251, 'n_estimators': 523}
# -17.6691 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 70, 'max_features': None, 'min_samples_leaf': 291, 'min_samples_split': 181, 'n_estimators': 224}
# -16.8862 {'bootstrap': False, 'criterion': 'mae', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 97, 'min_samples_split': 258, 'n_estimators': 326}

# %%
"{:.4f}".format(-rnd_search_rf.best_score_)
# Out:
# '15.9989'

# %%
# best tuned hyperparameter values
rnd_search_rf.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'mae',
#  'max_depth': 87,
#  'max_features': None,
#  'min_samples_leaf': 67,
#  'min_samples_split': 171,
#  'n_estimators': 558}

# %%
best_rf = rnd_search_rf.best_estimator_

# %%
# evaluate random search
val_pred = best_rf.predict(val_feature_scaled)

print("Mean Absolute Error for Random Forest: ", "{:.4f}".format(mean_absolute_error(val_label, val_pred)))
# Out:
# Mean Absolute Error for Random Forest:  17.2509

# %%
# plot feature importance
import matplotlib
import matplotlib.pyplot as plt

features = tr_feature_scaled.columns
importances = best_rf.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(10,15))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# save all tree plots
#
# import os
# from sklearn.tree import export_graphviz
# import six
# import pydot
# from sklearn import tree
#
# dotfile = six.StringIO()
# i_tree = 0
# for tree_in_forest in best_rf.estimators_:
#     export_graphviz(tree_in_forest,out_file='tree.dot',
#     feature_names=tr_feature_scaled.columns,
#     filled=True,
#     rounded=True)
#     (graph,) = pydot.graph_from_dot_file('tree.dot')
#     name = 'tree' + str(i_tree)
#     graph.write_png(name+  '.png')
#     os.system('dot -Tpng tree.dot -o tree.png')
#     i_tree +=1

# %%
# visualize a tree plot within the random forest

from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()
export_graphviz(best_rf.estimators_[3], out_file=dot_data,  
                feature_names=tr_feature_scaled.columns,
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ## Predit Test Data Using Best Hyperparameter Model

# %%
# predict on test data
te_pred = best_rf.predict(te_feature_scaled)

# %%
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)

# %%
submission
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18            9
# 1     sj  2008          19            9
# 2     sj  2008          20            4
# 3     sj  2008          21            3
# 4     sj  2008          22           10
# 5     sj  2008          23           10
# 6     sj  2008          24           10
# 7     sj  2008          25            5
# 8     sj  2008          26           12
# 9     sj  2008          27           12
# 10    sj  2008          28           11
# 11    sj  2008          29           13
# 12    sj  2008          30           13
# 13    sj  2008          31           14
# 14    sj  2008          32           21
# 15    sj  2008          33           28
# 16    sj  2008          34           31
# 17    sj  2008          35           32
# 18    sj  2008          36           33
# 19    sj  2008          37           33
# 20    sj  2008          38           33
# 21    sj  2008          39           33
# 22    sj  2008          40           33
# 23    sj  2008          41           33
# 24    sj  2008          42           33
# 25    sj  2008          43           34
# 26    sj  2008          44           34
# 27    sj  2008          45           33
# 28    sj  2008          46           33
# 29    sj  2008          47           33
# 30    sj  2008          48           34
# 31    sj  2008          49           33
# 32    sj  2008          50           34
# 33    sj  2008          51           33
# 34    sj  2008          52           31
# 35    sj  2009           1            5
# 36    sj  2009           2           16
# 37    sj  2009           3           17
# 38    sj  2009           4           17
# 39    sj  2009           5           17
# 40    sj  2009           6           17
# 41    sj  2009           7           18
# 42    sj  2009           8           18
# 43    sj  2009           9           16
# 44    sj  2009          10           11
# 45    sj  2009          11           10
# 46    sj  2009          12           10
# 47    sj  2009          13            9
# 48    sj  2009          14           10
# 49    sj  2009          15           10
# 50    sj  2009          16            9
# 51    sj  2009          17            9
# 52    sj  2009          18            9
# 53    sj  2009          19            9
# 54    sj  2009          20           10
# 55    sj  2009          21           10
# 56    sj  2009          22           10
# 57    sj  2009          23           10
# 58    sj  2009          24           11
# 59    sj  2009          25           12
# 60    sj  2009          26           11
# 61    sj  2009          27            9
# 62    sj  2009          28           12
# 63    sj  2009          29           13
# 64    sj  2009          30           13
# 65    sj  2009          31           15
# 66    sj  2009          32           21
# 67    sj  2009          33           28
# 68    sj  2009          34           31
# 69    sj  2009          35           32
# 70    sj  2009          36           33
# 71    sj  2009          37           33
# 72    sj  2009          38           33
# 73    sj  2009          39           33
# 74    sj  2009          40           33
# 75    sj  2009          41           34
# 76    sj  2009          42           34
# 77    sj  2009          43           34
# 78    sj  2009          44           33
# 79    sj  2009          45           33
# 80    sj  2009          46           34
# 81    sj  2009          47           33
# 82    sj  2009          48           33
# 83    sj  2009          49           33
# 84    sj  2009          50           34
# 85    sj  2009          51           34
# 86    sj  2009          52           33
# 87    sj  2010          53            7
# 88    sj  2010           1           18
# 89    sj  2010           2           17
# 90    sj  2010           3           18
# 91    sj  2010           4           18
# 92    sj  2010           5           18
# 93    sj  2010           6           11
# 94    sj  2010           7            5
# 95    sj  2010           8           17
# 96    sj  2010           9            9
# 97    sj  2010          10           11
# 98    sj  2010          11           10
# 99    sj  2010          12           10
# 100   sj  2010          13           11
# 101   sj  2010          14            9
# 102   sj  2010          15            9
# 103   sj  2010          16           10
# 104   sj  2010          17           11
# 105   sj  2010          18           11
# 106   sj  2010          19           10
# 107   sj  2010          20           12
# 108   sj  2010          21           11
# 109   sj  2010          22           12
# 110   sj  2010          23           11
# 111   sj  2010          24           12
# 112   sj  2010          25           12
# 113   sj  2010          26           11
# 114   sj  2010          27           12
# 115   sj  2010          28           12
# 116   sj  2010          29           12
# 117   sj  2010          30           13
# 118   sj  2010          31           14
# 119   sj  2010          32           20
# 120   sj  2010          33           27
# 121   sj  2010          34           31
# 122   sj  2010          35           32
# 123   sj  2010          36           33
# 124   sj  2010          37           33
# 125   sj  2010          38           33
# 126   sj  2010          39           33
# 127   sj  2010          40           33
# 128   sj  2010          41           34
# 129   sj  2010          42           33
# 130   sj  2010          43           33
# 131   sj  2010          44           33
# 132   sj  2010          45           34
# 133   sj  2010          46           33
# 134   sj  2010          47           33
# 135   sj  2010          48           33
# 136   sj  2010          49           31
# 137   sj  2010          50           32
# 138   sj  2010          51           33
# 139   sj  2011          52           34
# 140   sj  2011           1           17
# 141   sj  2011           2           17
# 142   sj  2011           3           17
# 143   sj  2011           4           17
# 144   sj  2011           5           18
# 145   sj  2011           6           18
# 146   sj  2011           7           17
# 147   sj  2011           8           17
# 148   sj  2011           9           15
# 149   sj  2011          10           11
# 150   sj  2011          11            9
# 151   sj  2011          12           11
# 152   sj  2011          13           10
# 153   sj  2011          14           10
# 154   sj  2011          15           10
# 155   sj  2011          16           10
# 156   sj  2011          17            9
# 157   sj  2011          18            9
# 158   sj  2011          19            9
# 159   sj  2011          20           10
# 160   sj  2011          21           10
# 161   sj  2011          22           11
# 162   sj  2011          23           11
# 163   sj  2011          24           12
# 164   sj  2011          25           12
# 165   sj  2011          26           12
# 166   sj  2011          27           12
# 167   sj  2011          28           13
# 168   sj  2011          29           13
# 169   sj  2011          30           13
# 170   sj  2011          31           15
# 171   sj  2011          32           21
# 172   sj  2011          33           28
# 173   sj  2011          34           31
# 174   sj  2011          35           32
# 175   sj  2011          36           34
# 176   sj  2011          37           34
# 177   sj  2011          38           33
# 178   sj  2011          39           34
# 179   sj  2011          40           34
# 180   sj  2011          41           34
# 181   sj  2011          42           34
# 182   sj  2011          43           33
# 183   sj  2011          44           33
# 184   sj  2011          45           34
# 185   sj  2011          46           34
# 186   sj  2011          47           34
# 187   sj  2011          48           33
# 188   sj  2011          49           33
# 189   sj  2011          50           34
# 190   sj  2011          51           33
# 191   sj  2012          52           34
# 192   sj  2012           1           18
# 193   sj  2012           2           17
# 194   sj  2012           3           17
# 195   sj  2012           4           18
# 196   sj  2012           5           17
# 197   sj  2012           6           18
# 198   sj  2012           7           17
# 199   sj  2012           8           18
# 200   sj  2012           9           15
# 201   sj  2012          10           12
# 202   sj  2012          11           11
# 203   sj  2012          12           10
# 204   sj  2012          13           10
# 205   sj  2012          14           10
# 206   sj  2012          15            9
# 207   sj  2012          16           10
# 208   sj  2012          17            9
# 209   sj  2012          18           10
# 210   sj  2012          19           10
# 211   sj  2012          20           10
# 212   sj  2012          21           10
# 213   sj  2012          22           10
# 214   sj  2012          23           11
# 215   sj  2012          24           12
# 216   sj  2012          25           12
# 217   sj  2012          26           12
# 218   sj  2012          27           12
# 219   sj  2012          28           13
# 220   sj  2012          29           12
# 221   sj  2012          30           13
# 222   sj  2012          31           15
# 223   sj  2012          32           21
# 224   sj  2012          33           28
# 225   sj  2012          34           31
# 226   sj  2012          35           32
# 227   sj  2012          36           33
# 228   sj  2012          37           33
# 229   sj  2012          38           34
# 230   sj  2012          39           34
# 231   sj  2012          40           34
# 232   sj  2012          41           34
# 233   sj  2012          42           34
# 234   sj  2012          43           34
# 235   sj  2012          44           34
# 236   sj  2012          45           34
# 237   sj  2012          46           34
# 238   sj  2012          47           34
# 239   sj  2012          48           34
# 240   sj  2012          49           33
# 241   sj  2012          50           33
# 242   sj  2012          51           33
# 243   sj  2013           1           17
# 244   sj  2013           2           18
# 245   sj  2013           3           17
# 246   sj  2013           4           17
# 247   sj  2013           5           18
# 248   sj  2013           6           17
# 249   sj  2013           7           18
# 250   sj  2013           8           17
# 251   sj  2013           9           15
# 252   sj  2013          10           11
# 253   sj  2013          11           11
# 254   sj  2013          12            9
# 255   sj  2013          13           10
# 256   sj  2013          14            9
# 257   sj  2013          15            9
# 258   sj  2013          16            9
# 259   sj  2013          17            9
# 260   iq  2010          26            5
# 261   iq  2010          27            2
# 262   iq  2010          28            6
# 263   iq  2010          29            2
# 264   iq  2010          30            2
# 265   iq  2010          31            2
# 266   iq  2010          32            2
# 267   iq  2010          33            2
# 268   iq  2010          34            2
# 269   iq  2010          35            2
# 270   iq  2010          36            2
# 271   iq  2010          37            2
# 272   iq  2010          38            2
# 273   iq  2010          39            2
# 274   iq  2010          40            2
# 275   iq  2010          41            2
# 276   iq  2010          42            6
# 277   iq  2010          43            6
# 278   iq  2010          44            9
# 279   iq  2010          45            6
# 280   iq  2010          46            6
# 281   iq  2010          47            6
# 282   iq  2010          48            8
# 283   iq  2010          49            8
# 284   iq  2010          50            8
# 285   iq  2010          51            2
# 286   iq  2011          52            4
# 287   iq  2011           1            3
# 288   iq  2011           2            6
# 289   iq  2011           3            4
# 290   iq  2011           4            3
# 291   iq  2011           5            3
# 292   iq  2011           6            6
# 293   iq  2011           7            7
# 294   iq  2011           8            6
# 295   iq  2011           9            7
# 296   iq  2011          10            7
# 297   iq  2011          11            6
# 298   iq  2011          12            7
# 299   iq  2011          13            7
# 300   iq  2011          14            6
# 301   iq  2011          15            6
# 302   iq  2011          16            6
# 303   iq  2011          17            6
# 304   iq  2011          18            7
# 305   iq  2011          19            2
# 306   iq  2011          20            2
# 307   iq  2011          21            3
# 308   iq  2011          22            2
# 309   iq  2011          23            2
# 310   iq  2011          24            2
# 311   iq  2011          25            2
# 312   iq  2011          26            2
# 313   iq  2011          27            2
# 314   iq  2011          28            2
# 315   iq  2011          29            2
# 316   iq  2011          30            2
# 317   iq  2011          31            2
# 318   iq  2011          32            2
# 319   iq  2011          33            2
# 320   iq  2011          34            2
# 321   iq  2011          35            2
# 322   iq  2011          36            2
# 323   iq  2011          37            2
# 324   iq  2011          38            2
# 325   iq  2011          39            3
# 326   iq  2011          40            2
# 327   iq  2011          41            6
# 328   iq  2011          42            9
# 329   iq  2011          43            6
# 330   iq  2011          44            4
# 331   iq  2011          45            6
# 332   iq  2011          46            6
# 333   iq  2011          47            6
# 334   iq  2011          48            6
# 335   iq  2011          49            6
# 336   iq  2011          50            6
# 337   iq  2011          51            6
# 338   iq  2012          52            6
# 339   iq  2012           1            6
# 340   iq  2012           2            7
# 341   iq  2012           3            4
# 342   iq  2012           4            3
# 343   iq  2012           5            6
# 344   iq  2012           6            7
# 345   iq  2012           7            4
# 346   iq  2012           8            3
# 347   iq  2012           9            3
# 348   iq  2012          10            6
# 349   iq  2012          11            3
# 350   iq  2012          12            3
# 351   iq  2012          13            7
# 352   iq  2012          14            3
# 353   iq  2012          15            6
# 354   iq  2012          16            6
# 355   iq  2012          17            6
# 356   iq  2012          18            6
# 357   iq  2012          19            2
# 358   iq  2012          20            6
# 359   iq  2012          21            2
# 360   iq  2012          22            2
# 361   iq  2012          23            2
# 362   iq  2012          24            2
# 363   iq  2012          25            2
# 364   iq  2012          26            2
# 365   iq  2012          27            2
# 366   iq  2012          28            2
# 367   iq  2012          29            2
# 368   iq  2012          30            2
# 369   iq  2012          31            2
# 370   iq  2012          32            2
# 371   iq  2012          33            2
# 372   iq  2012          34            2
# 373   iq  2012          35            2
# 374   iq  2012          36            2
# 375   iq  2012          37            2
# 376   iq  2012          38            2
# 377   iq  2012          39            2
# 378   iq  2012          40            2
# 379   iq  2012          41            5
# 380   iq  2012          42            2
# 381   iq  2012          43            6
# 382   iq  2012          44            6
# 383   iq  2012          45            6
# 384   iq  2012          46            6
# 385   iq  2012          47            6
# 386   iq  2012          48            8
# 387   iq  2012          49            6
# 388   iq  2012          50            6
# 389   iq  2012          51            6
# 390   iq  2013           1            7
# 391   iq  2013           2            3
# 392   iq  2013           3            3
# 393   iq  2013           4            7
# 394   iq  2013           5            4
# 395   iq  2013           6            7
# 396   iq  2013           7            7
# 397   iq  2013           8            7
# 398   iq  2013           9            7
# 399   iq  2013          10            7
# 400   iq  2013          11            7
# 401   iq  2013          12            7
# 402   iq  2013          13            7
# 403   iq  2013          14            7
# 404   iq  2013          15            6
# 405   iq  2013          16            7
# 406   iq  2013          17            6
# 407   iq  2013          18            2
# 408   iq  2013          19            6
# 409   iq  2013          20            6
# 410   iq  2013          21            3
# 411   iq  2013          22            2
# 412   iq  2013          23            3
# 413   iq  2013          24            2
# 414   iq  2013          25            2
# 415   iq  2013          26            2

# %%
upload = './My Drive/ML Term Project/Submission CSV/submission_randomforest.csv'
submission.to_csv(upload, index = False)

# %% [markdown]
# # SVR

# %% [markdown]
# ## Fit a Linear SVR with Default Parameters

# %%
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())

# %%
np.random.seed(42)
svr_reg = SVR()

# fit the decision tree regressor onto training data
svr_reg.fit(tr_feature_scaled, tr_label)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# predict on val data
val_pred = svr_reg.predict(val_feature_scaled)

# %%
# mean absolue error of the val data
mean_absolute_error(val_label, val_pred)
# Out:
# 18.19792041117418

# %%
# cross-validation
svr_cv_score = cross_val_score(svr_reg, tr_feature_scaled, tr_label, cv=20, scoring='neg_mean_absolute_error')

# %%
svr_mae_scores = -svr_cv_score
display_scores(svr_mae_scores)
# Out:
# Scores: [16.62856742  8.05129566 24.06885861 14.3481605  16.69304432 27.65608509
#  15.77955429 22.59397278 12.75958195 29.49666568 12.88105933 18.94920357
#  12.90334134 11.46270922 21.26440533 11.39516473 12.68281544 22.23024446
#  15.25445607  9.82755922]
# Mean: 16.846337250731473

# %% [markdown]
# ## Hyperparameters Tuning

# %%
# random search to fine tune hyperparameters
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from scipy.stats import uniform
from time import time

# set parameter range 
param_distribs = {
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'gamma': uniform(loc=0, scale=3),
    'tol': uniform(loc=0, scale=1),
    'C': uniform(loc=0, scale=5),
    'epsilon': uniform(loc=0, scale=1),
}

# %%
np.random.seed(42)
svr_reg = SVR()
rnd_search_svr = RandomizedSearchCV(svr_reg, param_distributions=param_distribs, n_jobs=-1,
                                   n_iter=100, cv=5, scoring='neg_mean_absolute_error', random_state=42)

start = time()
rnd_search_svr.fit(tr_feature_scaled, tr_label)
print("RandomizedSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(rnd_search_svr.cv_results_['params'])))
# Out:
# RandomizedSearchCV took 1323.89 seconds for 100 candidate parameter settings.

# %%
# display the score of each hyperparameter combination tested during the random search
cvres = rnd_search_svr.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print("{:.4f}".format(mean_score), params)
# Out:
# -17.2152 {'C': 1.8727005942368125, 'epsilon': 0.9507143064099162, 'gamma': 2.1959818254342154, 'kernel': 'linear', 'tol': 0.596850157946487}
# -17.2082 {'C': 2.229163764267956, 'epsilon': 0.09997491581800289, 'gamma': 1.3777466758976016, 'kernel': 'linear', 'tol': 0.6011150117432088}
# -269.8844 {'C': 3.540362888980227, 'epsilon': 0.020584494295802447, 'gamma': 2.909729556485983, 'kernel': 'sigmoid', 'tol': 0.9385527090157502}
# -19.4586 {'C': 0.0038938292050716417, 'epsilon': 0.9922115592912175, 'gamma': 1.8524445288831495, 'kernel': 'rbf', 'tol': 0.5247564316322378}
# -19.4134 {'C': 2.1597250932105787, 'epsilon': 0.2912291401980419, 'gamma': 1.8355586841671383, 'kernel': 'rbf', 'tol': 0.04666566321361543}
# -16.6955 {'C': 4.8687775942072955, 'epsilon': 0.23277134043030423, 'gamma': 0.2718193035984624, 'kernel': 'rbf', 'tol': 0.19967378215835974}
# -17.9520 {'C': 2.571172192068058, 'epsilon': 0.5924145688620425, 'gamma': 0.13935123815999317, 'kernel': 'poly', 'tol': 0.6803075385877797}
# -19.4545 {'C': 2.2524962598477147, 'epsilon': 0.013264961159866528, 'gamma': 2.8266052670545583, 'kernel': 'rbf', 'tol': 0.8083973481164611}
# -93.9383 {'C': 1.5230688458668533, 'epsilon': 0.09767211400638387, 'gamma': 2.052699079536471, 'kernel': 'poly', 'tol': 0.6832635188254582}
# -17.2079 {'C': 3.0499832889131047, 'epsilon': 0.8331949117361643, 'gamma': 0.5200939605233162, 'kernel': 'linear', 'tol': 0.2587799816000169}
# -19.3416 {'C': 3.31261142176991, 'epsilon': 0.31171107608941095, 'gamma': 1.5602040635334324, 'kernel': 'rbf', 'tol': 0.5677003278199915}
# -17.2176 {'C': 1.6160146601037761, 'epsilon': 0.5187906217433661, 'gamma': 2.1090568766855338, 'kernel': 'linear', 'tol': 0.06489224710898156}
# -90.1450 {'C': 1.2695770696717235, 'epsilon': 0.2468760628386012, 'gamma': 2.088912818519365, 'kernel': 'poly', 'tol': 0.30087830981676966}
# -19.4348 {'C': 1.424202471887338, 'epsilon': 0.036886947354532795, 'gamma': 1.8286930019396905, 'kernel': 'rbf', 'tol': 0.4110370133182313}
# -19.4967 {'C': 0.16525366450274193, 'epsilon': 0.345071248026683, 'gamma': 1.9030540341040914, 'kernel': 'rbf', 'tol': 0.1448948720912231}
# -173.2264 {'C': 2.447263801387815, 'epsilon': 0.9856504541106007, 'gamma': 0.7261658145345012, 'kernel': 'sigmoid', 'tol': 0.08085332633271525}
# -17.2135 {'C': 1.8482722803070222, 'epsilon': 0.24215993827742588, 'gamma': 2.4094192691396876, 'kernel': 'linear', 'tol': 0.6323058305935795}
# -17.2170 {'C': 3.1676485538044736, 'epsilon': 0.5357746840747585, 'gamma': 0.2708693101632249, 'kernel': 'linear', 'tol': 0.15071754396542947}
# -193.1761 {'C': 2.5409938837035932, 'epsilon': 0.6958128067908819, 'gamma': 2.5750764144411598, 'kernel': 'sigmoid', 'tol': 0.6775643618422824}
# -18.0899 {'C': 0.08293914463928076, 'epsilon': 0.512093058299281, 'gamma': 0.6794873255938139, 'kernel': 'sigmoid', 'tol': 0.09617655109142076}
# -357.2147 {'C': 4.70261632244802, 'epsilon': 0.3975720210875223, 'gamma': 1.5532540515824405, 'kernel': 'sigmoid', 'tol': 0.13752094414599325}
# -19.4649 {'C': 1.7053317552512925, 'epsilon': 0.11347352124058907, 'gamma': 2.774080854835688, 'kernel': 'rbf', 'tol': 0.6957843993450822}
# -89.8273 {'C': 1.1427501089864984, 'epsilon': 0.17495492709593619, 'gamma': 2.9465050299883067, 'kernel': 'sigmoid', 'tol': 0.5296505783560065}
# -17.2141 {'C': 1.2092614545022584, 'epsilon': 0.09310276780589921, 'gamma': 2.69164727385998, 'kernel': 'linear', 'tol': 0.8826363431893397}
# -74.9399 {'C': 0.9435355417068969, 'epsilon': 0.2788713525921819, 'gamma': 2.101073489918314, 'kernel': 'sigmoid', 'tol': 0.8971102599525771}
# -121.6488 {'C': 4.4354321213255865, 'epsilon': 0.7798755458576239, 'gamma': 1.9260949384628634, 'kernel': 'poly', 'tol': 0.9356349942209475}
# -296.5062 {'C': 3.926703255569718, 'epsilon': 0.6689882547142286, 'gamma': 1.7420598643093639, 'kernel': 'sigmoid', 'tol': 0.1014715428660321}
# -17.9419 {'C': 3.317508845540279, 'epsilon': 0.005061583846218687, 'gamma': 0.48242415425249596, 'kernel': 'rbf', 'tol': 0.4856137535862266}
# -150.0077 {'C': 2.2421207149312368, 'epsilon': 0.9944574626108207, 'gamma': 0.5277757580320361, 'kernel': 'sigmoid', 'tol': 0.23724908749680007}
# -90.8452 {'C': 1.6269984907963386, 'epsilon': 0.7464914051180241, 'gamma': 1.948898697141644, 'kernel': 'poly', 'tol': 0.7209399242521293}
# -19.3963 {'C': 1.540303959261946, 'epsilon': 0.5425402305548993, 'gamma': 1.5264422305162801, 'kernel': 'rbf', 'tol': 0.26520236768172545}
# -19.3479 {'C': 1.2199482168954179, 'epsilon': 0.9730105547524456, 'gamma': 1.1792931740002812, 'kernel': 'rbf', 'tol': 0.906098787718554}
# -98.5326 {'C': 2.1719718275521434, 'epsilon': 0.3500784076946757, 'gamma': 1.9353100860916945, 'kernel': 'poly', 'tol': 0.4925176938188639}
# -34.8744 {'C': 0.9762149389902225, 'epsilon': 0.7224521152615053, 'gamma': 0.8423170873225674, 'kernel': 'poly', 'tol': 0.768554014306309}
# -19.4713 {'C': 0.21801885877216876, 'epsilon': 0.994550510797341, 'gamma': 1.4098335419728287, 'kernel': 'rbf', 'tol': 0.9148643902204485}
# -17.2005 {'C': 1.8507935012772219, 'epsilon': 0.015456616528867428, 'gamma': 2.7849556877631763, 'kernel': 'linear', 'tol': 0.5527649668354899}
# -17.2070 {'C': 2.8614623458541915, 'epsilon': 0.9803315837160457, 'gamma': 0.22603876801838463, 'kernel': 'linear', 'tol': 0.38509772860192526}
# -17.2059 {'C': 4.255683357584284, 'epsilon': 0.31692200515627766, 'gamma': 0.5084782400582775, 'kernel': 'linear', 'tol': 0.3946914668094722}
# -16.5501 {'C': 4.221065703631557, 'epsilon': 0.9300168348108319, 'gamma': 0.2112483925486317, 'kernel': 'rbf', 'tol': 0.6150072266991697}
# -19.2876 {'C': 4.950269250521316, 'epsilon': 0.14008401523652403, 'gamma': 1.55498895709121, 'kernel': 'rbf', 'tol': 0.3225507642386005}
# -132.0769 {'C': 4.243348974623372, 'epsilon': 0.13662133144202881, 'gamma': 2.126732990730356, 'kernel': 'poly', 'tol': 0.29359184426449336}
# -17.2120 {'C': 4.046805777392568, 'epsilon': 0.8101133946791808, 'gamma': 2.601216955740311, 'kernel': 'linear', 'tol': 0.08159418040024036}
# -18.1878 {'C': 0.02592431386993388, 'epsilon': 0.6278944149486361, 'gamma': 0.5828218605361267, 'kernel': 'sigmoid', 'tol': 0.7019668772577033}
# -288.6440 {'C': 3.978963347180505, 'epsilon': 0.8900053418175663, 'gamma': 1.0139854705546074, 'kernel': 'sigmoid', 'tol': 0.5788648955075587}
# -19.1457 {'C': 2.192370615090435, 'epsilon': 0.6720261352951994, 'gamma': 0.9844580024241958, 'kernel': 'rbf', 'tol': 0.5426446347075766}
# -29.0641 {'C': 1.432706260641422, 'epsilon': 0.5908332605690108, 'gamma': 0.09150074981714829, 'kernel': 'sigmoid', 'tol': 0.0388347344294232}
# -112.0528 {'C': 1.5163275733661141, 'epsilon': 0.5370824271966554, 'gamma': 0.9799537253881226, 'kernel': 'sigmoid', 'tol': 0.7699935530986108}
# -17.2119 {'C': 1.0791051374842158, 'epsilon': 0.6228904758190003, 'gamma': 0.256042394981304, 'kernel': 'linear', 'tol': 0.19438003399487302}
# -17.2058 {'C': 0.8871977188986141, 'epsilon': 0.7506147516408583, 'gamma': 2.420504217801792, 'kernel': 'linear', 'tol': 0.7316477552996402}
# -57.9504 {'C': 0.638448647112328, 'epsilon': 0.25001644921610466, 'gamma': 1.7416320370317295, 'kernel': 'poly', 'tol': 0.9307573256035647}
# -17.2035 {'C': 4.2920637592150594, 'epsilon': 0.42899402737501835, 'gamma': 2.252613203374492, 'kernel': 'linear', 'tol': 0.23823615240397944}
# -17.2201 {'C': 1.8886444308814743, 'epsilon': 0.5343274735305634, 'gamma': 1.4896835720492332, 'kernel': 'linear', 'tol': 0.32004960103061175}
# -17.2016 {'C': 4.477616142481002, 'epsilon': 0.3892016787341631, 'gamma': 0.03251295444089508, 'kernel': 'linear', 'tol': 0.8471431440955898}
# -137.7720 {'C': 1.7745259523136032, 'epsilon': 0.9568008851264563, 'gamma': 2.03030971327291, 'kernel': 'sigmoid', 'tol': 0.5734378881232861}
# -17.2176 {'C': 3.159186060848996, 'epsilon': 0.44844552197831977, 'gamma': 0.8796323150941936, 'kernel': 'linear', 'tol': 0.5537030523458008}
# -94.2694 {'C': 1.0636394751211449, 'epsilon': 0.9461945428816902, 'gamma': 2.3438881514136076, 'kernel': 'poly', 'tol': 0.09120610304869037}
# -17.2096 {'C': 2.472101523512907, 'epsilon': 0.057558760016644284, 'gamma': 1.6485866469712067, 'kernel': 'linear', 'tol': 0.7370355567910089}
# -17.2129 {'C': 2.729578850824945, 'epsilon': 0.7058314838786945, 'gamma': 2.905955831922405, 'kernel': 'linear', 'tol': 0.7615106317174722}
# -17.2123 {'C': 3.0910903165813055, 'epsilon': 0.10112267612279024, 'gamma': 0.2523204183449923, 'kernel': 'linear', 'tol': 0.22257641757103053}
# -17.2122 {'C': 1.9832580097712593, 'epsilon': 0.8918969087767766, 'gamma': 0.43981446507607647, 'kernel': 'linear', 'tol': 0.08483771408519192}
# -365.9354 {'C': 4.933197892505877, 'epsilon': 0.3742707957561203, 'gamma': 1.1119264412006729, 'kernel': 'sigmoid', 'tol': 0.23668519368207874}
# -330.4722 {'C': 4.538468531742732, 'epsilon': 0.5918887388212843, 'gamma': 1.0506547401009407, 'kernel': 'sigmoid', 'tol': 0.08350071669866876}

# %%
"{:.4f}".format(-rnd_search_rf.best_score_)
# Out:
# '15.9989'

# %%
# best tuned hyperparameter values
rnd_search_svr.best_params_
# Out:
# {'C': 4.221065703631557,
#  'epsilon': 0.9300168348108319,
#  'gamma': 0.2112483925486317,
#  'kernel': 'rbf',
#  'tol': 0.6150072266991697}

# %%
best_svr = rnd_search_svr.best_estimator_

# %%
# evaluate random search
val_pred = best_svr.predict(val_feature_scaled)

print("Mean Absolute Error for SVR: ", "{:.4f}".format(mean_absolute_error(val_label, val_pred)))
# Out:
# Mean Absolute Error for SVR:  17.5404

# %% [markdown]
# ## Predit Test Data Using Best Hyperparameter Model

# %%
# predict on test data
te_pred = best_svr.predict(te_feature_scaled)

# %%
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)

# %%
submission
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18            8
# 1     sj  2008          19           10
# 2     sj  2008          20           11
# 3     sj  2008          21           13
# 4     sj  2008          22           12
# 5     sj  2008          23           12
# 6     sj  2008          24           10
# 7     sj  2008          25           15
# 8     sj  2008          26           13
# 9     sj  2008          27           17
# 10    sj  2008          28           11
# 11    sj  2008          29           21
# 12    sj  2008          30           13
# 13    sj  2008          31           16
# 14    sj  2008          32           27
# 15    sj  2008          33           14
# 16    sj  2008          34           19
# 17    sj  2008          35           26
# 18    sj  2008          36           26
# 19    sj  2008          37           10
# 20    sj  2008          38           36
# 21    sj  2008          39           12
# 22    sj  2008          40           20
# 23    sj  2008          41           31
# 24    sj  2008          42           33
# 25    sj  2008          43           17
# 26    sj  2008          44           22
# 27    sj  2008          45           24
# 28    sj  2008          46           30
# 29    sj  2008          47           34
# 30    sj  2008          48           27
# 31    sj  2008          49           13
# 32    sj  2008          50           12
# 33    sj  2008          51           16
# 34    sj  2008          52           14
# 35    sj  2009           1            9
# 36    sj  2009           2           11
# 37    sj  2009           3           16
# 38    sj  2009           4           17
# 39    sj  2009           5           19
# 40    sj  2009           6           14
# 41    sj  2009           7           14
# 42    sj  2009           8           11
# 43    sj  2009           9           10
# 44    sj  2009          10            6
# 45    sj  2009          11           10
# 46    sj  2009          12            8
# 47    sj  2009          13            6
# 48    sj  2009          14           11
# 49    sj  2009          15            8
# 50    sj  2009          16            7
# 51    sj  2009          17           10
# 52    sj  2009          18           11
# 53    sj  2009          19            9
# 54    sj  2009          20           11
# 55    sj  2009          21           15
# 56    sj  2009          22           13
# 57    sj  2009          23            9
# 58    sj  2009          24           16
# 59    sj  2009          25           17
# 60    sj  2009          26           16
# 61    sj  2009          27           16
# 62    sj  2009          28           23
# 63    sj  2009          29           21
# 64    sj  2009          30           17
# 65    sj  2009          31           20
# 66    sj  2009          32           17
# 67    sj  2009          33           22
# 68    sj  2009          34           25
# 69    sj  2009          35           21
# 70    sj  2009          36           16
# 71    sj  2009          37           22
# 72    sj  2009          38           16
# 73    sj  2009          39           32
# 74    sj  2009          40           28
# 75    sj  2009          41           18
# 76    sj  2009          42           25
# 77    sj  2009          43           12
# 78    sj  2009          44           28
# 79    sj  2009          45           16
# 80    sj  2009          46           13
# 81    sj  2009          47           26
# 82    sj  2009          48           36
# 83    sj  2009          49           28
# 84    sj  2009          50           25
# 85    sj  2009          51           19
# 86    sj  2009          52           24
# 87    sj  2010          53           38
# 88    sj  2010           1           13
# 89    sj  2010           2           17
# 90    sj  2010           3           10
# 91    sj  2010           4           16
# 92    sj  2010           5           15
# 93    sj  2010           6            9
# 94    sj  2010           7           12
# 95    sj  2010           8            9
# 96    sj  2010           9            4
# 97    sj  2010          10           11
# 98    sj  2010          11           10
# 99    sj  2010          12            5
# 100   sj  2010          13            7
# 101   sj  2010          14           11
# 102   sj  2010          15           11
# 103   sj  2010          16           11
# 104   sj  2010          17           11
# 105   sj  2010          18            3
# 106   sj  2010          19            9
# 107   sj  2010          20           11
# 108   sj  2010          21            9
# 109   sj  2010          22           10
# 110   sj  2010          23           20
# 111   sj  2010          24           18
# 112   sj  2010          25           15
# 113   sj  2010          26           19
# 114   sj  2010          27           12
# 115   sj  2010          28           18
# 116   sj  2010          29           15
# 117   sj  2010          30           19
# 118   sj  2010          31           16
# 119   sj  2010          32           13
# 120   sj  2010          33           24
# 121   sj  2010          34           25
# 122   sj  2010          35           16
# 123   sj  2010          36           18
# 124   sj  2010          37           25
# 125   sj  2010          38           21
# 126   sj  2010          39           24
# 127   sj  2010          40           35
# 128   sj  2010          41           17
# 129   sj  2010          42           19
# 130   sj  2010          43           13
# 131   sj  2010          44           21
# 132   sj  2010          45           20
# 133   sj  2010          46           16
# 134   sj  2010          47           10
# 135   sj  2010          48           13
# 136   sj  2010          49           10
# 137   sj  2010          50           14
# 138   sj  2010          51           14
# 139   sj  2011          52           18
# 140   sj  2011           1           13
# 141   sj  2011           2           18
# 142   sj  2011           3           10
# 143   sj  2011           4           15
# 144   sj  2011           5           17
# 145   sj  2011           6           16
# 146   sj  2011           7           14
# 147   sj  2011           8           15
# 148   sj  2011           9            8
# 149   sj  2011          10            9
# 150   sj  2011          11            7
# 151   sj  2011          12           14
# 152   sj  2011          13           15
# 153   sj  2011          14           14
# 154   sj  2011          15           12
# 155   sj  2011          16           11
# 156   sj  2011          17            7
# 157   sj  2011          18           11
# 158   sj  2011          19            6
# 159   sj  2011          20           10
# 160   sj  2011          21           10
# 161   sj  2011          22           15
# 162   sj  2011          23           12
# 163   sj  2011          24           10
# 164   sj  2011          25           12
# 165   sj  2011          26           19
# 166   sj  2011          27           21
# 167   sj  2011          28           16
# 168   sj  2011          29           17
# 169   sj  2011          30           28
# 170   sj  2011          31           20
# 171   sj  2011          32           18
# 172   sj  2011          33           21
# 173   sj  2011          34           12
# 174   sj  2011          35           16
# 175   sj  2011          36           30
# 176   sj  2011          37           25
# 177   sj  2011          38           24
# 178   sj  2011          39           24
# 179   sj  2011          40           20
# 180   sj  2011          41           31
# 181   sj  2011          42           24
# 182   sj  2011          43           22
# 183   sj  2011          44           25
# 184   sj  2011          45           23
# 185   sj  2011          46           12
# 186   sj  2011          47           27
# 187   sj  2011          48           20
# 188   sj  2011          49           12
# 189   sj  2011          50           12
# 190   sj  2011          51           17
# 191   sj  2012          52           20
# 192   sj  2012           1           16
# 193   sj  2012           2           15
# 194   sj  2012           3           11
# 195   sj  2012           4           16
# 196   sj  2012           5           12
# 197   sj  2012           6           17
# 198   sj  2012           7           10
# 199   sj  2012           8           10
# 200   sj  2012           9           10
# 201   sj  2012          10           16
# 202   sj  2012          11            9
# 203   sj  2012          12            9
# 204   sj  2012          13           10
# 205   sj  2012          14           11
# 206   sj  2012          15            9
# 207   sj  2012          16           11
# 208   sj  2012          17           11
# 209   sj  2012          18           10
# 210   sj  2012          19           11
# 211   sj  2012          20           11
# 212   sj  2012          21            8
# 213   sj  2012          22           12
# 214   sj  2012          23           11
# 215   sj  2012          24           13
# 216   sj  2012          25           19
# 217   sj  2012          26           13
# 218   sj  2012          27           14
# 219   sj  2012          28           22
# 220   sj  2012          29           14
# 221   sj  2012          30           12
# 222   sj  2012          31           17
# 223   sj  2012          32           27
# 224   sj  2012          33           21
# 225   sj  2012          34           20
# 226   sj  2012          35           20
# 227   sj  2012          36           23
# 228   sj  2012          37           26
# 229   sj  2012          38           20
# 230   sj  2012          39           20
# 231   sj  2012          40           35
# 232   sj  2012          41           33
# 233   sj  2012          42           27
# 234   sj  2012          43           29
# 235   sj  2012          44           21
# 236   sj  2012          45           36
# 237   sj  2012          46           30
# 238   sj  2012          47           14
# 239   sj  2012          48           22
# 240   sj  2012          49           35
# 241   sj  2012          50           11
# 242   sj  2012          51           15
# 243   sj  2013           1            8
# 244   sj  2013           2           10
# 245   sj  2013           3            4
# 246   sj  2013           4           10
# 247   sj  2013           5           16
# 248   sj  2013           6           14
# 249   sj  2013           7           14
# 250   sj  2013           8            8
# 251   sj  2013           9            7
# 252   sj  2013          10            8
# 253   sj  2013          11            6
# 254   sj  2013          12            6
# 255   sj  2013          13            8
# 256   sj  2013          14            9
# 257   sj  2013          15            8
# 258   sj  2013          16           11
# 259   sj  2013          17           10
# 260   iq  2010          26            5
# 261   iq  2010          27            2
# 262   iq  2010          28            6
# 263   iq  2010          29            9
# 264   iq  2010          30            6
# 265   iq  2010          31            3
# 266   iq  2010          32            4
# 267   iq  2010          33            2
# 268   iq  2010          34            4
# 269   iq  2010          35            2
# 270   iq  2010          36            6
# 271   iq  2010          37            2
# 272   iq  2010          38            7
# 273   iq  2010          39            3
# 274   iq  2010          40           10
# 275   iq  2010          41            2
# 276   iq  2010          42            8
# 277   iq  2010          43            4
# 278   iq  2010          44            7
# 279   iq  2010          45            9
# 280   iq  2010          46            6
# 281   iq  2010          47            9
# 282   iq  2010          48            7
# 283   iq  2010          49            7
# 284   iq  2010          50            6
# 285   iq  2010          51            3
# 286   iq  2011          52            9
# 287   iq  2011           1            7
# 288   iq  2011           2            7
# 289   iq  2011           3            2
# 290   iq  2011           4            7
# 291   iq  2011           5            6
# 292   iq  2011           6            5
# 293   iq  2011           7            8
# 294   iq  2011           8           10
# 295   iq  2011           9            9
# 296   iq  2011          10            4
# 297   iq  2011          11            5
# 298   iq  2011          12            9
# 299   iq  2011          13            6
# 300   iq  2011          14            7
# 301   iq  2011          15            3
# 302   iq  2011          16            6
# 303   iq  2011          17            5
# 304   iq  2011          18            7
# 305   iq  2011          19            4
# 306   iq  2011          20            6
# 307   iq  2011          21            3
# 308   iq  2011          22            6
# 309   iq  2011          23            8
# 310   iq  2011          24            6
# 311   iq  2011          25            6
# 312   iq  2011          26            4
# 313   iq  2011          27            7
# 314   iq  2011          28            3
# 315   iq  2011          29            2
# 316   iq  2011          30            3
# 317   iq  2011          31            5
# 318   iq  2011          32            5
# 319   iq  2011          33            4
# 320   iq  2011          34            6
# 321   iq  2011          35            3
# 322   iq  2011          36            2
# 323   iq  2011          37            5
# 324   iq  2011          38            6
# 325   iq  2011          39            8
# 326   iq  2011          40            6
# 327   iq  2011          41            5
# 328   iq  2011          42            6
# 329   iq  2011          43            8
# 330   iq  2011          44            6
# 331   iq  2011          45            5
# 332   iq  2011          46           10
# 333   iq  2011          47            7
# 334   iq  2011          48            6
# 335   iq  2011          49           10
# 336   iq  2011          50           11
# 337   iq  2011          51            7
# 338   iq  2012          52            8
# 339   iq  2012           1            6
# 340   iq  2012           2            4
# 341   iq  2012           3            7
# 342   iq  2012           4            1
# 343   iq  2012           5            6
# 344   iq  2012           6            9
# 345   iq  2012           7            8
# 346   iq  2012           8            9
# 347   iq  2012           9            5
# 348   iq  2012          10            8
# 349   iq  2012          11            1
# 350   iq  2012          12            0
# 351   iq  2012          13           11
# 352   iq  2012          14            3
# 353   iq  2012          15            6
# 354   iq  2012          16            8
# 355   iq  2012          17            7
# 356   iq  2012          18            2
# 357   iq  2012          19            0
# 358   iq  2012          20            6
# 359   iq  2012          21            0
# 360   iq  2012          22            1
# 361   iq  2012          23            5
# 362   iq  2012          24            5
# 363   iq  2012          25            4
# 364   iq  2012          26            6
# 365   iq  2012          27            3
# 366   iq  2012          28            5
# 367   iq  2012          29            8
# 368   iq  2012          30            9
# 369   iq  2012          31            3
# 370   iq  2012          32            3
# 371   iq  2012          33            5
# 372   iq  2012          34            8
# 373   iq  2012          35            4
# 374   iq  2012          36            6
# 375   iq  2012          37            3
# 376   iq  2012          38            6
# 377   iq  2012          39            2
# 378   iq  2012          40            5
# 379   iq  2012          41            5
# 380   iq  2012          42            3
# 381   iq  2012          43            8
# 382   iq  2012          44            4
# 383   iq  2012          45            5
# 384   iq  2012          46            8
# 385   iq  2012          47           11
# 386   iq  2012          48           10
# 387   iq  2012          49            7
# 388   iq  2012          50            7
# 389   iq  2012          51           10
# 390   iq  2013           1            7
# 391   iq  2013           2            7
# 392   iq  2013           3            5
# 393   iq  2013           4            8
# 394   iq  2013           5            8
# 395   iq  2013           6            7
# 396   iq  2013           7            9
# 397   iq  2013           8            7
# 398   iq  2013           9            8
# 399   iq  2013          10            6
# 400   iq  2013          11            8
# 401   iq  2013          12            8
# 402   iq  2013          13            9
# 403   iq  2013          14            9
# 404   iq  2013          15            4
# 405   iq  2013          16            7
# 406   iq  2013          17            4
# 407   iq  2013          18            7
# 408   iq  2013          19            7
# 409   iq  2013          20            5
# 410   iq  2013          21            3
# 411   iq  2013          22            5
# 412   iq  2013          23            1
# 413   iq  2013          24            1
# 414   iq  2013          25            5
# 415   iq  2013          26            3

# %%
upload = './My Drive/ML Term Project/Submission CSV/submission_svr.csv'
submission.to_csv(upload, index = False)

# %% [markdown]
# # SGD Regressor

# %% [markdown]
# ## Fit a SGD Regressor with Default Parameters

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())

# %%
np.random.seed(42)
sgd_reg = linear_model.SGDRegressor()

# fit the decision tree regressor onto training data
sgd_reg.fit(tr_feature_scaled, tr_label)
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='squared_loss', max_iter=1000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
# predict on val data
val_pred = sgd_reg.predict(val_feature_scaled)

# %%
# mean absolue error of the val data
mean_absolute_error(val_label, val_pred)
# Out:
# 21.05470213787792

# %%
# cross-validation
sgd_cv_score = cross_val_score(sgd_reg, tr_feature_scaled, tr_label, cv=20, scoring='neg_mean_absolute_error')

# %%
sgd_mae_scores = -sgd_cv_score
display_scores(sgd_mae_scores)
# Out:
# Scores: [19.12725784 15.00382597 28.10105228 18.80426261 19.83760655 28.00596802
#  21.43642777 24.0235927  18.18713711 29.53209038 15.18860015 23.19431837
#  19.03057064 19.2555854  24.69071789 15.37845637 18.08866833 22.91174908
#  19.04354908 17.4021393 ]
# Mean: 20.812178791591318

# %% [markdown]
# ## Hyperparameters Tuning

# %%
# random search to fine tune hyperparameters
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from scipy.stats import uniform
from time import time

# set parameter range 
param_distribs = {
    'loss': ['squared_loss', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'],
    'penalty': ['l2', 'l1', 'elasticnet'],
    'alpha': uniform(loc=0, scale=1),
    'tol': uniform(loc=0, scale=1),
    'learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
    'early_stopping': [True, False],
}

# %%
np.random.seed(42)
sgd_reg = linear_model.SGDRegressor()
rnd_search_sgd = RandomizedSearchCV(sgd_reg, param_distributions=param_distribs, n_jobs=-1,
                                   n_iter=1000, cv=5, scoring='neg_mean_absolute_error', random_state=42)

start = time()
rnd_search_sgd.fit(tr_feature_scaled, tr_label)
print("RandomizedSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(rnd_search_sgd.cv_results_['params'])))
# Out:
# RandomizedSearchCV took 53.85 seconds for 1000 candidate parameter settings.

# %%
# display the score of each hyperparameter combination tested during the random search
cvres = rnd_search_sgd.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print("{:.4f}".format(mean_score), params)
# Out:
# -19.5931 {'alpha': 0.3745401188473625, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'epsilon_insensitive', 'penalty': 'l2', 'tol': 0.596850157946487}
# -19.6711 {'alpha': 0.44583275285359114, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'epsilon_insensitive', 'penalty': 'l2', 'tol': 0.6011150117432088}
# -21.4608 {'alpha': 0.7080725777960455, 'early_stopping': False, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l1', 'tol': 0.21233911067827616}
# -21.5577 {'alpha': 0.18182496720710062, 'early_stopping': True, 'learning_rate': 'constant', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l1', 'tol': 0.5247564316322378}
# -19.7522 {'alpha': 0.43194501864211576, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet', 'tol': 0.13949386065204183}
# -23.5083 {'alpha': 0.29214464853521815, 'early_stopping': False, 'learning_rate': 'invscaling', 'loss': 'huber', 'penalty': 'l1', 'tol': 0.7851759613930136}
# -20.6818 {'alpha': 0.19967378215835974, 'early_stopping': True, 'learning_rate': 'adaptive', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l2', 'tol': 0.046450412719997725}
# -19.4685 {'alpha': 0.6075448519014384, 'early_stopping': True, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l1', 'tol': 0.9488855372533332}
# -72.2644 {'alpha': 0.9656320330745594, 'early_stopping': False, 'learning_rate': 'optimal', 'loss': 'squared_loss', 'penalty': 'l1', 'tol': 0.09767211400638387}
# -18.3105 {'alpha': 0.6842330265121569, 'early_stopping': True, 'learning_rate': 'adaptive', 'loss': 'epsilon_insensitive', 'penalty': 'l2', 'tol': 0.8331949117361643}
# -21.3288 {'alpha': 0.17336465350777208, 'early_stopping': True, 'learning_rate': 'adaptive', 'loss': 'huber', 'penalty': 'l1', 'tol': 0.4251558744912447}
# -787177.1166 {'alpha': 0.20794166286818883, 'early_stopping': False, 'learning_rate': 'optimal', 'loss': 'squared_loss', 'penalty': 'elasticnet', 'tol': 0.8422847745949985}
# -1793213885.0045 {'alpha': 0.44975413336976566, 'early_stopping': False, 'learning_rate': 'optimal', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l1', 'tol': 0.7272719958564209}
# -20.9133 {'alpha': 0.3265407688058354, 'early_stopping': False, 'learning_rate': 'invscaling', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l2', 'tol': 0.9611720243493491}
# -19.4516 {'alpha': 0.8445338486781514, 'early_stopping': True, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l2', 'tol': 0.5867511656638482}
# -19.7182 {'alpha': 0.965255307264138, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'squared_loss', 'penalty': 'l2', 'tol': 0.2962735057040824}
# -20.6470 {'alpha': 0.1652669390630025, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'squared_loss', 'penalty': 'l2', 'tol': 0.1987156815341724}
# -20.4284 {'alpha': 0.005522117123602399, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'squared_loss', 'penalty': 'elasticnet', 'tol': 0.7901755405312056}
# -23.3949 {'alpha': 0.6059599747810114, 'early_stopping': False, 'learning_rate': 'invscaling', 'loss': 'huber', 'penalty': 'l2', 'tol': 0
 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'huber', 'penalty': 'l1', 'tol': 0.045294643613077445}
# -21.3148 {'alpha': 0.6563858593847672, 'early_stopping': True, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l1', 'tol': 0.034939246405988444}
# -200.7554 {'alpha': 0.9897564134093346, 'early_stopping': True, 'learning_rate': 'optimal', 'loss': 'squared_loss', 'penalty': 'l1', 'tol': 0.5046190246076956}
# -17.6417 {'alpha': 0.11728014780044504, 'early_stopping': False, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet', 'tol': 0.5778070502510847}
# -19.6156 {'alpha': 0.8661015453778347, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'squared_loss', 'penalty': 'l1', 'tol': 0.4343614981412177}
# -20.0665 {'alpha': 0.44644192179654874, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l2', 'tol': 0.5007109258366713}
# -18.5045 {'alpha': 0.6448612228149799, 'early_stopping': True, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'elasticnet', 'tol': 0.27893807607347676}
# -17.7091 {'alpha': 0.1291744452431104, 'early_stopping': True, 'learning_rate': 'adaptive', 'loss': 'epsilon_insensitive', 'penalty': 'l1', 'tol': 0.5236005471526117}
# -17.8669 {'alpha': 0.2535841169963692, 'early_stopping': True, 'learning_rate': 'constant', 'loss': 'epsilon_insensitive', 'penalty': 'l2', 'tol': 0.6520930618816506}
# -23.2423 {'alpha': 0.7809193563860904, 'early_stopping': True, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'elasticnet', 'tol': 0.12595519637935826}
# -19.6717 {'alpha': 0.9791515551006156, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'squared_loss', 'penalty': 'elasticnet', 'tol': 0.324329377351518}
# -23.0297 {'alpha': 0.6764837495206044, 'early_stopping': True, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l2', 'tol': 0.6825324595377216}
# -19.8030 {'alpha': 0.5753591731290986, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'huber', 'penalty': 'l2', 'tol': 0.018386142151597284}
# -19.8115 {'alpha': 0.4640666894045047, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'squared_loss', 'penalty': 'l2', 'tol': 0.6611406784286965}
# -21.4453 {'alpha': 0.6522353531324407, 'early_stopping': True, 'learning_rate': 'constant', 'loss': 'huber', 'penalty': 'l2', 'tol': 0.6059969672710255}
# -20.1297 {'alpha': 0.8494464062257355, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'squared_loss', 'penalty': 'l1', 'tol': 0.18345240115022932}
# -20.3219 {'alpha': 0.5941418627564575, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'squared_loss', 'penalty': 'l1', 'tol': 0.013682414760681105}
# -20.7180 {'alpha': 0.08159872000483837, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'squared_epsilon_insensitive', 'penalty': 'elasticnet', 'tol': 0.631375326048251}
# -20.7269 {'alpha': 0.4263983568016225, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l1', 'tol': 0.2959320294366161}
# -23.5240 {'alpha': 0.6638244748527251, 'early_stopping': False, 'learning_rate': 'optimal', 'loss': 'squared_loss', 'penalty': 'elasticnet', 'tol': 0.8903843208552661}
# -20.8416 {'alpha': 0.5768812013112085, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l2', 'tol': 0.06939408590418339}
# -21.1404 {'alpha': 0.08987685173616067, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'huber', 'penalty': 'l1', 'tol': 0.9172680665776807}
# -2161903.0519 {'alpha': 0.40659053735947226, 'early_stopping': False, 'learning_rate': 'optimal', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l2', 'tol': 0.29335342144100984}
# -22.2798 {'alpha': 0.5254703073558932, 'early_stopping': False, 'learning_rate': 'constant', 'loss': 'squared_epsilon_insensitive', 'penalty': 'l2', 'tol': 0.3078863820162494}
# -23.3113 {'alpha': 0.8375308340760557, 'early_stopping': False, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'elasticnet', 'tol': 0.25363555551403827}
# -19.7712 {'alpha': 0.7563342695828866, 'early_stopping': False, 'learning_rate': 'invscaling', 'loss': 'squared_loss', 'penalty': 'l2', 'tol': 0.633711599765529}
# -22.9310 {'alpha': 0.5934613827047238, 'early_stopping': True, 'learning_rate': 'optimal', 'loss': 'huber', 'penalty': 'l2', 'tol': 0.6650559890066311}
# -6802779.3565 {'alpha': 0.5565784285021533, 'early_stopping': True, 'learning_rate': 'optimal', 'loss': 'squared_epsilon_insensitive', 'penalty': 'elasticnet', 'tol': 0.09441889766048095}
# -21.1738 {'alpha': 0.8315183331122236, 'early_stopping': True, 'learning_rate': 'adaptive', 'loss': 'huber', 'penalty': 'l2', 'tol': 0.10343411486048337}
# -18.7687 {'alpha': 0.4020272168882407, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'epsilon_insensitive', 'penalty': 'l1', 'tol': 0.1182186222910886}
# -20.9923 {'alpha': 3.071884538241587e-05, 'early_stopping': True, 'learning_rate': 'invscaling', 'loss': 'squared_loss', 'penalty': 'elasticnet', 'tol': 0.14821746209932463}
# -20.4647 {'alpha': 0.0920987541995898, 'early_stopping': False, 'learning_rate': 'adaptive', 'loss': 'squared_loss', 'penalty': 'elasticnet', 'tol': 0.8236064207981895}
# -19.6401 {'alpha': 0.8987878897373477, 'early_stopping': True, 'learning_rate': 'optimal', 'loss': 'epsilon_insensitive', 'penalty': 'l2', 'tol': 0.3840426383911004}
# -18.2606 {'alpha': 0.6662678614790385, 'early_stopping': True, 'learning_rate': 'adaptive', 'loss': 'epsilon_insensitive', 'penalty': 'l2', 'tol': 0.3898997462910806}
# -20.4142 {'alpha': 0.4800473773100856, 'early_stopping': False, 'learning_rate': 'invscaling', 'loss': 'squared_epsilon_insensitive', 'penalty': 'elasticnet', 'tol': 0.8297228663216244}

# %%
"{:.4f}".format(-rnd_search_sgd.best_score_)
# Out:
# '17.2658'

# %%
# best tuned hyperparameter values
rnd_search_sgd.best_params_
# Out:
# {'alpha': 0.007964404745451126,
#  'early_stopping': False,
#  'learning_rate': 'adaptive',
#  'loss': 'epsilon_insensitive',
#  'penalty': 'l1',
#  'tol': 0.5355538148796726}

# %%
best_sgd = rnd_search_sgd.best_estimator_

# %%
# evaluate random search
val_pred = best_sgd.predict(val_feature_scaled)

print("Mean Absolute Error for SGD Regressor: ", "{:.4f}".format(mean_absolute_error(val_label, val_pred)))
# Out:
# Mean Absolute Error for SGD Regressor:  18.4428

# %% [markdown]
# ## Predit Test Data Using Best Hyperparameter Model

# %%
# predict on test data
te_pred = best_sgd.predict(te_feature_scaled)

# %%
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)

# %%
submission
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18           16
# 1     sj  2008          19           17
# 2     sj  2008          20           17
# 3     sj  2008          21           16
# 4     sj  2008          22           19
# 5     sj  2008          23           18
# 6     sj  2008          24           18
# 7     sj  2008          25           19
# 8     sj  2008          26           21
# 9     sj  2008          27           22
# 10    sj  2008          28           19
# 11    sj  2008          29           21
# 12    sj  2008          30           26
# 13    sj  2008          31           21
# 14    sj  2008          32           21
# 15    sj  2008          33           24
# 16    sj  2008          34           25
# 17    sj  2008          35           23
# 18    sj  2008          36           22
# 19    sj  2008          37           32
# 20    sj  2008          38           23
# 21    sj  2008          39           21
# 22    sj  2008          40           21
# 23    sj  2008          41           23
# 24    sj  2008          42           23
# 25    sj  2008          43           19
# 26    sj  2008          44           24
# 27    sj  2008          45           22
# 28    sj  2008          46           22
# 29    sj  2008          47           22
# 30    sj  2008          48           22
# 31    sj  2008          49           23
# 32    sj  2008          50           20
# 33    sj  2008          51           20
# 34    sj  2008          52           19
# 35    sj  2009           1           15
# 36    sj  2009           2            9
# 37    sj  2009           3           15
# 38    sj  2009           4           14
# 39    sj  2009           5           14
# 40    sj  2009           6           14
# 41    sj  2009           7           14
# 42    sj  2009           8           14
# 43    sj  2009           9           16
# 44    sj  2009          10           12
# 45    sj  2009          11           14
# 46    sj  2009          12           12
# 47    sj  2009          13           11
# 48    sj  2009          14           15
# 49    sj  2009          15           15
# 50    sj  2009          16           15
# 51    sj  2009          17           15
# 52    sj  2009          18           17
# 53    sj  2009          19           18
# 54    sj  2009          20           19
# 55    sj  2009          21           19
# 56    sj  2009          22           18
# 57    sj  2009          23           19
# 58    sj  2009          24           21
# 59    sj  2009          25           20
# 60    sj  2009          26           18
# 61    sj  2009          27           17
# 62    sj  2009          28           22
# 63    sj  2009          29           21
# 64    sj  2009          30           21
# 65    sj  2009          31           24
# 66    sj  2009          32           20
# 67    sj  2009          33           23
# 68    sj  2009          34           22
# 69    sj  2009          35           20
# 70    sj  2009          36           21
# 71    sj  2009          37           24
# 72    sj  2009          38           24
# 73    sj  2009          39           22
# 74    sj  2009          40           22
# 75    sj  2009          41           23
# 76    sj  2009          42           24
# 77    sj  2009          43           19
# 78    sj  2009          44           21
# 79    sj  2009          45           20
# 80    sj  2009          46           20
# 81    sj  2009          47           21
# 82    sj  2009          48           23
# 83    sj  2009          49           24
# 84    sj  2009          50           22
# 85    sj  2009          51           26
# 86    sj  2009          52           21
# 87    sj  2010          53           21
# 88    sj  2010           1           14
# 89    sj  2010           2           13
# 90    sj  2010           3           19
# 91    sj  2010           4           14
# 92    sj  2010           5           16
# 93    sj  2010           6           15
# 94    sj  2010           7           13
# 95    sj  2010           8           14
# 96    sj  2010           9           15
# 97    sj  2010          10           15
# 98    sj  2010          11           11
# 99    sj  2010          12           12
# 100   sj  2010          13           14
# 101   sj  2010          14           12
# 102   sj  2010          15           15
# 103   sj  2010          16           18
# 104   sj  2010          17           18
# 105   sj  2010          18           17
# 106   sj  2010          19           18
# 107   sj  2010          20           21
# 108   sj  2010          21           19
# 109   sj  2010          22           22
# 110   sj  2010          23           19
# 111   sj  2010          24           19
# 112   sj  2010          25           21
# 113   sj  2010          26           19
# 114   sj  2010          27           20
# 115   sj  2010          28           21
# 116   sj  2010          29           23
# 117   sj  2010          30           22
# 118   sj  2010          31           20
# 119   sj  2010          32           23
# 120   sj  2010          33           21
# 121   sj  2010          34           22
# 122   sj  2010          35           24
# 123   sj  2010          36           26
# 124   sj  2010          37           23
# 125   sj  2010          38           24
# 126   sj  2010          39           25
# 127   sj  2010          40           23
# 128   sj  2010          41           26
# 129   sj  2010          42           22
# 130   sj  2010          43           18
# 131   sj  2010          44           25
# 132   sj  2010          45           24
# 133   sj  2010          46           23
# 134   sj  2010          47           20
# 135   sj  2010          48           21
# 136   sj  2010          49           19
# 137   sj  2010          50           17
# 138   sj  2010          51           20
# 139   sj  2011          52           23
# 140   sj  2011           1           15
# 141   sj  2011           2           14
# 142   sj  2011           3           12
# 143   sj  2011           4           13
# 144   sj  2011           5           13
# 145   sj  2011           6           15
# 146   sj  2011           7           12
# 147   sj  2011           8           13
# 148   sj  2011           9           12
# 149   sj  2011          10           10
# 150   sj  2011          11           11
# 151   sj  2011          12           14
# 152   sj  2011          13           14
# 153   sj  2011          14           17
# 154   sj  2011          15           16
# 155   sj  2011          16           16
# 156   sj  2011          17           12
# 157   sj  2011          18           18
# 158   sj  2011          19           16
# 159   sj  2011          20           20
# 160   sj  2011          21           22
# 161   sj  2011          22           21
# 162   sj  2011          23           22
# 163   sj  2011          24           23
# 164   sj  2011          25           22
# 165   sj  2011          26           23
# 166   sj  2011          27           21
# 167   sj  2011          28           23
# 168   sj  2011          29           23
# 169   sj  2011          30           22
# 170   sj  2011          31           22
# 171   sj  2011          32           24
# 172   sj  2011          33           24
# 173   sj  2011          34           25
# 174   sj  2011          35           21
# 175   sj  2011          36           23
# 176   sj  2011          37           25
# 177   sj  2011          38           22
# 178   sj  2011          39           23
# 179   sj  2011          40           22
# 180   sj  2011          41           24
# 181   sj  2011          42           21
# 182   sj  2011          43           21
# 183   sj  2011          44           23
# 184   sj  2011          45           23
# 185   sj  2011          46           22
# 186   sj  2011          47           23
# 187   sj  2011          48           21
# 188   sj  2011          49           20
# 189   sj  2011          50           24
# 190   sj  2011          51           23
# 191   sj  2012          52           24
# 192   sj  2012           1           14
# 193   sj  2012           2           13
# 194   sj  2012           3           14
# 195   sj  2012           4           15
# 196   sj  2012           5           13
# 197   sj  2012           6           14
# 198   sj  2012           7           12
# 199   sj  2012           8           13
# 200   sj  2012           9           14
# 201   sj  2012          10           14
# 202   sj  2012          11           14
# 203   sj  2012          12           13
# 204   sj  2012          13           15
# 205   sj  2012          14           15
# 206   sj  2012          15           16
# 207   sj  2012          16           19
# 208   sj  2012          17           14
# 209   sj  2012          18           18
# 210   sj  2012          19           20
# 211   sj  2012          20           18
# 212   sj  2012          21           19
# 213   sj  2012          22           18
# 214   sj  2012          23           18
# 215   sj  2012          24           19
# 216   sj  2012          25           19
# 217   sj  2012          26           20
# 218   sj  2012          27           21
# 219   sj  2012          28           21
# 220   sj  2012          29           20
# 221   sj  2012          30           20
# 222   sj  2012          31           22
# 223   sj  2012          32           22
# 224   sj  2012          33           23
# 225   sj  2012          34           23
# 226   sj  2012          35           20
# 227   sj  2012          36           21
# 228   sj  2012          37           22
# 229   sj  2012          38           22
# 230   sj  2012          39           23
# 231   sj  2012          40           24
# 232   sj  2012          41           24
# 233   sj  2012          42           25
# 234   sj  2012          43           24
# 235   sj  2012          44           21
# 236   sj  2012          45           24
# 237   sj  2012          46           23
# 238   sj  2012          47           26
# 239   sj  2012          48           21
# 240   sj  2012          49           22
# 241   sj  2012          50           19
# 242   sj  2012          51           21
# 243   sj  2013           1           11
# 244   sj  2013           2           16
# 245   sj  2013           3           12
# 246   sj  2013           4           12
# 247   sj  2013           5           16
# 248   sj  2013           6           14
# 249   sj  2013           7           14
# 250   sj  2013           8           12
# 251   sj  2013           9           14
# 252   sj  2013          10           14
# 253   sj  2013          11           13
# 254   sj  2013          12           13
# 255   sj  2013          13           14
# 256   sj  2013          14           12
# 257   sj  2013          15           15
# 258   sj  2013          16           17
# 259   sj  2013          17           15
# 260   iq  2010          26            3
# 261   iq  2010          27            3
# 262   iq  2010          28            8
# 263   iq  2010          29            1
# 264   iq  2010          30            3
# 265   iq  2010          31            4
# 266   iq  2010          32            2
# 267   iq  2010          33            3
# 268   iq  2010          34            1
# 269   iq  2010          35            4
# 270   iq  2010          36            4
# 271   iq  2010          37            3
# 272   iq  2010          38            5
# 273   iq  2010          39            3
# 274   iq  2010          40            6
# 275   iq  2010          41            4
# 276   iq  2010          42            4
# 277   iq  2010          43            8
# 278   iq  2010          44           10
# 279   iq  2010          45            8
# 280   iq  2010          46            7
# 281   iq  2010          47           13
# 282   iq  2010          48            9
# 283   iq  2010          49           10
# 284   iq  2010          50           10
# 285   iq  2010          51            7
# 286   iq  2011          52           14
# 287   iq  2011           1            1
# 288   iq  2011           2            4
# 289   iq  2011           3            1
# 290   iq  2011           4            1
# 291   iq  2011           5            1
# 292   iq  2011           6            2
# 293   iq  2011           7            5
# 294   iq  2011           8            3
# 295   iq  2011           9            6
# 296   iq  2011          10            4
# 297   iq  2011          11            4
# 298   iq  2011          12            4
# 299   iq  2011          13            6
# 300   iq  2011          14            5
# 301   iq  2011          15            7
# 302   iq  2011          16            7
# 303   iq  2011          17            7
# 304   iq  2011          18            8
# 305   iq  2011          19            5
# 306   iq  2011          20            4
# 307   iq  2011          21            2
# 308   iq  2011          22            4
# 309   iq  2011          23            3
# 310   iq  2011          24            3
# 311   iq  2011          25            3
# 312   iq  2011          26            4
# 313   iq  2011          27            4
# 314   iq  2011          28            3
# 315   iq  2011          29            1
# 316   iq  2011          30            2
# 317   iq  2011          31            2
# 318   iq  2011          32            3
# 319   iq  2011          33            1
# 320   iq  2011          34            3
# 321   iq  2011          35            2
# 322   iq  2011          36            1
# 323   iq  2011          37            4
# 324   iq  2011          38            5
# 325   iq  2011          39            6
# 326   iq  2011          40            5
# 327   iq  2011          41            6
# 328   iq  2011          42            9
# 329   iq  2011          43            7
# 330   iq  2011          44            6
# 331   iq  2011          45            6
# 332   iq  2011          46           13
# 333   iq  2011          47           10
# 334   iq  2011          48            9
# 335   iq  2011          49            9
# 336   iq  2011          50           11
# 337   iq  2011          51           11
# 338   iq  2012          52           12
# 339   iq  2012           1            4
# 340   iq  2012           2            3
# 341   iq  2012           3            3
# 342   iq  2012           4            0
# 343   iq  2012           5            2
# 344   iq  2012           6            7
# 345   iq  2012           7            1
# 346   iq  2012           8            1
# 347   iq  2012           9            4
# 348   iq  2012          10            4
# 349   iq  2012          11            3
# 350   iq  2012          12            2
# 351   iq  2012          13            4
# 352   iq  2012          14            5
# 353   iq  2012          15            4
# 354   iq  2012          16            8
# 355   iq  2012          17            4
# 356   iq  2012          18            3
# 357   iq  2012          19            3
# 358   iq  2012          20            5
# 359   iq  2012          21            3
# 360   iq  2012          22            1
# 361   iq  2012          23            5
# 362   iq  2012          24            1
# 363   iq  2012          25            1
# 364   iq  2012          26            2
# 365   iq  2012          27            4
# 366   iq  2012          28            4
# 367   iq  2012          29            7
# 368   iq  2012          30            1
# 369   iq  2012          31            2
# 370   iq  2012          32            1
# 371   iq  2012          33            0
# 372   iq  2012          34            4
# 373   iq  2012          35            2
# 374   iq  2012          36            5
# 375   iq  2012          37            4
# 376   iq  2012          38            4
# 377   iq  2012          39            6
# 378   iq  2012          40            4
# 379   iq  2012          41            7
# 380   iq  2012          42            6
# 381   iq  2012          43            7
# 382   iq  2012          44            8
# 383   iq  2012          45           10
# 384   iq  2012          46           10
# 385   iq  2012          47           14
# 386   iq  2012          48           12
# 387   iq  2012          49           11
# 388   iq  2012          50           11
# 389   iq  2012          51           11
# 390   iq  2013           1            5
# 391   iq  2013           2            1
# 392   iq  2013           3            1
# 393   iq  2013           4            2
# 394   iq  2013           5            4
# 395   iq  2013           6            3
# 396   iq  2013           7            3
# 397   iq  2013           8            7
# 398   iq  2013           9            4
# 399   iq  2013          10            7
# 400   iq  2013          11            4
# 401   iq  2013          12            6
# 402   iq  2013          13            3
# 403   iq  2013          14            4
# 404   iq  2013          15            3
# 405   iq  2013          16            5
# 406   iq  2013          17            5
# 407   iq  2013          18           -1
# 408   iq  2013          19            4
# 409   iq  2013          20            8
# 410   iq  2013          21            6
# 411   iq  2013          22            6
# 412   iq  2013          23            3
# 413   iq  2013          24            4
# 414   iq  2013          25            1
# 415   iq  2013          26            0

# %%
upload = './My Drive/ML Term Project/Submission CSV/submission_sgdregressor.csv'
submission.to_csv(upload, index = False)

# %% [markdown]
# # Deep Neural Network

# %%
import tensorflow as tf
from tensorflow.compat.v1.keras.models import Sequential
from tensorflow.compat.v1.keras.layers import Dense, Activation, Dropout

# %% [markdown]
# ## Model Builder

# %%
def model_builder(neurons=[8,4],
              epochs=20,
              batch_size=32,
              af='relu',
              ki=tf.keras.initializers.RandomNormal(),
              optim=tf.keras.optimizers.Adam()):
    model = Sequential()
    model.add(Dense(neurons[0], activation=af, kernel_initializer=ki, input_shape=(22,)))
    for neuron in neurons[1:]:
      model.add(Dense(neuron, activation=af, kernel_initializer=ki))
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mae',
                  optimizer=optim,
                  metrics=['accuracy'])
    history = model.fit(tr_feature_scaled, tr_label,
                        batch_size=batch_size, epochs=epochs,
                        verbose=1, validation_data=(val_feature_scaled, val_label))
    val_pred = model.predict(val_feature_scaled)
    mae = mean_absolute_error(val_label, val_pred)
    return model, history.history, mae

# %% [markdown]
# ## Hyperparameters Tuning

# %% [markdown]
# We do it manually because we want to have more control of what architecture we are training

# %%
df = pd.DataFrame(columns=['Neurons', 'Epochs', 'Batch Size', 'Activation', 'Optimizer', 'initializers', 'MAE'])

neurons=[[16,12,8,4,2], [30,15,5], [16,8,4], [8, 4]]
afs=['relu', 'tanh'] 
optims=[tf.keras.optimizers.Adam(), tf.keras.optimizers.RMSprop()]
optims_name=['Adam','RMSprop']
kis=[tf.keras.initializers.RandomNormal()]
kis_name=['Normal']
epochs = [512, 1024]
batchs = [64,32,128]

history = []
models = []

for b in batchs:
  for e in epochs:
    for m in range(len(neurons)):
      for j in range(len(afs)):
        for k in range(len(optims)):
          for l in range(len(kis)):
              my_model, my_history, mae=model_builder(neurons=neurons[m],
                                                        epochs=e,
                                                        batch_size=b,
                                                        af=afs[j],
                                                        ki=kis[l],
                                                        optim=optims[k])
              history.append(my_history)
              models.append(my_model)
              string = ""
              for x in neurons[m]:
                string+=(str(x)+"-")
              df = df.append({'Neurons':string,
                          'Epochs':e,
                          'Batch Size':b,
                          'Activation':afs[j],
                          'Optimizer':optims_name[k],
                          'initializers':kis_name[l],
                          'MAE':mae}, ignore_index=True)
df.sort_values(by=['MAE'], inplace=True)
print(df)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 578/1024
# 16/16 [==============================] - 0s 10ms/step - loss: 14.2489 - accuracy: 0.0692 - val_loss: 16.9058 - val_accuracy: 0.0438
# Epoch 579/1024
# 16/16 [==============================] - 0s 9ms/step - loss: 14.1914 - accuracy: 0.0711 - val_loss: 16.8581 - val_accuracy: 0.0461
# Epoch 580/1024
# 16/16 [==============================] - 0s 9ms/step - loss: 14.2209 - accuracy: 0.0702 - val_loss: 16.8641 - val_accuracy: 0.0461
# Epoch 581/1024
# 16/16 [==============================] - 0s 9ms/step - loss: 14.2195 - accuracy: 0.0702 - val_loss: 16.8734 - val_accuracy: 0.0438
# Epoch 582/1024
# 16/16 [==============================] - 0s 9ms/step - loss: 14.2000 - accuracy: 0.0692 - val_loss: 16.8962 - val_accuracy: 0.0438
# Epoch 583/1024
# 16/16 [==============================] - 0s 10ms/step - loss: 14
1024
# 16/16 [==============================] - 0s 9ms/step - loss: 14.9116 - accuracy: 0.0534 - val_loss: 16.7632 - val_accuracy: 0.0346
# Epoch 1023/1024
# 16/16 [==============================] - 0s 10ms/step - loss: 14.8839 - accuracy: 0.0514 - val_loss: 16.7693 - val_accuracy: 0.0346
# Epoch 1024/1024
# 16/16 [==============================] - 0s 9ms/step - loss: 14.8767 - accuracy: 0.0514 - val_loss: 16.7535 - val_accuracy: 0.0346
#         Neurons Epochs Batch Size Activation Optimizer initializers        MAE
# 2       16-8-4-    512         64       relu      Adam       Normal  16.630160
# 6       16-8-4-   1024         64       relu      Adam       Normal  16.742589
# 7          8-4-   1024         64       relu      Adam       Normal  16.747819
# 0  16-12-8-4-2-    512         64       relu      Adam       Normal  16.845572
# 3          8-4-    512         64       relu      Adam       Normal  16.937018
# 1      30-15-5-    512         64       relu      Adam       Normal  17.243343
# 5      30-15-5-   1024         64       relu      Adam       Normal  17.734581
# 4  16-12-8-4-2-   1024         64       relu      Adam       Normal  20.903593

# %%
def plot_it(r, name):

  # Plot training & validation loss values
  plt.plot(r['loss'])
  plt.plot(r['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Validation'], loc='upper left')

  plt.show()

# %%
index_best = df.index[0]
best_model = models[index_best]
model_hist = history[index_best]
plot_it(model_hist, 'Best ANN model')

# %% [markdown]
# ## Predit Test Data Using Best Hyperparameter Model

# %%
# predict on test data
te_pred = best_model.predict(te_feature_scaled)

# %%
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)

# %%
submission
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18            2
# 1     sj  2008          19            3
# 2     sj  2008          20            4
# 3     sj  2008          21            0
# 4     sj  2008          22            4
# 5     sj  2008          23            8
# 6     sj  2008          24            4
# 7     sj  2008          25            9
# 8     sj  2008          26           14
# 9     sj  2008          27           17
# 10    sj  2008          28           13
# 11    sj  2008          29           21
# 12    sj  2008          30           31
# 13    sj  2008          31           23
# 14    sj  2008          32           21
# 15    sj  2008          33           33
# 16    sj  2008          34           28
# 17    sj  2008          35           28
# 18    sj  2008          36           37
# 19    sj  2008          37           49
# 20    sj  2008          38           34
# 21    sj  2008          39           22
# 22    sj  2008          40           29
# 23    sj  2008          41           32
# 24    sj  2008          42           27
# 25    sj  2008          43           29
# 26    sj  2008          44           34
# 27    sj  2008          45           37
# 28    sj  2008          46           30
# 29    sj  2008          47           33
# 30    sj  2008          48           31
# 31    sj  2008          49           25
# 32    sj  2008          50           27
# 33    sj  2008          51           33
# 34    sj  2008          52           16
# 35    sj  2009           1           18
# 36    sj  2009           2           14
# 37    sj  2009           3           19
# 38    sj  2009           4           19
# 39    sj  2009           5           20
# 40    sj  2009           6           14
# 41    sj  2009           7           12
# 42    sj  2009           8           11
# 43    sj  2009           9           14
# 44    sj  2009          10            6
# 45    sj  2009          11            5
# 46    sj  2009          12            3
# 47    sj  2009          13            2
# 48    sj  2009          14            5
# 49    sj  2009          15            4
# 50    sj  2009          16            2
# 51    sj  2009          17            4
# 52    sj  2009          18            4
# 53    sj  2009          19            3
# 54    sj  2009          20            6
# 55    sj  2009          21            5
# 56    sj  2009          22            6
# 57    sj  2009          23            5
# 58    sj  2009          24            8
# 59    sj  2009          25           13
# 60    sj  2009          26           11
# 61    sj  2009          27           18
# 62    sj  2009          28           19
# 63    sj  2009          29           24
# 64    sj  2009          30           20
# 65    sj  2009          31           24
# 66    sj  2009          32           28
# 67    sj  2009          33           30
# 68    sj  2009          34           32
# 69    sj  2009          35           38
# 70    sj  2009          36           32
# 71    sj  2009          37           26
# 72    sj  2009          38           36
# 73    sj  2009          39           36
# 74    sj  2009          40           43
# 75    sj  2009          41           51
# 76    sj  2009          42           50
# 77    sj  2009          43           39
# 78    sj  2009          44           47
# 79    sj  2009          45           36
# 80    sj  2009          46           23
# 81    sj  2009          47           36
# 82    sj  2009          48           43
# 83    sj  2009          49           38
# 84    sj  2009          50           38
# 85    sj  2009          51           43
# 86    sj  2009          52           40
# 87    sj  2010          53           33
# 88    sj  2010           1           22
# 89    sj  2010           2           21
# 90    sj  2010           3           17
# 91    sj  2010           4           19
# 92    sj  2010           5           20
# 93    sj  2010           6           15
# 94    sj  2010           7           13
# 95    sj  2010           8           13
# 96    sj  2010           9           14
# 97    sj  2010          10           15
# 98    sj  2010          11            9
# 99    sj  2010          12            9
# 100   sj  2010          13            7
# 101   sj  2010          14            4
# 102   sj  2010          15            4
# 103   sj  2010          16            8
# 104   sj  2010          17           13
# 105   sj  2010          18            7
# 106   sj  2010          19            4
# 107   sj  2010          20            8
# 108   sj  2010          21            7
# 109   sj  2010          22           16
# 110   sj  2010          23           16
# 111   sj  2010          24           15
# 112   sj  2010          25           13
# 113   sj  2010          26           18
# 114   sj  2010          27           19
# 115   sj  2010          28           19
# 116   sj  2010          29           18
# 117   sj  2010          30           19
# 118   sj  2010          31           21
# 119   sj  2010          32           33
# 120   sj  2010          33           25
# 121   sj  2010          34           34
# 122   sj  2010          35           26
# 123   sj  2010          36           41
# 124   sj  2010          37           32
# 125   sj  2010          38           35
# 126   sj  2010          39           33
# 127   sj  2010          40           40
# 128   sj  2010          41           45
# 129   sj  2010          42           35
# 130   sj  2010          43           31
# 131   sj  2010          44           36
# 132   sj  2010          45           40
# 133   sj  2010          46           23
# 134   sj  2010          47           24
# 135   sj  2010          48           19
# 136   sj  2010          49            8
# 137   sj  2010          50           22
# 138   sj  2010          51           20
# 139   sj  2011          52           31
# 140   sj  2011           1           20
# 141   sj  2011           2           29
# 142   sj  2011           3           20
# 143   sj  2011           4           21
# 144   sj  2011           5           18
# 145   sj  2011           6           18
# 146   sj  2011           7           12
# 147   sj  2011           8           14
# 148   sj  2011           9            7
# 149   sj  2011          10            7
# 150   sj  2011          11            1
# 151   sj  2011          12            9
# 152   sj  2011          13           12
# 153   sj  2011          14           15
# 154   sj  2011          15            8
# 155   sj  2011          16            5
# 156   sj  2011          17            0
# 157   sj  2011          18            5
# 158   sj  2011          19            2
# 159   sj  2011          20           12
# 160   sj  2011          21           12
# 161   sj  2011          22           13
# 162   sj  2011          23           15
# 163   sj  2011          24           15
# 164   sj  2011          25           21
# 165   sj  2011          26           20
# 166   sj  2011          27           19
# 167   sj  2011          28           19
# 168   sj  2011          29           19
# 169   sj  2011          30           27
# 170   sj  2011          31           20
# 171   sj  2011          32           23
# 172   sj  2011          33           27
# 173   sj  2011          34           32
# 174   sj  2011          35           26
# 175   sj  2011          36           34
# 176   sj  2011          37           50
# 177   sj  2011          38           26
# 178   sj  2011          39           38
# 179   sj  2011          40           40
# 180   sj  2011          41           36
# 181   sj  2011          42           35
# 182   sj  2011          43           26
# 183   sj  2011          44           31
# 184   sj  2011          45           37
# 185   sj  2011          46           38
# 186   sj  2011          47           38
# 187   sj  2011          48           29
# 188   sj  2011          49           20
# 189   sj  2011          50           38
# 190   sj  2011          51           28
# 191   sj  2012          52           33
# 192   sj  2012           1           21
# 193   sj  2012           2           22
# 194   sj  2012           3           17
# 195   sj  2012           4           18
# 196   sj  2012           5           13
# 197   sj  2012           6           15
# 198   sj  2012           7           14
# 199   sj  2012           8           12
# 200   sj  2012           9            9
# 201   sj  2012          10           13
# 202   sj  2012          11            8
# 203   sj  2012          12            4
# 204   sj  2012          13            2
# 205   sj  2012          14            7
# 206   sj  2012          15            7
# 207   sj  2012          16           12
# 208   sj  2012          17            6
# 209   sj  2012          18            9
# 210   sj  2012          19            6
# 211   sj  2012          20           11
# 212   sj  2012          21            7
# 213   sj  2012          22            4
# 214   sj  2012          23            9
# 215   sj  2012          24           13
# 216   sj  2012          25           22
# 217   sj  2012          26           23
# 218   sj  2012          27           22
# 219   sj  2012          28           18
# 220   sj  2012          29           23
# 221   sj  2012          30           21
# 222   sj  2012          31           25
# 223   sj  2012          32           26
# 224   sj  2012          33           28
# 225   sj  2012          34           37
# 226   sj  2012          35           21
# 227   sj  2012          36           35
# 228   sj  2012          37           34
# 229   sj  2012          38           41
# 230   sj  2012          39           47
# 231   sj  2012          40           46
# 232   sj  2012          41           40
# 233   sj  2012          42           46
# 234   sj  2012          43           48
# 235   sj  2012          44           47
# 236   sj  2012          45           56
# 237   sj  2012          46           51
# 238   sj  2012          47           48
# 239   sj  2012          48           37
# 240   sj  2012          49           39
# 241   sj  2012          50           39
# 242   sj  2012          51           27
# 243   sj  2013           1           17
# 244   sj  2013           2           18
# 245   sj  2013           3           12
# 246   sj  2013           4           12
# 247   sj  2013           5           19
# 248   sj  2013           6           14
# 249   sj  2013           7           12
# 250   sj  2013           8           11
# 251   sj  2013           9           10
# 252   sj  2013          10           11
# 253   sj  2013          11            4
# 254   sj  2013          12            1
# 255   sj  2013          13            9
# 256   sj  2013          14            8
# 257   sj  2013          15            7
# 258   sj  2013          16            5
# 259   sj  2013          17            4
# 260   iq  2010          26            2
# 261   iq  2010          27            1
# 262   iq  2010          28            4
# 263   iq  2010          29            1
# 264   iq  2010          30            3
# 265   iq  2010          31            1
# 266   iq  2010          32            1
# 267   iq  2010          33            1
# 268   iq  2010          34            1
# 269   iq  2010          35            0
# 270   iq  2010          36            0
# 271   iq  2010          37            0
# 272   iq  2010          38            0
# 273   iq  2010          39            1
# 274   iq  2010          40            0
# 275   iq  2010          41            0
# 276   iq  2010          42            0
# 277   iq  2010          43            2
# 278   iq  2010          44            5
# 279   iq  2010          45            2
# 280   iq  2010          46            0
# 281   iq  2010          47           17
# 282   iq  2010          48            4
# 283   iq  2010          49            6
# 284   iq  2010          50           13
# 285   iq  2010          51            4
# 286   iq  2011          52           37
# 287   iq  2011           1           12
# 288   iq  2011           2           12
# 289   iq  2011           3           11
# 290   iq  2011           4           10
# 291   iq  2011           5           10
# 292   iq  2011           6           15
# 293   iq  2011           7            9
# 294   iq  2011           8           14
# 295   iq  2011           9           17
# 296   iq  2011          10            8
# 297   iq  2011          11            8
# 298   iq  2011          12            6
# 299   iq  2011          13           12
# 300   iq  2011          14            4
# 301   iq  2011          15           11
# 302   iq  2011          16            6
# 303   iq  2011          17            4
# 304   iq  2011          18            7
# 305   iq  2011          19            1
# 306   iq  2011          20            2
# 307   iq  2011          21            4
# 308   iq  2011          22            0
# 309   iq  2011          23            2
# 310   iq  2011          24            1
# 311   iq  2011          25            2
# 312   iq  2011          26            2
# 313   iq  2011          27            1
# 314   iq  2011          28            0
# 315   iq  2011          29            1
# 316   iq  2011          30            2
# 317   iq  2011          31            1
# 318   iq  2011          32            2
# 319   iq  2011          33            0
# 320   iq  2011          34            0
# 321   iq  2011          35            1
# 322   iq  2011          36            1
# 323   iq  2011          37            0
# 324   iq  2011          38            1
# 325   iq  2011          39            1
# 326   iq  2011          40            6
# 327   iq  2011          41            4
# 328   iq  2011          42            4
# 329   iq  2011          43            4
# 330   iq  2011          44            3
# 331   iq  2011          45            2
# 332   iq  2011          46           10
# 333   iq  2011          47            6
# 334   iq  2011          48            8
# 335   iq  2011          49            6
# 336   iq  2011          50           20
# 337   iq  2011          51           23
# 338   iq  2012          52           11
# 339   iq  2012           1           14
# 340   iq  2012           2           14
# 341   iq  2012           3           10
# 342   iq  2012           4           10
# 343   iq  2012           5           14
# 344   iq  2012           6           14
# 345   iq  2012           7            6
# 346   iq  2012           8            6
# 347   iq  2012           9            6
# 348   iq  2012          10            7
# 349   iq  2012          11            3
# 350   iq  2012          12            4
# 351   iq  2012          13            7
# 352   iq  2012          14            1
# 353   iq  2012          15            3
# 354   iq  2012          16            4
# 355   iq  2012          17            2
# 356   iq  2012          18            3
# 357   iq  2012          19            3
# 358   iq  2012          20            5
# 359   iq  2012          21            1
# 360   iq  2012          22            2
# 361   iq  2012          23            3
# 362   iq  2012          24            4
# 363   iq  2012          25            3
# 364   iq  2012          26            0
# 365   iq  2012          27            2
# 366   iq  2012          28            1
# 367   iq  2012          29            0
# 368   iq  2012          30            4
# 369   iq  2012          31            2
# 370   iq  2012          32            2
# 371   iq  2012          33            2
# 372   iq  2012          34            3
# 373   iq  2012          35            0
# 374   iq  2012          36            0
# 375   iq  2012          37            1
# 376   iq  2012          38            1
# 377   iq  2012          39            0
# 378   iq  2012          40            1
# 379   iq  2012          41            2
# 380   iq  2012          42            0
# 381   iq  2012          43            7
# 382   iq  2012          44            3
# 383   iq  2012          45            3
# 384   iq  2012          46            7
# 385   iq  2012          47           20
# 386   iq  2012          48           21
# 387   iq  2012          49            8
# 388   iq  2012          50            5
# 389   iq  2012          51           10
# 390   iq  2013           1           18
# 391   iq  2013           2           10
# 392   iq  2013           3            7
# 393   iq  2013           4           14
# 394   iq  2013           5            6
# 395   iq  2013           6            9
# 396   iq  2013           7            5
# 397   iq  2013           8           10
# 398   iq  2013           9            3
# 399   iq  2013          10            5
# 400   iq  2013          11            6
# 401   iq  2013          12           10
# 402   iq  2013          13            5
# 403   iq  2013          14            2
# 404   iq  2013          15            5
# 405   iq  2013          16            2
# 406   iq  2013          17            4
# 407   iq  2013          18            7
# 408   iq  2013          19            3
# 409   iq  2013          20            1
# 410   iq  2013          21            1
# 411   iq  2013          22            1
# 412   iq  2013          23            3
# 413   iq  2013          24            1
# 414   iq  2013          25            0
# 415   iq  2013          26            3

# %%
upload = './My Drive/ML Term Project/Submission CSV/submission_dnn.csv'
submission.to_csv(upload, index = False)

# %% [markdown]
# # Combined Techniques

# %% [markdown]
# ![alt_text](https://drive.google.com/uc?id=14agWoLfeW711Nhx4on_Xv_y8VgolHSRV)
#
# As our project is a competition and the test data it can only be tested in it, our best metric to decide wich model is better is the MAE that the website gives as output. So we can say that our bests three models are the Decision Tree, the Deep Neural Network, and the Random Forest. So lets try if we can get a lower MAE by applying Voting and then Bagging to them.

# %%
from sklearn.ensemble import VotingRegressor

voting = VotingRegressor([('dt', best_dt), ('rf', best_rf)])

cv = cross_val_score(voting, tr_feature_scaled, tr_label, cv = 4, scoring='neg_mean_absolute_error')
print("CV AVG MAE: ",-cv.mean())

voting.fit(tr_feature_scaled, tr_label)

predictions = voting.predict(val_feature_scaled)
mae = mean_absolute_error(val_label, predictions)

print("MAE in val : ", mae)
# Out:
# CV AVG MAE:  16.72989560782289
# MAE in val :  17.6246200712705

# %%
# predict on test data
te_pred = voting.predict(te_feature_scaled)
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)
upload = './My Drive/ML Term Project/Submission CSV/submission_voting.csv'
submission.to_csv(upload, index = False)

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.model_selection import GridSearchCV

param_distribs = {
    'n_estimators': [5, 10, 15],
    'bootstrap': [True, False],
    'bootstrap_features': [True, False],
    'oob_score': [True, False],
    'n_jobs': [-1],
    'random_state': [42]
}

bg = BaggingRegressor(best_rf)

rnd_search_bg = GridSearchCV(bg, param_grid=param_distribs, n_jobs=-1, cv=5, scoring='neg_mean_absolute_error')

rnd_search_bg.fit(tr_feature_scaled, tr_label)

print("{:.4f}".format(-rnd_search_bg.best_score_))

best_bg = rnd_search_bg.best_estimator_

predictions = best_bg.predict(val_feature_scaled)
mae = mean_absolute_error(val_label, predictions)

print("MAE in val : ", mae)
# Out:
# 15.9882
# MAE in val :  17.25994623655914

# %%
# predict on test data
te_pred = best_bg.predict(te_feature_scaled)
# create submission dataframe
submission = dengue_features_test.iloc[:,0:3]
submission['total_cases'] = te_pred.astype(int)
upload = './My Drive/ML Term Project/Submission CSV/submission_rf_bg.csv'
submission.to_csv(upload, index = False)

# %% [markdown]
# # Best Model

# %% [markdown]
# Voting with Random Forest and Decision Tree.
# Competition Rank = 1356 out of 8735 competitors
